# %% [markdown]
# # FD001
#
# here we'll build the models for FD001, and test it.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import os

import plotly.express as px
from plotly.subplots import make_subplots


import warnings
# Ignore warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import ruptures as rpt
from scipy.interpolate import interp1d
from scipy.stats import linregress
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import statsmodels.api as sm
from tslearn.clustering import TimeSeriesKMeans
from tslearn.utils import to_time_series_dataset
from joblib import dump, load

# %% [markdown]
# Cause we're treating stationary data as time series, we'll have an un-clustered global regression with sliding window features. And FD001's data have been transform to stationary data in EDA process, but because we want all columns to have rolling window features, we'll not load the file but re-generate stationary data again.

# %% [markdown]
# ## generates  rolling window features

# %%
# train and test column names
column_names_first_5 = ['Unit_Number', 'Time_in_Cycles', 'Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']

remaining_column_names = [f'Sensor_Measurement_{i}' for i in range(1,22)]

column_names = column_names_first_5 + remaining_column_names

DF_train_FD001 = pd.read_csv("train_FD001.txt", delim_whitespace=True, names=column_names)

# %%
Max_Life_train_FD001 = DF_train_FD001.groupby('Unit_Number')['Time_in_Cycles'].max()
    
DF_train_FD001['Max_Life'] = DF_train_FD001['Unit_Number'].map(Max_Life_train_FD001)
DF_train_FD001['RUL'] = DF_train_FD001['Max_Life'] - DF_train_FD001['Time_in_Cycles']


exponential_growth = ['Sensor_Measurement_2', 'Sensor_Measurement_3', 'Sensor_Measurement_4','Sensor_Measurement_8','Sensor_Measurement_11', 'Sensor_Measurement_12', 'Sensor_Measurement_13', 'Sensor_Measurement_15', 'Sensor_Measurement_17']
logarithmic_decay = ['Sensor_Measurement_7','Sensor_Measurement_20', 'Sensor_Measurement_21']

# Process exponential growth features
for feature in exponential_growth:
    # Apply log transformation
    DF_train_FD001[f"{feature}_stationary"] = np.log(DF_train_FD001[feature])

# Process logarithmic decay features
for feature in logarithmic_decay:
    # Apply differencing 
    DF_train_FD001[f"{feature}_stationary"] = DF_train_FD001[feature].diff()
    

stationary_data = DF_train_FD001
stationary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 40 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unit_Number                       20631 non-null  int64
#  1   Time_in_Cycles                    20631 non-null  int64
#  2   Operational_Setting_1             20631 non-null  float64
#  3   Operational_Setting_2             20631 non-null  float64
#  4   Operational_Setting_3             20631 non-null  float64
#  5   Sensor_Measurement_1              20631 non-null  float64
#  6   Sensor_Measurement_2              20631 non-null  float64
#  7   Sensor_Measurement_3              20631 non-null  float64
#  8   Sensor_Measurement_4              20631 non-null  float64
#  9   Sensor_Measurement_5              20631 non-null  float64
#  10  Sensor_Measurement_6              20631 non-null  float64
#  11  Sensor_Measurement_7              20631 non-null  float64
#  12  Sensor_Measurement_8              20631 non-null  float64
#  13  Sensor_Measurement_9              20631 non-null  float64
#  14  Sensor_Measurement_10             20631 non-null  float64
#  15  Sensor_Measurement_11             20631 non-null  float64
#  16  Sensor_Measurement_12             20631 non-null  float64
#  17  Sensor_Measurement_13             20631 non-null  float64
#  18  Sensor_Measurement_14             20631 non-null  float64
#  19  Sensor_Measurement_15             20631 non-null  float64
#  20  Sensor_Measurement_16             20631 non-null  float64
#  21  Sensor_Measurement_17             20631 non-null  int64
#  22  Sensor_Measurement_18             20631 non-null  int64
#  23  Sensor_Measurement_19             20631 non-null  float64
#  24  Sensor_Measurement_20             20631 non-null  float64
#  25  Sensor_Measurement_21             20631 non-null  float64
#  26  Max_Life                          20631 non-null  int64
#  27  RUL                               20631 non-null  int64
#  28  Sensor_Measurement_2_stationary   20631 non-null  float64
#  29  Sensor_Measurement_3_stationary   20631 non-null  float64
#  30  Sensor_Measurement_4_stationary   20631 non-null  float64
#  31  Sensor_Measurement_8_stationary   20631 non-null  float64
#  32  Sensor_Measurement_11_stationary  20631 non-null  float64
#  33  Sensor_Measurement_12_stationary  20631 non-null  float64
#  34  Sensor_Measurement_13_stationary  20631 non-null  float64
#  35  Sensor_Measurement_15_stationary  20631 non-null  float64
#  36  Sensor_Measurement_17_stationary  20631 non-null  float64
#  37  Sensor_Measurement_7_stationary   20630 non-null  float64
#  38  Sensor_Measurement_20_stationary  20630 non-null  float64
#  39  Sensor_Measurement_21_stationary  20630 non-null  float64
# dtypes: float64(34), int64(6)
# memory usage: 6.3 MB

# %%
features_draft = [col for col in stationary_data.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number']]

window_size = 20

# Create copies to store results
result_df = stationary_data.copy()

# Group the data by Unit_Number to calculate statistics separately for each unit
for feature in features_draft:
    if feature != "Time_in_Cycles":
        # Initialize empty lists to store the computed values
        means = []
        variances = []
        slopes = []

        # Process each unit separately
        for unit, group in stationary_data.groupby("Unit_Number"):
            group = group.sort_values("Time_in_Cycles")  # Ensure data is sorted by time

            # Initialize temporary lists for this feature and unit
            unit_means = []
            unit_variances = []
            unit_slopes = []

            # Iterate over rolling windows
            for i in range(len(group)):
                window = group.iloc[max(0, i - window_size + 1): i + 1]

                # Compute mean and variance
                unit_means.append(window[feature].mean())
                unit_variances.append(window[feature].var())

                # Compute slope if there's enough data
                if len(window) > 1:
                    slope, _, _, _, _ = linregress(window["Time_in_Cycles"], window[feature])
                    unit_slopes.append(slope)
                else:
                    unit_slopes.append(np.nan)

            # Append the computed results to the main lists
            means.extend(unit_means)
            variances.extend(unit_variances)
            slopes.extend(unit_slopes)

        # Add results to the DataFrame
        result_df[f"{feature}_mean"] = means
        result_df[f"{feature}_variance"] = variances
        result_df[f"{feature}_slope"] = slopes
# Out:
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_slope"] = slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_mean"] = means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_variance"] = variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_slope"] = slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_mean"] = means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_variance"] = variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_slope"] = slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_mean"] = means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_variance"] = variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/346362457.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_df[f"{feature}_slope"] = slopes

# %%
print(result_df.info())
result_df.to_csv('data.csv', index=False)  # Saves to the current working directory
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Columns: 148 entries, Unit_Number to Sensor_Measurement_21_stationary_slope
# dtypes: float64(142), int64(6)
# memory usage: 23.3 MB
# None

# %% [markdown]
# ## generates un-clustered global linear regression

# %%
features_draft = [col for col in result_df.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number']]

result_df = result_df.fillna(0)

# Ensure this loop will refine features_draft until all p-values < 0.05
while True:
    
    # Prepare the features (X) and target (y)
    X = result_df[features_draft]
    y = result_df['RUL']
    
    # Add a constant to the features for the intercept
    X_train_with_const = sm.add_constant(X)
    
    # Fit the linear model
    linear_model2 = sm.OLS(y, X_train_with_const)
    linear_model_fit2 = linear_model2.fit()
    
    # Get p-values and coef
    p_values = linear_model_fit2.pvalues
    params = linear_model_fit2.params
    
    
    # Identify features with p-values > 0.05 or coef == 0
    insignificant_features = params[params == 0].index.tolist()
    insignificant_features = insignificant_features + p_values[p_values > 0.05].index.tolist()
    
    # Exclude 'const' from insignificant features if present
    insignificant_features = [col for col in insignificant_features if col != 'const']
    
    # Break the loop if there are no insignificant features
    if not insignificant_features:
        break
    
    # Update features_draft by removing insignificant features
    features_draft = [col for col in features_draft if col not in insignificant_features]
    

print(linear_model_fit2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     823.8
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:14:49   Log-Likelihood:            -1.0446e+05
# No. Observations:               20631   AIC:                         2.090e+05
# Df Residuals:                   20574   BIC:                         2.095e+05
# Df Model:                          56
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                      -2.24e+11   1.06e+10    -21.089      0.000   -2.45e+11   -2.03e+11
# Time_in_Cycles                               -0.3300      0.006    -51.011      0.000      -0.343      -0.317
# Sensor_Measurement_7                          8.2322      0.946      8.706      0.000       6.379      10.086
# Sensor_Measurement_8                       1.011e+06   2.99e+05      3.382      0.001    4.25e+05     1.6e+06
# Sensor_Measurement_9                         -0.2167      0.066     -3.279      0.001      -0.346      -0.087
# Sensor_Measurement_13                      1.137e+06   2.92e+05      3.900      0.000    5.66e+05    1.71e+06
# Sensor_Measurement_20                        28.3838      4.067      6.979      0.000      20.412      36.356
# Sensor_Measurement_21                        52.4462      6.987      7.506      0.000      38.751      66.141
# Sensor_Measurement_8_stationary           -2.415e+09   7.14e+08     -3.383      0.001   -3.81e+09   -1.02e+09
# Sensor_Measurement_13_stationary          -2.716e+09   6.96e+08     -3.900      0.000   -4.08e+09   -1.35e+09
# Sensor_Measurement_7_stationary              -5.1850      0.669     -7.754      0.000      -6.496      -3.874
# Sensor_Measurement_20_stationary            -14.7020      2.716     -5.413      0.000     -20.026      -9.378
# Sensor_Measurement_21_stationary            -27.1504      4.622     -5.874      0.000     -36.211     -18.090
# Operational_Setting_1_variance            -4.402e+05   1.59e+05     -2.761      0.006   -7.53e+05   -1.28e+05
# Operational_Setting_2_mean                 1.576e+04   3187.612      4.945      0.000    9513.592     2.2e+04
# Operational_Setting_2_slope                3.209e+04   7571.523      4.238      0.000    1.72e+04    4.69e+04
# Sensor_Measurement_2_mean                  1.599e+04   5896.863      2.712      0.007    4432.535    2.75e+04
# Sensor_Measurement_2_variance               2.18e+04   6213.209      3.508      0.000    9617.954     3.4e+04
# Sensor_Measurement_2_slope                 -7.88e+04   1.48e+04     -5.333      0.000   -1.08e+05   -4.98e+04
# Sensor_Measurement_3_mean                   620.2411     90.717      6.837      0.000     442.429     798.053
# Sensor_Measurement_3_variance               -26.2821      6.270     -4.192      0.000     -38.571     -13.993
# Sensor_Measurement_6_mean                 -3614.5765    620.377     -5.826      0.000   -4830.565   -2398.588
# Sensor_Measurement_7_variance               -52.9676      4.764    -11.117      0.000     -62.306     -43.629
# Sensor_Measurement_7_slope                   37.4216      6.857      5.457      0.000      23.981      50.862
# Sensor_Measurement_8_mean                  -4.33e+06   1.11e+06     -3.912      0.000    -6.5e+06   -2.16e+06
# Sensor_Measurement_8_variance             -1880.0055    750.541     -2.505      0.012   -3351.125    -408.886
# Sensor_Measurement_9_mean                     1.0507      0.215      4.881      0.000       0.629       1.473
# Sensor_Measurement_9_slope                   -2.1332      0.573     -3.725      0.000      -3.256      -1.011
# Sensor_Measurement_11_variance             1.535e+04   5907.058      2.598      0.009    3766.847    2.69e+04
# Sensor_Measurement_12_mean                 7739.9035   2372.707      3.262      0.001    3089.209    1.24e+04
# Sensor_Measurement_12_variance            -1.656e+04   2880.498     -5.751      0.000   -2.22e+04   -1.09e+04
# Sensor_Measurement_13_mean                -1.166e+07   1.14e+06    -10.272      0.000   -1.39e+07   -9.44e+06
# Sensor_Measurement_13_slope               -1.872e+07   3.51e+06     -5.334      0.000   -2.56e+07   -1.18e+07
# Sensor_Measurement_14_mean                   -1.3921      0.235     -5.913      0.000      -1.854      -0.931
# Sensor_Measurement_14_variance                0.0635      0.024      2.601      0.009       0.016       0.111
# Sensor_Measurement_14_slope                   3.0688      0.700      4.383      0.000       1.696       4.441
# Sensor_Measurement_17_mean                 2664.2604    357.786      7.447      0.000    1962.971    3365.550
# Sensor_Measurement_17_variance             -919.5746    121.694     -7.556      0.000   -1158.104    -681.045
# Sensor_Measurement_20_mean                  -40.2056     11.244     -3.576      0.000     -62.244     -18.167
# Sensor_Measurement_20_variance             -520.8021     73.940     -7.044      0.000    -665.730    -375.874
# Sensor_Measurement_20_slope                 156.9365     23.429      6.698      0.000     111.014     202.859
# Sensor_Measurement_21_mean                   78.9885     18.928      4.173      0.000      41.889     116.088
# Sensor_Measurement_21_variance             -795.0507    245.136     -3.243      0.001   -1275.536    -314.565
# Sensor_Measurement_21_slope                 166.8547     45.084      3.701      0.000      78.485     255.224
# Sensor_Measurement_2_stationary_mean       -1.03e+07   3.79e+06     -2.719      0.007   -1.77e+07   -2.88e+06
# Sensor_Measurement_2_stationary_variance  -8.992e+09   2.57e+09     -3.505      0.000    -1.4e+10   -3.96e+09
# Sensor_Measurement_2_stationary_slope       5.06e+07   9.49e+06      5.331      0.000     3.2e+07    6.92e+07
# Sensor_Measurement_3_stationary_mean      -9.881e+05   1.44e+05     -6.853      0.000   -1.27e+06   -7.05e+05
# Sensor_Measurement_3_stationary_variance    6.63e+07   1.58e+07      4.187      0.000    3.53e+07    9.73e+07
# Sensor_Measurement_8_stationary_mean       1.034e+10   2.64e+09      3.912      0.000    5.16e+09    1.55e+10
# Sensor_Measurement_11_stationary_variance -3.609e+07   1.33e+07     -2.705      0.007   -6.22e+07   -9.94e+06
# Sensor_Measurement_12_stationary_mean     -4.028e+06   1.24e+06     -3.255      0.001   -6.45e+06    -1.6e+06
# Sensor_Measurement_12_stationary_variance  4.492e+09   7.83e+08      5.735      0.000    2.96e+09    6.03e+09
# Sensor_Measurement_13_stationary_mean      2.785e+10   2.71e+09     10.272      0.000    2.25e+10    3.32e+10
# Sensor_Measurement_13_stationary_slope     4.469e+10   8.38e+09      5.333      0.000    2.83e+10    6.11e+10
# Sensor_Measurement_17_stationary_mean     -1.046e+06   1.41e+05     -7.444      0.000   -1.32e+06   -7.71e+05
# Sensor_Measurement_17_stationary_variance  1.421e+08   1.88e+07      7.560      0.000    1.05e+08    1.79e+08
# Sensor_Measurement_7_stationary_mean         16.7351      1.900      8.807      0.000      13.011      20.459
# Sensor_Measurement_7_stationary_variance     14.0424      1.297     10.826      0.000      11.500      16.585
# Sensor_Measurement_7_stationary_slope        20.1719      2.689      7.502      0.000      14.901      25.443
# Sensor_Measurement_21_stationary_variance   295.9005     68.192      4.339      0.000     162.240     429.561
# ==============================================================================
# Omnibus:                     3301.992   Durbin-Watson:                   0.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6139.758
# Skew:                           1.011   Prob(JB):                         0.00
# Kurtosis:                       4.748   Cond. No.                     6.46e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.27e-17. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Save the model and preprocessed data
dump((linear_model_fit2, X_train_with_const.columns), "FD001unclustered_regression_model_and_columns.joblib")
# Out:
# ['FD001unclustered_regression_model_and_columns.joblib']

# %%
print(result_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Columns: 148 entries, Unit_Number to Sensor_Measurement_21_stationary_slope
# dtypes: float64(142), int64(6)
# memory usage: 23.3 MB
# None

# %% [markdown]
# ## clustering

# %%
def normalize_segment_length(segment, length=100):
    if len(segment) == 0:  # Handle empty segments
        return np.zeros(length)
    x = np.linspace(0, 1, len(segment))
    f = interp1d(x, segment, kind='linear', fill_value="extrapolate")
    x_new = np.linspace(0, 1, length)
    return f(x_new)

# Initialize storage for normalized segments and mappings
normalized_segments = {}
segments_mapping = {}

# Features to segment and cluster
features = ['Operational_Setting_1', 'Operational_Setting_2', 'Sensor_Measurement_11_stationary']


# Loop through each feature
for feature in features:
    normalized_segments[feature] = []
    segments_mapping[feature] = []
    
    # Segment time series for each unit
    for unit in stationary_data['Unit_Number'].unique():
        # Extract unit data
        unit_data = stationary_data[stationary_data['Unit_Number'] == unit]
        
        # Scale the feature values
        scaler = StandardScaler()
        scaled_data = scaler.fit_transform(unit_data[feature].values.reshape(-1, 1)).flatten()
        
        # Detect change points using Ruptures
        model = rpt.Pelt(model="l2").fit(scaled_data)
        change_points = model.predict(pen=10)  # Adjust `pen` for granularity
        
        # Normalize each segment and store mapping information
        for start, end in zip([0] + change_points[:-1], change_points):
            segment = scaled_data[start:end]
            normalized_segment = normalize_segment_length(segment, length=100)
            
            normalized_segments[feature].append(normalized_segment)
            segments_mapping[feature].append({
                "unit_number": unit,
                "start_idx": start,
                "end_idx": end
            })

# %%
cluster_labels = {}
cluster_models = {}
k = 3  # Number of clusters (adjust as needed)

for feature, segments in normalized_segments.items():
    # Convert normalized segments to time-series dataset
    ts_data = to_time_series_dataset(segments)
    
    # Perform DTW clustering
    model = TimeSeriesKMeans(n_clusters=k, metric="dtw", random_state=42)
    labels = model.fit_predict(ts_data)
    
    # Store cluster labels and the trained model
    cluster_labels[feature] = labels
    cluster_models[feature] = model

# %%
for feature, model in cluster_models.items():
    plt.figure(figsize=(10, 6))
    for i, centroid in enumerate(model.cluster_centers_):
        plt.plot(centroid.ravel(), label=f"Cluster {i}")
    plt.title(f"Cluster Centroids for {feature}")
    plt.legend()
    plt.show()

# %%
for feature, labels in cluster_labels.items():
    # Count the number of segments in each cluster
    unique, counts = np.unique(labels, return_counts=True)
    cluster_sizes = dict(zip(unique, counts))
    
    plt.figure(figsize=(4, 3))
    plt.bar(unique, counts, tick_label=[f"Cluster {i}" for i in unique])
    plt.title(f"Cluster Sizes for {feature}")
    plt.xlabel("Cluster")
    plt.ylabel("Number of Segments")
    plt.show()
    
    # Print the cluster sizes
    print(f"Cluster sizes for {feature}:")
    for cluster, size in cluster_sizes.items():
        print(f"  Cluster {cluster}: {size} segments")
# Out:
# Cluster sizes for Operational_Setting_1:
#   Cluster 0: 28 segments
#   Cluster 1: 33 segments
#   Cluster 2: 40 segments
# Cluster sizes for Operational_Setting_2:
#   Cluster 0: 49 segments
#   Cluster 1: 38 segments
#   Cluster 2: 16 segments
# Cluster sizes for Sensor_Measurement_11_stationary:
#   Cluster 0: 108 segments
#   Cluster 1: 111 segments
#   Cluster 2: 102 segments

# %%
model_save_path = "clustering_models"

# Save each clustering model in the cluster_models dictionary
for feature, model in cluster_models.items():
    model_filename = f"{model_save_path}/FD001{feature}_clustering_model.pkl"
    dump(model, model_filename)
    
# # Load the saved clustering models
# loaded_cluster_models = {}

# for feature in normalized_segments.keys():
#     model_filename = f"{model_save_path}/{feature}_clustering_model.pkl"
#     loaded_cluster_models[feature] = joblib.load(model_filename)

# %% [markdown]
# ## linear regression for each cluster

# %%
# Create a mapping of cluster assignments to original rows
cluster_to_original_rows = {}

for feature, labels in cluster_labels.items():
    cluster_to_original_rows[feature] = []
    for i, label in enumerate(labels):
        metadata = segments_mapping[feature][i]
        unit_number = metadata["unit_number"]
        start_idx = metadata["start_idx"]
        end_idx = metadata["end_idx"]
        
        # Map each original row in the segment to the cluster
        cluster_to_original_rows[feature].append({
            "unit_number": unit_number,
            "start_idx": start_idx,
            "end_idx": end_idx,
            "cluster": label
        })

# %%
def get_windowdf_rows_by_cluster(feature, cluster_id):
    original_rows = []
    for mapping in cluster_to_original_rows[feature]:
        if mapping["cluster"] == cluster_id:
            unit = mapping["unit_number"]
            start, end = mapping["start_idx"], mapping["end_idx"]
            
            # Retrieve the original rows for the segment
            rows = result_df[
                (result_df["Unit_Number"] == unit) &
                (result_df["Time_in_Cycles"] >= start) &
                (result_df["Time_in_Cycles"] < end)
            ]
            original_rows.append(rows)
    
    return pd.concat(original_rows)

# %%
print(features)
# Out:
# ['Operational_Setting_1', 'Operational_Setting_2', 'Sensor_Measurement_11_stationary']

# %%
level2_models = {}

for cluster_feature in features:
    for cluster_number_id in range(3):
        
        cluster_rows = get_windowdf_rows_by_cluster(cluster_feature, cluster_number_id)

        features_draft = [col for col in cluster_rows.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number','Time_in_Cycles_mean','Time_in_Cycles_variance','Time_in_Cycles_slope']]

        cluster_rows = cluster_rows.fillna(0)

        X = cluster_rows[features_draft]
        y = cluster_rows['RUL']
        X_train_with_const = sm.add_constant(X)


        linear_model = sm.OLS(y, X_train_with_const)
        linear_model_fit = linear_model.fit()

        # Get the p-values from the fitted model
        p_values = linear_model_fit.pvalues

        # Filter for columns with p-value > 0.05
        insignificant_features = p_values[p_values > 0.05].index.tolist()

        features_draft = [col for col in features_draft if col not in insignificant_features]

        t_stats = linear_model_fit.tvalues

        # Sort the t-statistics by absolute value
        sorted_features_by_tstat = t_stats.abs().sort_values(ascending=False)

        filtered_t_stats = {key: value for key, value in t_stats.items() if key in features_draft}
        t_stats_df = pd.DataFrame(list(filtered_t_stats.items()), columns=["Feature", "T_Value"])

        # Identify sensor-stationary pairs
        sensor_pairs = []
        for feature in t_stats_df['Feature']:
            if "_stationary" in feature:
                original = feature.replace("_stationary", "")
                if original in t_stats_df['Feature'].values:
                    sensor_pairs.append((original, feature))


        kept_features = []

        for original, stationary in sensor_pairs:
            t_original = t_stats_df.loc[t_stats_df['Feature'] == original, 'T_Value'].values[0]
            t_stationary = t_stats_df.loc[t_stats_df['Feature'] == stationary, 'T_Value'].values[0]
            if abs(t_stationary) > abs(t_original):
                if original in features_draft: 
                    features_draft.remove(original)
            else:
                if stationary in features_draft: features_draft.remove(stationary)

        # Ensure this loop will refine features_draft until all p-values < 0.05
        while True:

            # Prepare the features (X) and target (y)
            X = cluster_rows[features_draft]
            y = cluster_rows['RUL']
            X_train_with_const = sm.add_constant(X)

            # Fit the linear model
            linear_model2 = sm.OLS(y, X_train_with_const)
            linear_model_fit2 = linear_model2.fit()

            # Get p-values
            p_values = linear_model_fit2.pvalues

            # Identify features with p-values > 0.05
            insignificant_features = p_values[p_values > 0.05].index.tolist()

            # Exclude 'const' from insignificant features if present
            insignificant_features = [col for col in insignificant_features if col != 'const']

            # Break the loop if there are no insignificant features
            if not insignificant_features:
                break

            # Update features_draft by removing insignificant features
            features_draft = [col for col in features_draft if col not in insignificant_features]

        level2_models[f'{cluster_feature},{cluster_number_id}'] = (linear_model_fit2,linear_model_fit2.summary())
        dump((linear_model_fit2, X_train_with_const.columns), f"FD001{cluster_feature}_c{cluster_number_id}_model_and_columns.joblib")

# %%
print(level2_models)
# Out:
# {'Operational_Setting_1,0': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd3d1534d00>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     1691.
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:15:19   Log-Likelihood:                -26033.
# No. Observations:                5613   AIC:                         5.210e+04
# Df Residuals:                    5595   BIC:                         5.222e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                      2.228e+04    767.491     29.031      0.000    2.08e+04    2.38e+04
# Time_in_Cycles                               -0.6398      0.008    -80.528      0.000      -0.655      -0.624
# Operational_Setting_2_mean                -1.435e+04   4244.781     -3.382      0.001   -2.27e+04   -6033.323
# Operational_Setting_2_variance             5.327e+07   1.63e+07      3.270      0.001    2.13e+07    8.52e+07
# Sensor_Measurement_2_variance               -28.2379      9.807     -2.879      0.004     -47.463      -9.013
# Sensor_Measurement_4_variance                 0.2995      0.050      5.940      0.000       0.201       0.398
# Sensor_Measurement_6_variance              1.542e+06   9.31e+04     16.566      0.000    1.36e+06    1.72e+06
# Sensor_Measurement_7_variance               -29.5905      4.515     -6.553      0.000     -38.442     -20.739
# Sensor_Measurement_9_variance                -0.1710      0.034     -5.031      0.000      -0.238      -0.104
# Sensor_Measurement_12_variance              -35.5483      9.286     -3.828      0.000     -53.752     -17.345
# Sensor_Measurement_13_slope                -319.9837    102.538     -3.121      0.002    -520.999    -118.969
# Sensor_Measurement_14_variance                0.1872      0.050      3.745      0.000       0.089       0.285
# Sensor_Measurement_4_stationary_mean      -3048.5884    105.947    -28.775      0.000   -3256.285   -2840.892
# Sensor_Measurement_11_stationary_variance  -1.71e+06      2e+05     -8.553      0.000    -2.1e+06   -1.32e+06
# Sensor_Measurement_7_stationary_slope       -13.6891      2.283     -5.995      0.000     -18.166      -9.213
# Sensor_Measurement_20_stationary_mean        31.3405      8.157      3.842      0.000      15.349      47.331
# Sensor_Measurement_20_stationary_variance  -124.1331     20.932     -5.930      0.000    -165.167     -83.099
# Sensor_Measurement_21_stationary_variance   278.0834     70.105      3.967      0.000     140.650     415.517
# ==============================================================================
# Omnibus:                       71.109   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.860
# Skew:                          -0.086   Prob(JB):                     6.68e-11
# Kurtosis:                       2.586   Cond. No.                     6.08e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.36e-12. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_1,1': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd3d4ddcb50>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.683
# Model:                            OLS   Adj. R-squared:                  0.682
# Method:                 Least Squares   F-statistic:                     607.1
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:15:20   Log-Likelihood:                -36299.
# No. Observations:                7074   AIC:                         7.265e+04
# Df Residuals:                    7048   BIC:                         7.283e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                     -7.739e+06   8.57e+05     -9.029      0.000   -9.42e+06   -6.06e+06
# Time_in_Cycles                               -0.3863      0.011    -35.874      0.000      -0.407      -0.365
# Sensor_Measurement_7                          5.5890      1.236      4.521      0.000       3.166       8.012
# Operational_Setting_2_mean                 2.677e+04   5699.421      4.696      0.000    1.56e+04    3.79e+04
# Sensor_Measurement_2_mean                   -23.3687      6.392     -3.656      0.000     -35.899     -10.838
# Sensor_Measurement_2_slope                  -61.6690     15.447     -3.992      0.000     -91.949     -31.389
# Sensor_Measurement_3_slope                   -4.2647      0.972     -4.388      0.000      -6.170      -2.359
# Sensor_Measurement_4_slope                   -3.9787      1.088     -3.657      0.000      -6.111      -1.846
# Sensor_Measurement_5_slope                -2.236e+04   6448.357     -3.468      0.001    -3.5e+04   -9723.766
# Sensor_Measurement_7_mean                    44.0746      4.123     10.690      0.000      35.992      52.157
# Sensor_Measurement_8_variance             -6018.3782   1470.411     -4.093      0.000   -8900.825   -3135.931
# Sensor_Measurement_12_slope                  63.5010     13.045      4.868      0.000      37.929      89.073
# Sensor_Measurement_13_slope               -1222.0287    130.065     -9.396      0.000   -1476.995    -967.063
# Sensor_Measurement_14_mean                   -0.3858      0.076     -5.045      0.000      -0.536      -0.236
# Sensor_Measurement_14_slope                  11.4578      1.227      9.339      0.000       9.053      13.863
# Sensor_Measurement_18_variance             -398.8207    114.992     -3.468      0.001    -624.240    -173.402
# Sensor_Measurement_20_mean                 -113.6911     18.286     -6.217      0.000    -149.538     -77.844
# Sensor_Measurement_20_variance             -492.1260    131.578     -3.740      0.000    -750.058    -234.194
# Sensor_Measurement_20_slope                 344.3691     43.514      7.914      0.000     259.069     429.669
# Sensor_Measurement_21_variance             -911.6277    343.184     -2.656      0.008   -1584.372    -238.883
# Sensor_Measurement_3_stationary_mean      -7774.8824    725.552    -10.716      0.000   -9197.182   -6352.583
# Sensor_Measurement_4_stationary_variance  -4.162e+05   1.69e+05     -2.458      0.014   -7.48e+05   -8.43e+04
# Sensor_Measurement_13_stationary_mean      1.002e+06    1.1e+05      9.086      0.000    7.86e+05    1.22e+06
# Sensor_Measurement_13_stationary_variance -2.564e+10   7.39e+09     -3.468      0.001   -4.01e+10   -1.11e+10
# Sensor_Measurement_17_stationary_variance  1.215e+06   2.28e+05      5.321      0.000    7.68e+05    1.66e+06
# Sensor_Measurement_7_stationary_variance     12.5081      2.018      6.197      0.000       8.552      16.464
# Sensor_Measurement_7_stationary_slope        16.8475      4.605      3.658      0.000       7.820      25.875
# Sensor_Measurement_21_stationary_mean        99.9553     21.624      4.622      0.000      57.565     142.346
# ==============================================================================
# Omnibus:                      373.115   Durbin-Watson:                   0.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              433.806
# Skew:                           0.587   Prob(JB):                     6.31e-95
# Kurtosis:                       3.303   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.76e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_1,2': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd3d9932fd0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.635
# Model:                            OLS   Adj. R-squared:                  0.633
# Method:                 Least Squares   F-statistic:                     424.2
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:15:21   Log-Likelihood:                -40367.
# No. Observations:                7844   AIC:                         8.080e+04
# Df Residuals:                    7811   BIC:                         8.103e+04
# Df Model:                          32
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Time_in_Cycles                               -0.2567      0.010    -24.851      0.000      -0.277      -0.236
# Sensor_Measurement_7                          4.1136      1.174      3.504      0.000       1.812       6.415
# Sensor_Measurement_9                         -0.2153      0.107     -2.005      0.045      -0.426      -0.005
# Sensor_Measurement_19                     -6.709e+04   8538.142     -7.857      0.000   -8.38e+04   -5.04e+04
# Sensor_Measurement_20                        14.7997      4.801      3.083      0.002       5.389      24.210
# Sensor_Measurement_21                        26.8989      8.084      3.328      0.001      11.053      42.745
# Operational_Setting_1_variance            -2.443e+06   2.94e+05     -8.323      0.000   -3.02e+06   -1.87e+06
# Operational_Setting_2_variance             1.259e+08    2.2e+07      5.722      0.000    8.28e+07    1.69e+08
# Operational_Setting_2_slope                3.805e+04   1.26e+04      3.012      0.003    1.33e+04    6.28e+04
# Sensor_Measurement_2_variance                93.9725     14.930      6.294      0.000      64.706     123.239
# Sensor_Measurement_2_slope                  -56.3933     13.872     -4.065      0.000     -83.587     -29.200
# Sensor_Measurement_6_mean                 -1.675e+04   1994.203     -8.398      0.000   -2.07e+04   -1.28e+04
# Sensor_Measurement_6_variance             -1.096e+06   2.74e+05     -3.995      0.000   -1.63e+06   -5.58e+05
# Sensor_Measurement_6_slope                 8668.4784   3112.009      2.785      0.005    2568.108    1.48e+04
# Sensor_Measurement_7_slope                   38.7310      9.783      3.959      0.000      19.554      57.908
# Sensor_Measurement_8_variance             -3848.5644   1309.232     -2.940      0.003   -6415.009   -1282.120
# Sensor_Measurement_9_mean                     1.6869      0.379      4.452      0.000       0.944       2.430
# Sensor_Measurement_12_variance              -85.7769     13.948     -6.150      0.000    -113.118     -58.435
# Sensor_Measurement_13_variance            -1.536e+04   1354.334    -11.341      0.000    -1.8e+04   -1.27e+04
# Sensor_Measurement_14_mean                   -1.3252      0.415     -3.194      0.001      -2.139      -0.512
# Sensor_Measurement_18_slope               -2.403e-05    4.2e-06     -5.723      0.000   -3.23e-05   -1.58e-05
# Sensor_Measurement_20_variance             -932.9115    134.518     -6.935      0.000   -1196.602    -669.221
# Sensor_Measurement_20_slope                 127.0597     40.701      3.122      0.002      47.275     206.844
# Sensor_Measurement_21_mean                  247.8712     32.168      7.706      0.000     184.814     310.928
# Sensor_Measurement_2_stationary_mean      -3.229e+04   3855.387     -8.376      0.000   -3.98e+04   -2.47e+04
# Sensor_Measurement_3_stationary_mean       2674.5793    739.481      3.617      0.000    1224.999    4124.159
# Sensor_Measurement_3_stationary_variance   6.742e+05   2.05e+05      3.289      0.001    2.72e+05    1.08e+06
# Sensor_Measurement_4_stationary_variance  -1.255e+06   1.54e+05     -8.124      0.000   -1.56e+06   -9.52e+05
# Sensor_Measurement_11_stationary_variance -2.979e+06    2.6e+05    -11.443      0.000   -3.49e+06   -2.47e+06
# Sensor_Measurement_13_stationary_mean      9.349e+05   1.11e+05      8.449      0.000    7.18e+05    1.15e+06
# Sensor_Measurement_15_stationary_mean     -2756.6197    715.243     -3.854      0.000   -4158.688   -1354.551
# Sensor_Measurement_15_stationary_variance  7.018e+05   2.01e+05      3.494      0.000    3.08e+05     1.1e+06
# Sensor_Measurement_17_stationary_mean     -2977.5185    725.816     -4.102      0.000   -4400.312   -1554.725
# Sensor_Measurement_21_stationary_variance   628.7906     69.216      9.085      0.000     493.110     764.472
# ==============================================================================
# Omnibus:                     1389.585   Durbin-Watson:                   0.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2553.308
# Skew:                           1.112   Prob(JB):                         0.00
# Kurtosis:                       4.693   Cond. No.                     1.19e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.27e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_2,0': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd3e0da0d30>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.676
# Method:                 Least Squares   F-statistic:                     655.2
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:15:21   Log-Likelihood:                -51240.
# No. Observations:               10041   AIC:                         1.025e+05
# Df Residuals:                   10008   BIC:                         1.028e+05
# Df Model:                          32
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                     -1.459e+06   7.75e+05     -1.881      0.060   -2.98e+06    6.11e+04
# Time_in_Cycles                               -0.3759      0.009    -39.922      0.000      -0.394      -0.357
# Sensor_Measurement_7                          4.6754      0.997      4.689      0.000       2.721       6.630
# Sensor_Measurement_9                         -0.3142      0.097     -3.243      0.001      -0.504      -0.124
# Sensor_Measurement_14                        -0.3244      0.128     -2.530      0.011      -0.576      -0.073
# Sensor_Measurement_20                        14.7155      4.142      3.553      0.000       6.597      22.834
# Sensor_Measurement_11_stationary          -1581.1045    182.267     -8.675      0.000   -1938.384   -1223.825
# Operational_Setting_1_mean                -3946.8136    747.792     -5.278      0.000   -5412.635   -2480.992
# Operational_Setting_1_variance            -7.032e+05   2.43e+05     -2.891      0.004   -1.18e+06   -2.26e+05
# Operational_Setting_2_mean                 2.806e+04   4859.525      5.775      0.000    1.85e+04    3.76e+04
# Sensor_Measurement_2_variance                35.9530     12.550      2.865      0.004      11.353      60.553
# Sensor_Measurement_2_slope                  -49.6987     11.982     -4.148      0.000     -73.185     -26.212
# Sensor_Measurement_3_variance                 0.1596      0.064      2.502      0.012       0.035       0.285
# Sensor_Measurement_7_slope                   67.4725     10.098      6.682      0.000      47.678      87.267
# Sensor_Measurement_8_mean                  -133.7871     46.574     -2.873      0.004    -225.081     -42.493
# Sensor_Measurement_9_mean                     1.6126      0.313      5.153      0.000       0.999       2.226
# Sensor_Measurement_9_variance                -0.3037      0.043     -7.077      0.000      -0.388      -0.220
# Sensor_Measurement_14_mean                   -1.1579      0.367     -3.159      0.002      -1.876      -0.439
# Sensor_Measurement_14_variance                0.2929      0.058      5.063      0.000       0.179       0.406
# Sensor_Measurement_14_slope                   2.4333      1.007      2.415      0.016       0.458       4.408
# Sensor_Measurement_15_mean                 -347.7173     73.232     -4.748      0.000    -491.267    -204.168
# Sensor_Measurement_17_slope                 -14.4777      3.604     -4.017      0.000     -21.543      -7.413
# Sensor_Measurement_20_mean                  -55.6501     15.863     -3.508      0.000     -86.744     -24.556
# Sensor_Measurement_20_variance             -616.3492    107.188     -5.750      0.000    -826.459    -406.239
# Sensor_Measurement_20_slope                 129.1743     32.219      4.009      0.000      66.019     192.329
# Sensor_Measurement_3_stationary_mean      -5461.7818    615.824     -8.869      0.000   -6668.921   -4254.642
# Sensor_Measurement_8_stationary_slope     -2.943e+06   2.73e+05    -10.766      0.000   -3.48e+06   -2.41e+06
# Sensor_Measurement_13_stationary_mean      2.349e+05   1.06e+05      2.216      0.027    2.71e+04    4.43e+05
# Sensor_Measurement_17_stationary_variance   6.83e+05   1.95e+05      3.511      0.000    3.02e+05    1.06e+06
# Sensor_Measurement_7_stationary_variance     11.2765      1.228      9.186      0.000       8.870      13.683
# Sensor_Measurement_21_stationary_mean       132.3217     18.927      6.991      0.000      95.222     169.422
# Sensor_Measurement_21_stationary_variance   575.1216     93.862      6.127      0.000     391.133     759.110
# Sensor_Measurement_21_stationary_slope      158.0588     29.475      5.363      0.000     100.282     215.835
# ==============================================================================
# Omnibus:                     1078.892   Durbin-Watson:                   0.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1539.876
# Skew:                           0.833   Prob(JB):                         0.00
# Kurtosis:                       3.952   Cond. No.                     3.42e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.42e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """), 'Operational_Setting_2,1': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd3e0cc4790>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     435.8
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:15:22   Log-Likelihood:                -39234.
# No. Observations:                7705   AIC:                         7.854e+04
# Df Residuals:                    7669   BIC:                         7.879e+04
# Df Model:                          35
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Time_in_Cycles                               -0.3923      0.011    -35.870      0.000      -0.414      -0.371
# Operational_Setting_3                      5.935e+06   1.25e+06      4.734      0.000    3.48e+06    8.39e+06
# Sensor_Measurement_5                       7.739e+05   1.63e+05      4.734      0.000    4.53e+05    1.09e+06
# Sensor_Measurement_10                      8.269e+04   1.75e+04      4.734      0.000    4.85e+04    1.17e+05
# Sensor_Measurement_16                      -584.9260    123.373     -4.741      0.000    -826.771    -343.081
# Sensor_Measurement_19                      1.169e+07   2.47e+06      4.735      0.000    6.85e+06    1.65e+07
# Sensor_Measurement_20                        17.4761      4.743      3.685      0.000       8.179      26.773
# Sensor_Measurement_21                        36.4949      7.702      4.738      0.000      21.396      51.594
# Sensor_Measurement_8_stationary           -2.134e+05   3.64e+04     -5.868      0.000   -2.85e+05   -1.42e+05
# Sensor_Measurement_7_stationary              -2.2124      0.788     -2.808      0.005      -3.757      -0.668
# Operational_Setting_1_mean                 2581.4300    897.965      2.875      0.004     821.173    4341.687
# Operational_Setting_2_mean                -1.939e+04   5788.554     -3.350      0.001   -3.07e+04   -8043.831
# Operational_Setting_2_variance             1.442e+08   2.22e+07      6.495      0.000    1.01e+08    1.88e+08
# Operational_Setting_3_mean                 6.487e+06   1.37e+06      4.734      0.000     3.8e+06    9.17e+06
# Operational_Setting_3_variance               -4.9891      1.055     -4.728      0.000      -7.058      -2.921
# Operational_Setting_3_slope                 -84.6896     17.884     -4.735      0.000    -119.747     -49.632
# Sensor_Measurement_1_mean                 -7.261e+06   1.53e+06     -4.743      0.000   -1.03e+07   -4.26e+06
# Sensor_Measurement_1_variance                 7.6738      1.620      4.737      0.000       4.498      10.849
# Sensor_Measurement_1_slope                    0.3228      0.068      4.734      0.000       0.189       0.456
# Sensor_Measurement_5_mean                  8.307e+05   1.75e+05      4.734      0.000    4.87e+05    1.17e+06
# Sensor_Measurement_5_variance                 0.4870      0.103      4.736      0.000       0.285       0.689
# Sensor_Measurement_5_slope                    1.4473      0.306      4.736      0.000       0.848       2.046
# Sensor_Measurement_6_mean                 -9964.4895    863.449    -11.540      0.000   -1.17e+04   -8271.894
# Sensor_Measurement_7_variance               -18.9607      6.509     -2.913      0.004     -31.720      -6.201
# Sensor_Measurement_7_slope                   42.7296      9.275      4.607      0.000      24.549      60.910
# Sensor_Measurement_8_variance             -6784.7257   1243.014     -5.458      0.000   -9221.372   -4348.079
# Sensor_Measurement_9_mean                     1.4184      0.361      3.930      0.000       0.711       2.126
# Sensor_Measurement_9_variance                 0.2332      0.047      4.942      0.000       0.141       0.326
# Sensor_Measurement_9_slope                   -2.3802      1.092     -2.180      0.029      -4.520      -0.240
# Sensor_Measurement_10_mean                 5.549e+04   1.17e+04      4.734      0.000    3.25e+04    7.85e+04
# Sensor_Measurement_10_slope                   0.0062      0.001      4.736      0.000       0.004       0.009
# Sensor_Measurement_12_variance              -47.2562     13.307     -3.551      0.000     -73.342     -21.171
# Sensor_Measurement_13_slope                -385.3902    134.205     -2.872      0.004    -648.468    -122.313
# Sensor_Measurement_14_mean                   -1.6938      0.413     -4.103      0.000      -2.503      -0.885
# Sensor_Measurement_14_variance               -0.1541      0.067     -2.293      0.022      -0.286      -0.022
# Sensor_Measurement_14_slope                   5.6757      1.150      4.935      0.000       3.421       7.930
# Sensor_Measurement_16_variance             -3.72e-06   7.85e-07     -4.736      0.000   -5.26e-06   -2.18e-06
# Sensor_Measurement_16_slope                        0          0        nan        nan           0           0
# Sensor_Measurement_17_mean                    3.6941      1.800      2.052      0.040       0.166       7.222
# Sensor_Measurement_19_mean                 1.325e+07    2.8e+06      4.735      0.000    7.76e+06    1.87e+07
# Sensor_Measurement_19_variance                     0          0        nan        nan           0           0
# Sensor_Measurement_19_slope                        0          0        nan        nan           0           0
# Sensor_Measurement_20_mean                 -114.4559     19.327     -5.922      0.000    -152.342     -76.570
# Sensor_Measurement_20_variance            -1073.8557    129.816     -8.272      0.000   -1328.331    -819.381
# Sensor_Measurement_20_slope                 157.9225     41.626      3.794      0.000      76.325     239.520
# Sensor_Measurement_21_mean                  226.4179     29.983      7.551      0.000     167.642     285.194
# Sensor_Measurement_2_stationary_mean       -5.15e+04   3988.416    -12.913      0.000   -5.93e+04   -4.37e+04
# Sensor_Measurement_3_stationary_mean       3151.6562    694.999      4.535      0.000    1789.268    4514.044
# Sensor_Measurement_4_stationary_variance  -5.101e+05   1.37e+05     -3.717      0.000   -7.79e+05   -2.41e+05
# Sensor_Measurement_8_stationary_mean       6.268e+05    1.3e+05      4.829      0.000    3.72e+05    8.81e+05
# Sensor_Measurement_11_stationary_variance -1.827e+06   2.59e+05     -7.043      0.000   -2.34e+06   -1.32e+06
# Sensor_Measurement_11_stationary_slope    -7973.4624   1710.903     -4.660      0.000   -1.13e+04   -4619.625
# Sensor_Measurement_13_stationary_mean      5.365e+05   1.21e+05      4.432      0.000    2.99e+05    7.74e+05
# Sensor_Measurement_13_stationary_variance -3.351e+10   7.07e+09     -4.736      0.000   -4.74e+10   -1.96e+10
# Sensor_Measurement_15_stationary_mean     -6230.2437    762.495     -8.171      0.000   -7724.942   -4735.546
# Sensor_Measurement_15_stationary_variance -1.539e+06   2.09e+05     -7.355      0.000   -1.95e+06   -1.13e+06
# Sensor_Measurement_7_stationary_mean         17.1515      2.603      6.589      0.000      12.049      22.254
# ==============================================================================
# Omnibus:                     1391.871   Durbin-Watson:                   0.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2948.992
# Skew:                           1.063   Prob(JB):                         0.00
# Kurtosis:                       5.160   Cond. No.                     1.18e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.22e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_2,2': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd3e0d9da00>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     745.3
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:15:22   Log-Likelihood:                -12969.
# No. Observations:                2785   AIC:                         2.598e+04
# Df Residuals:                    2764   BIC:                         2.611e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                      8.047e+05   1.16e+05      6.917      0.000    5.77e+05    1.03e+06
# Time_in_Cycles                               -0.3890      0.012    -31.479      0.000      -0.413      -0.365
# Operational_Setting_2_mean                 6.711e+04   5950.830     11.278      0.000    5.54e+04    7.88e+04
# Operational_Setting_2_slope               -5.462e+04   1.41e+04     -3.861      0.000   -8.24e+04   -2.69e+04
# Sensor_Measurement_2_slope                   67.4078     16.337      4.126      0.000      35.373      99.442
# Sensor_Measurement_6_mean                 -1.389e+04    870.351    -15.959      0.000   -1.56e+04   -1.22e+04
# Sensor_Measurement_7_mean                    16.4903      3.880      4.250      0.000       8.881      24.099
# Sensor_Measurement_7_variance               -40.7371      7.414     -5.495      0.000     -55.274     -26.200
# Sensor_Measurement_8_variance              5165.6168   1304.636      3.959      0.000    2607.457    7723.777
# Sensor_Measurement_9_mean                    -0.5736      0.079     -7.284      0.000      -0.728      -0.419
# Sensor_Measurement_13_mean                 -123.5258     49.012     -2.520      0.012    -219.630     -27.422
# Sensor_Measurement_14_slope                   7.8726      1.653      4.763      0.000       4.632      11.114
# Sensor_Measurement_20_mean                   82.3076     18.740      4.392      0.000      45.562     119.054
# Sensor_Measurement_21_mean                 -222.6559     33.652     -6.616      0.000    -288.642    -156.669
# Sensor_Measurement_2_stationary_mean      -3.004e+04   4149.525     -7.240      0.000   -3.82e+04   -2.19e+04
# Sensor_Measurement_3_stationary_mean      -3062.3158    817.135     -3.748      0.000   -4664.574   -1460.058
# Sensor_Measurement_12_stationary_slope     2.456e+04   7459.536      3.293      0.001    9937.322    3.92e+04
# Sensor_Measurement_15_stationary_mean      2542.9516    832.037      3.056      0.002     911.474    4174.429
# Sensor_Measurement_7_stationary_slope       -29.3634      4.544     -6.461      0.000     -38.274     -20.453
# Sensor_Measurement_20_stationary_variance   234.5061     36.363      6.449      0.000     163.204     305.808
# Sensor_Measurement_21_stationary_slope      189.0969     33.470      5.650      0.000     123.468     254.726
# ==============================================================================
# Omnibus:                      122.276   Durbin-Watson:                   0.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.928
# Skew:                           0.527   Prob(JB):                     1.12e-30
# Kurtosis:                       3.282   Cond. No.                     2.25e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.25e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """), 'Sensor_Measurement_11_stationary,0': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd3d965d880>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.617
# Model:                            OLS   Adj. R-squared:                  0.615
# Method:                 Least Squares   F-statistic:                     420.3
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:15:23   Log-Likelihood:                -21761.
# No. Observations:                5240   AIC:                         4.356e+04
# Df Residuals:                    5219   BIC:                         4.370e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Time_in_Cycles                               0.1545      0.005     28.116      0.000       0.144       0.165
# Operational_Setting_1_variance            -1.39e+06   1.46e+05     -9.536      0.000   -1.68e+06    -1.1e+06
# Operational_Setting_2_mean               -9345.5296   2862.401     -3.265      0.001    -1.5e+04   -3734.025
# Operational_Setting_3_variance               0.0504      0.016      3.225      0.001       0.020       0.081
# Operational_Setting_3_slope                  0.0188      0.006      3.224      0.001       0.007       0.030
# Sensor_Measurement_1_variance                0.0002   7.65e-05      3.227      0.001     9.7e-05       0.000
# Sensor_Measurement_1_slope                  -0.0012      0.000     -3.225      0.001      -0.002      -0.000
# Sensor_Measurement_5_variance               -0.0010      0.000     -3.225      0.001      -0.002      -0.000
# Sensor_Measurement_5_slope                  -0.0004      0.000     -3.229      0.001      -0.001      -0.000
# Sensor_Measurement_7_slope                 194.5390     12.942     15.032      0.000     169.168     219.910
# Sensor_Measurement_9_variance               -0.0644      0.017     -3.752      0.000      -0.098      -0.031
# Sensor_Measurement_10_variance           -4.478e-05   1.39e-05     -3.222      0.001    -7.2e-05   -1.75e-05
# Sensor_Measurement_10_slope                5.12e-05   1.59e-05      3.225      0.001    2.01e-05    8.23e-05
# Sensor_Measurement_12_variance              13.9060      6.845      2.032      0.042       0.488      27.324
# Sensor_Measurement_12_slope                319.3167     18.216     17.530      0.000     283.606     355.027
# Sensor_Measurement_13_variance           -5305.7853    696.982     -7.613      0.000   -6672.161   -3939.409
# Sensor_Measurement_14_mean                  -0.4814      0.022    -21.910      0.000      -0.524      -0.438
# Sensor_Measurement_15_variance           -7137.8129   1648.722     -4.329      0.000   -1.04e+04   -3905.628
# Sensor_Measurement_16_slope              -5.388e-08   1.65e-08     -3.259      0.001   -8.63e-08   -2.15e-08
# Sensor_Measurement_18_variance            2.544e-09   8.02e-10      3.170      0.002    9.71e-10    4.12e-09
# Sensor_Measurement_18_slope                       0          0        nan        nan           0           0
# Sensor_Measurement_19_variance                    0          0        nan        nan           0           0
# Sensor_Measurement_20_mean                 117.0894      7.160     16.352      0.000     103.052     131.127
# Sensor_Measurement_20_variance            -310.1562     68.259     -4.544      0.000    -443.973    -176.340
# Sensor_Measurement_20_slope                533.2034     55.956      9.529      0.000     423.506     642.901
# Sensor_Measurement_21_mean                  47.1333     11.918      3.955      0.000      23.769      70.498
# Sensor_Measurement_21_slope               1076.9781     92.556     11.636      0.000     895.530    1258.426
# Sensor_Measurement_2_stationary_variance -9.298e+06   2.89e+06     -3.216      0.001    -1.5e+07   -3.63e+06
# Sensor_Measurement_4_stationary_slope    -2.998e+04   1913.559    -15.666      0.000   -3.37e+04   -2.62e+04
# Sensor_Measurement_13_stationary_slope   -4.337e+06   3.98e+05    -10.902      0.000   -5.12e+06   -3.56e+06
# Sensor_Measurement_15_stationary_mean     -768.1595     57.738    -13.304      0.000    -881.349    -654.970
# Sensor_Measurement_15_stationary_slope   -2.052e+04   2425.356     -8.461      0.000   -2.53e+04   -1.58e+04
# Sensor_Measurement_7_stationary_variance   -15.9858      1.604     -9.967      0.000     -19.130     -12.842
# ==============================================================================
# Omnibus:                      566.713   Durbin-Watson:                   0.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              853.064
# Skew:                           0.803   Prob(JB):                    5.75e-186
# Kurtosis:                       4.152   Cond. No.                     1.04e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.22e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Sensor_Measurement_11_stationary,1': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd3f5b4c460>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.357
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     231.0
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:15:25   Log-Likelihood:                -64815.
# No. Observations:               12515   AIC:                         1.297e+05
# Df Residuals:                   12484   BIC:                         1.299e+05
# Df Model:                          30
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Time_in_Cycles                               -0.4038      0.011    -37.498      0.000      -0.425      -0.383
# Operational_Setting_3                       -30.9910      6.512     -4.759      0.000     -43.756     -18.226
# Sensor_Measurement_7                          3.7920      0.937      4.045      0.000       1.954       5.630
# Sensor_Measurement_9                         -0.3048      0.096     -3.190      0.001      -0.492      -0.117
# Sensor_Measurement_14                        -0.3509      0.129     -2.731      0.006      -0.603      -0.099
# Sensor_Measurement_18                      -740.0730    155.515     -4.759      0.000   -1044.906    -435.240
# Sensor_Measurement_21                        15.2835      6.800      2.247      0.025       1.954      28.614
# Operational_Setting_2_mean                 2.251e+04   4314.487      5.218      0.000    1.41e+04     3.1e+04
# Operational_Setting_2_slope                2.204e+04   8589.039      2.566      0.010    5201.997    3.89e+04
# Operational_Setting_3_mean                  -30.9909      6.512     -4.759      0.000     -43.756     -18.226
# Operational_Setting_3_slope                2.774e-07   4.38e-08      6.327      0.000    1.91e-07    3.63e-07
# Sensor_Measurement_1_mean                  -160.7443     33.778     -4.759      0.000    -226.954     -94.535
# Sensor_Measurement_4_mean                    -3.3786      0.310    -10.885      0.000      -3.987      -2.770
# Sensor_Measurement_5_mean                    -4.5316      0.952     -4.760      0.000      -6.398      -2.665
# Sensor_Measurement_6_mean                 -4709.2311    679.060     -6.935      0.000   -6040.293   -3378.169
# Sensor_Measurement_8_variance             -4476.3362   1071.801     -4.176      0.000   -6577.231   -2375.441
# Sensor_Measurement_9_mean                     1.0583      0.293      3.614      0.000       0.484       1.632
# Sensor_Measurement_9_variance                -0.7043      0.058    -12.138      0.000      -0.818      -0.591
# Sensor_Measurement_10_mean                   -0.4029      0.085     -4.759      0.000      -0.569      -0.237
# Sensor_Measurement_10_slope                4.089e-09   1.21e-09      3.368      0.001    1.71e-09    6.47e-09
# Sensor_Measurement_14_mean                   -1.1885      0.341     -3.482      0.000      -1.857      -0.519
# Sensor_Measurement_14_variance               -0.5827      0.099     -5.903      0.000      -0.776      -0.389
# Sensor_Measurement_14_slope                   2.4726      0.822      3.009      0.003       0.862       4.084
# Sensor_Measurement_16_mean                   -0.0093      0.002     -4.759      0.000      -0.013      -0.005
# Sensor_Measurement_18_mean                 -740.0604    155.515     -4.759      0.000   -1044.894    -435.226
# Sensor_Measurement_19_mean                  -30.9912      6.512     -4.759      0.000     -43.756     -18.226
# Sensor_Measurement_20_mean                  -69.3773     13.986     -4.960      0.000     -96.793     -41.962
# Sensor_Measurement_20_variance             -749.0736    100.855     -7.427      0.000    -946.766    -551.382
# Sensor_Measurement_20_slope                 128.1651     25.594      5.008      0.000      77.997     178.334
# Sensor_Measurement_21_mean                  110.9626     24.073      4.609      0.000      63.775     158.150
# Sensor_Measurement_21_slope                 159.9423     47.830      3.344      0.001      66.189     253.696
# Sensor_Measurement_2_stationary_mean      -1.972e+04   3039.963     -6.487      0.000   -2.57e+04   -1.38e+04
# Sensor_Measurement_3_stationary_variance   7.229e+05   1.49e+05      4.852      0.000    4.31e+05    1.01e+06
# Sensor_Measurement_11_stationary_variance -1.596e+06   2.18e+05     -7.316      0.000   -2.02e+06   -1.17e+06
# Sensor_Measurement_11_stationary_slope    -2814.9385   1139.018     -2.471      0.013   -5047.590    -582.287
# Sensor_Measurement_13_stationary_mean      4.969e+05   9.86e+04      5.040      0.000    3.04e+05     6.9e+05
# Sensor_Measurement_15_stationary_variance -4.608e+05   1.66e+05     -2.773      0.006   -7.86e+05   -1.35e+05
# Sensor_Measurement_17_stationary_variance  6.168e+05   1.64e+05      3.750      0.000    2.94e+05    9.39e+05
# Sensor_Measurement_7_stationary_variance      7.4211      1.227      6.049      0.000       5.016       9.826
# Sensor_Measurement_7_stationary_slope         7.5745      2.770      2.735      0.006       2.145      13.004
# Sensor_Measurement_21_stationary_variance   262.5875     62.657      4.191      0.000     139.770     385.405
# ==============================================================================
# Omnibus:                     1662.616   Durbin-Watson:                   0.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2514.442
# Skew:                           0.963   Prob(JB):                         0.00
# Kurtosis:                       4.054   Cond. No.                     1.41e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.96e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Sensor_Measurement_11_stationary,2': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd3d5c281f0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     517.1
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:15:25   Log-Likelihood:                -8010.1
# No. Observations:                2776   AIC:                         1.607e+04
# Df Residuals:                    2752   BIC:                         1.621e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Time_in_Cycles                                0.0387      0.002     17.286      0.000       0.034       0.043
# Operational_Setting_3                         1.8236      0.306      5.967      0.000       1.224       2.423
# Sensor_Measurement_1                          9.1191      1.578      5.778      0.000       6.024      12.214
# Sensor_Measurement_5                          0.2338      0.044      5.301      0.000       0.147       0.320
# Sensor_Measurement_6                          0.3339      0.065      5.134      0.000       0.206       0.461
# Sensor_Measurement_10                         0.0225      0.004      5.686      0.000       0.015       0.030
# Sensor_Measurement_19                         1.7965      0.305      5.889      0.000       1.198       2.395
# Operational_Setting_2_mean                -1.076e+04   1106.014     -9.728      0.000   -1.29e+04   -8590.763
# Operational_Setting_3_mean                    1.8243      0.306      5.969      0.000       1.225       2.424
# Operational_Setting_3_slope                2.962e-08   2.86e-09     10.372      0.000     2.4e-08    3.52e-08
# Sensor_Measurement_1_mean                     8.9188      1.575      5.664      0.000       5.831      12.006
# Sensor_Measurement_5_mean                     0.2385      0.044      5.399      0.000       0.152       0.325
# Sensor_Measurement_6_mean                     0.3309      0.065      5.091      0.000       0.203       0.458
# Sensor_Measurement_7_slope                   48.7982      5.334      9.148      0.000      38.339      59.258
# Sensor_Measurement_10_mean                    0.0235      0.004      5.912      0.000       0.016       0.031
# Sensor_Measurement_13_mean                  -53.4324      7.098     -7.528      0.000     -67.351     -39.514
# Sensor_Measurement_13_variance             -475.7447    220.925     -2.153      0.031    -908.941     -42.548
# Sensor_Measurement_13_slope                -448.0842     78.381     -5.717      0.000    -601.775    -294.393
# Sensor_Measurement_14_mean                   -0.2353      0.014    -17.208      0.000      -0.262      -0.208
# Sensor_Measurement_14_slope                   0.7547      0.348      2.168      0.030       0.072       1.437
# Sensor_Measurement_15_variance            -1622.4445    667.627     -2.430      0.015   -2931.545    -313.344
# Sensor_Measurement_16_mean                    0.0005   9.07e-05      5.413      0.000       0.000       0.001
# Sensor_Measurement_16_slope                6.532e-09    6.3e-10     10.371      0.000     5.3e-09    7.77e-09
# Sensor_Measurement_18_mean                   26.3822      7.124      3.703      0.000      12.412      40.352
# Sensor_Measurement_19_mean                    1.8243      0.306      5.969      0.000       1.225       2.424
# Sensor_Measurement_19_slope                        0          0        nan        nan           0           0
# Sensor_Measurement_20_variance               95.4445     26.773      3.565      0.000      42.947     147.942
# Sensor_Measurement_20_slope                 210.0090     24.610      8.534      0.000     161.754     258.264
# Sensor_Measurement_21_slope                 288.0623     37.651      7.651      0.000     214.235     361.889
# Sensor_Measurement_2_stationary_slope      -2.68e+04   4512.019     -5.940      0.000   -3.57e+04    -1.8e+04
# Sensor_Measurement_3_stationary_mean       -275.7435    129.150     -2.135      0.033    -528.983     -22.504
# Sensor_Measurement_3_stationary_slope     -4351.8693    856.546     -5.081      0.000   -6031.408   -2672.331
# Sensor_Measurement_4_stationary_slope     -4832.8346    736.479     -6.562      0.000   -6276.942   -3388.727
# Sensor_Measurement_11_stationary_slope    -5989.4592    976.049     -6.136      0.000   -7903.321   -4075.598
# Sensor_Measurement_12_stationary_mean      9348.3836    403.032     23.195      0.000    8558.109    1.01e+04
# Sensor_Measurement_12_stationary_variance -6.193e+06   5.97e+05    -10.372      0.000   -7.36e+06   -5.02e+06
# Sensor_Measurement_15_stationary_slope    -3362.6987   1025.851     -3.278      0.001   -5374.215   -1351.183
# Sensor_Measurement_17_stationary_slope    -8005.6300    853.029     -9.385      0.000   -9678.271   -6332.989
# Sensor_Measurement_7_stationary_mean         10.1431      2.989      3.393      0.001       4.282      16.005
# Sensor_Measurement_21_stationary_variance   226.0622     32.429      6.971      0.000     162.474     289.650
# ==============================================================================
# Omnibus:                      272.486   Durbin-Watson:                   0.209
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              408.112
# Skew:                           0.738   Prob(JB):                     2.40e-89
# Kurtosis:                       4.161   Cond. No.                     1.24e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.42e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """)}

# %% [markdown]
# # testing

# %%
column_names_first_5 = ['Unit_Number', 'Time_in_Cycles', 'Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']

remaining_column_names = [f'Sensor_Measurement_{i}' for i in range(1,22)]

column_names = column_names_first_5 + remaining_column_names

test1 = pd.read_csv("test_FD001.txt", delim_whitespace=True, names=column_names)

# %% [markdown]
# ## generate columns for testing data

# %%
def generate_remaining_columns(df):
    
    exponential_growth = ['Sensor_Measurement_2', 'Sensor_Measurement_3', 'Sensor_Measurement_4','Sensor_Measurement_8','Sensor_Measurement_11', 'Sensor_Measurement_12', 'Sensor_Measurement_13', 'Sensor_Measurement_15', 'Sensor_Measurement_17']
    logarithmic_decay = ['Sensor_Measurement_7','Sensor_Measurement_20', 'Sensor_Measurement_21']

    # Process exponential growth features
    for feature in exponential_growth:
        # Apply log transformation
        df[f"{feature}_stationary"] = np.log(df[feature])

    # Process logarithmic decay features
    for feature in logarithmic_decay:
        # Apply differencing 
        df[f"{feature}_stationary"] = df[feature].diff()
    
    rolling_columns = [col for col in df.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number']]


    result = []
    window_size = 20

    for unit, group in df.groupby("Unit_Number"):
        group = group.sort_values("Time_in_Cycles")  # Ensure data is sorted by time

        for feature in rolling_columns:
            if feature in group.columns:
                # Initialize temporary lists for this feature and unit
                unit_means = []
                unit_variances = []
                unit_slopes = []

                # Iterate over rolling windows
                for i in range(len(group)):
                    window = group.iloc[max(0, i - window_size + 1): i + 1]

                    # Compute mean and variance
                    unit_means.append(window[feature].mean())
                    unit_variances.append(window[feature].var())

                    # Compute slope if there's enough data
                    if len(window) > 1:
                        slope, _, _, _, _ = linregress(window["Time_in_Cycles"], window[feature])
                        unit_slopes.append(slope)
                    else:
                        unit_slopes.append(np.nan)

                # Add new columns to the group
                group[f'{feature}_mean'] = unit_means
                group[f'{feature}_variance'] = unit_variances
                group[f'{feature}_slope'] = unit_slopes

        # Append the processed group to the result
        result.append(group)

    # Concatenate all processed groups back together
    final_df = pd.concat(result, axis=0).reset_index(drop=True)

    return final_df

# %%
test1_full = generate_remaining_columns(test1)
# Out:
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# ...
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_mean'] = unit_means
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_variance'] = unit_variances
# /var/folders/gd/ngdqm3753z14mnwyps6g4_0h0000gn/T/ipykernel_61382/3618401161.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group[f'{feature}_slope'] = unit_slopes

# %% [markdown]
# ## assign each unit's last segment to its cluster

# %%
def assign_last_segment_to_cluster(test_data, features, cluster_models, segments_mapping):
    assigned_clusters = {}

    for feature in features:
        # Extract test data for the feature
        test_feature_data = test_data[feature].values

        # Scale the test feature
        scaler = StandardScaler()
        scaled_test_feature = scaler.fit_transform(test_feature_data.reshape(-1, 1)).flatten()

        # Detect change points using Ruptures
        model = rpt.Pelt(model="l2").fit(scaled_test_feature)
        change_points = model.predict(pen=10)  # Use the same penalty as training

        # Extract the last segment
        start_idx = change_points[-2] if len(change_points) > 1 else 0
        end_idx = len(scaled_test_feature)
        last_segment = scaled_test_feature[start_idx:end_idx]

        # Normalize the last segment
        normalized_last_segment = normalize_segment_length(last_segment, length=100)

        # Convert to the correct format for the model
        normalized_last_segment = normalized_last_segment.reshape(1, -1)

        # Assign the last segment to the closest cluster
        cluster_model = cluster_models[feature]
        cluster_label = cluster_model.predict(normalized_last_segment)[0]

        # Store the result
        assigned_clusters[feature] = {
            "cluster_label": cluster_label,
            "start_idx": start_idx,
            "end_idx": end_idx
        }

    return assigned_clusters

# %%
test_data = test1_full[test1_full["Unit_Number"] == 1]

assigned_clusters = assign_last_segment_to_cluster(
    test_data=test_data,
    features=['Operational_Setting_1', 'Operational_Setting_2', 'Sensor_Measurement_11_stationary'],
    cluster_models=cluster_models,
    segments_mapping=segments_mapping
)
# Out:
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/tslearn/utils/utils.py:90: UserWarning: 2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries
#   warnings.warn(
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/tslearn/utils/utils.py:90: UserWarning: 2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries
#   warnings.warn(
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/tslearn/utils/utils.py:90: UserWarning: 2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries
#   warnings.warn(

# %%
print(assigned_clusters)
# Out:
# {'Operational_Setting_1': {'cluster_label': 2, 'start_idx': 0, 'end_idx': 31}, 'Operational_Setting_2': {'cluster_label': 2, 'start_idx': 0, 'end_idx': 31}, 'Sensor_Measurement_11_stationary': {'cluster_label': 0, 'start_idx': 0, 'end_idx': 31}}

# %% [markdown]
# ## get weighted prediction based on assigned clusters

# %%
def calculate_weighted_prediction(test_data, assigned_clusters, df_threshold=5):
    total_weight = 0
    weighted_sum = 0

    # Iterate through the assigned clusters
    for cluster_feature, details in assigned_clusters.items():
        cluster_number_id = details["cluster_label"]

        # Retrieve the corresponding model and its details
        model_key = f"{cluster_feature},{cluster_number_id}"
        model_fit, summary = level2_models[model_key]
        r2_value = model_fit.rsquared
        df_model = model_fit.df_model  # Degree of freedom of the model

        # Calculate scaling factor based on df_model
        scaling_factor = min(1, df_model / df_threshold)

        # Final weight for the model
        weight = r2_value * scaling_factor

        # Load the saved model and its features
        filename = f"FD001{cluster_feature}_c{cluster_number_id}_model_and_columns.joblib"
        linear_model_fit2, model_features = load(filename)

        # Prepare the test data for the model
        test_data = test_data.copy()
        test_data["const"] = 1  # Add intercept
        filtered_data = test_data[model_features].fillna(0)

        # Get the prediction for the current model
        filtered_data_last = filtered_data.iloc[-1]  # Use the last row of test data
        prediction = linear_model_fit2.predict(filtered_data_last)

        # Accumulate the weighted sum and total weight
        weighted_sum += prediction * weight
        total_weight += weight

    # Calculate the weighted average prediction
    if total_weight > 0:
        return weighted_sum / total_weight
    else:
        return 0  # Handle edge case where no models have a valid weight

# %%
import warnings
from statsmodels.tsa.api import SimpleExpSmoothing

# Ignore specific warning from tslearn
warnings.filterwarnings("ignore", message="2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries")

# Ignore SettingWithCopyWarning globally
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)


def test_dataset_fit(test_data_frame):
    RUL_predictions = []

    for unit_number, group in test_data_frame.groupby("Unit_Number"):
        # Get test data for the current unit
        test_data = test_data_frame[test_data_frame["Unit_Number"] == unit_number]

        # Assign clusters to the last segment of the test data
        assigned_clusters = assign_last_segment_to_cluster(
            test_data=test_data,
            features=['Operational_Setting_1', 'Operational_Setting_2', 'Sensor_Measurement_11_stationary'],
            cluster_models=cluster_models,
            segments_mapping=segments_mapping
        )

        # Get predictions and weights from all relevant models
        weighted_prediction = calculate_weighted_prediction(test_data, assigned_clusters)

        # Use exponential smoothing to stabilize predictions
        y_train = []
        for i in range(1, 11):  # Take the last 10 data points
            prediction = weighted_prediction
            y_train.append(prediction)

        fit3 = SimpleExpSmoothing(y_train, initialization_method="estimated").fit()
        fcast3 = fit3.forecast(1)
        RUL_predictions.append(fcast3[0])

    return RUL_predictions
    
        
test1_RUL_Predict = test_dataset_fit(test1_full)

# %%
RUL_real = pd.read_csv("RUL_FD001.txt",names=['RUL'])  # Replace "file.csv" with your actual file path

# # Extract the integers into a list
RUL_real = RUL_real.iloc[:, 0].tolist()  # Assuming the integers are in the first column
print(RUL_real)

res = [a - b for a, b in zip(RUL_real, test1_RUL_Predict)]

print(res)
# Out:
# [112, 98, 69, 82, 91, 93, 91, 95, 111, 96, 97, 124, 95, 107, 83, 84, 50, 28, 87, 16, 57, 111, 113, 20, 145, 119, 66, 97, 90, 115, 8, 48, 106, 7, 11, 19, 21, 50, 142, 28, 18, 10, 59, 109, 114, 47, 135, 92, 21, 79, 114, 29, 26, 97, 137, 15, 103, 37, 114, 100, 21, 54, 72, 28, 128, 14, 77, 8, 121, 94, 118, 50, 131, 126, 113, 10, 34, 107, 63, 90, 8, 9, 137, 58, 118, 89, 116, 115, 136, 28, 38, 20, 85, 55, 128, 137, 82, 59, 117, 20]
# [-16.421563127923037, -12.076786582558753, 6.71105412699044, -5.67458836399112, -10.194919461718868, -0.6547237321858717, -17.620667609434577, 18.976743515313444, 5.377242665244154, 21.681063562199043, -9.406419544256337, 34.268112729433554, 16.7520683499296, 3.7668146541850973, -56.320488989758644, -33.80172681628805, -14.474332773068355, -39.93978221461367, -19.282027382232712, 10.469653019292954, -29.14318117242577, -9.101167691058762, -8.069040849386298, -14.639316150877505, 9.55580875781257, -11.962082230301604, -32.58525629271986, -3.5453758367190744, 1.0127479294116881, 11.527734106453849, -0.2600346967239062, -30.301957286037535, 2.9822053326422235, -8.187828195971049, 0.8548255816781012, -21.402468104353446, -31.657123444242174, -9.207191921105562, -18.51438736408437, -29.22528149231764, -45.40990400583327, -10.807585260234386, -14.147058171929544, -1.863441521274666, 57.67987188151576, -8.687220344216058, 9.622312851314916, -17.972946659367054, 21.409384149184973, -37.77590061015782, 20.219632909177918, -15.074055605942199, -29.21676609800067, -24.914567129080268, 21.687710381559114, -17.36010029365101, 20.55157091595062, -6.561981675289722, -23.971641462285987, 7.817837730741587, -16.736735102201983, 5.4974513591235095, -19.223761087153562, -7.139955502289041, -26.704928817803733, -15.25034541784217, -58.49245010052624, -5.428834491204112, -18.704965038363866, -0.5482000572290815, 7.340291374128597, -44.2952720543376, 13.875796980244061, 32.04666086342087, 8.313989240639785, 5.38182233443286, -12.87475100060336, -59.44763287830034, -44.79102531306127, 4.82499789245044, 16.79974635121352, -3.385483162769548, 7.033397741834648, 1.507923826806639, -10.425155180985996, -9.089442495221633, -24.52922635810964, -8.681860375937404, 36.60752455395591, -3.6464293753610804, 20.51022629426888, -14.226349251696327, 62.280735859976424, -12.544197393290844, 8.004404749599459, 1.739705017155444, -21.424414597417567, -25.496849834373208, -0.21033633163762033, -4.030212812013925]

# %%
# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot the two lists against each other in the first subplot
axs[0].plot(RUL_real, label="RUL_real", marker='o')
axs[0].plot(test1_RUL_Predict, label="RUL_Predict", marker='x')
axs[0].set_title('Comparison of Two Lists')
axs[0].set_xlabel('Unit')
axs[0].set_ylabel('RUL')
axs[0].legend()

# Plot the difference in the second subplot
axs[1].plot(res, label="Difference (Real - Pred)", color='red', marker='s')
axs[1].axhline(0, color='blue', linestyle='--', label="x=0 Line,above is late pred, below is early")  # Add a horizontal line at x=0
axs[1].set_title('Difference Between the Lists')
axs[1].set_xlabel('Unit')
axs[1].set_ylabel('Difference')
axs[1].legend()

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
res_ratio = [(a - b)/((a+b)/2) for a, b in zip(RUL_real, test1_RUL_Predict)]
plt.figure(figsize=(8, 5))
plt.hist(res_ratio, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Residual = 0')  # Reference line at 0
plt.title('sMAPE Distribution')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
res= [a - b for a, b in zip(RUL_real, test1_RUL_Predict)]
plt.figure(figsize=(8, 5))
plt.hist(res, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Residual = 0')  # Reference line at 0
plt.title('residual Distribution')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
def test_dataset_fit_without_ep(test_data_frame):
    RUL_predictions = []

    for unit_number, group in test_data_frame.groupby("Unit_Number"):
        # Get test data for the current unit
        test_data = test_data_frame[test_data_frame["Unit_Number"] == unit_number]

        # Assign clusters to the last segment of the test data
        assigned_clusters = assign_last_segment_to_cluster(
            test_data=test_data,
            features=['Operational_Setting_1', 'Operational_Setting_2', 'Sensor_Measurement_11_stationary'],
            cluster_models=cluster_models,
            segments_mapping=segments_mapping
        )

        # Get predictions and weights from all relevant models
        weighted_prediction = calculate_weighted_prediction(test_data, assigned_clusters)
        
        RUL_predictions.append(weighted_prediction)

    return RUL_predictions
    
        
test1_RUL_Predict_2 = test_dataset_fit_without_ep(test1_full)

# %%
res_ratio2 = [(a - b)/((a+b)/2) for a, b in zip(RUL_real, test1_RUL_Predict_2)]

# %%
res_ratio2 = [float(x) for x in res_ratio2]  # Ensure it's a numeric 1D array

# Plot the histogram with adjustments
plt.figure(figsize=(8, 5))
plt.hist(res_ratio2, bins=50, range=(-1, 1), color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Residual = 0')  # Reference line at 0
plt.title('sMAPE Distribution')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# we'll keep the simple expensional in prediction for FD001

# %% [markdown]
# ## check each unit's prediction during its life time

# %%
def predict_unit_life(test_data_frame, unit_number, step=10):
    """
    Predict RUL for a specific unit every `step` data points.

    Args:
        test_data_frame (DataFrame): The dataset containing test data.
        unit_number (int): The unit number to process.
        step (int): The interval at which predictions are made.

    Returns:
        dict: Contains the unit number and its predictions.
    """
    # Filter data for the specified unit and sort by time
    unit_data = test_data_frame[test_data_frame["Unit_Number"] == unit_number].sort_values("Time_in_Cycles")
    predictions = []

    # Generate predictions at every `step`
    for i in range(0, len(unit_data), step):
        # Select the data range for prediction
        data_subset = unit_data.iloc[i:i + step]

        if len(data_subset) < step:  # Skip incomplete steps at the end
            continue

        # Predict RUL for the current subset
        assigned_clusters = assign_last_segment_to_cluster(
            test_data=data_subset,
            features=['Operational_Setting_1', 'Operational_Setting_2', 'Sensor_Measurement_11_stationary'],
            cluster_models=cluster_models,
            segments_mapping=segments_mapping
        )

        # Get raw prediction and convert to a numerical value
        prediction = calculate_weighted_prediction(data_subset, assigned_clusters)
        if isinstance(prediction, pd.Series):  # Extract value from Series if needed
            prediction = prediction.values[0]
        predictions.append({"index": i, "prediction": prediction})

    return {"unit_number": unit_number, "predictions": predictions}

# %%
#cherry pick
def calculate_slope_for_all_units(test_data_frame, step=10):
    """
    Loop through all units, calculate predictions, and compute the slope for each unit.

    Args:
        test_data_frame (DataFrame): The dataset containing test data.
        step (int): The interval at which predictions are made.

    Returns:
        list of dict: Each dict contains the unit number, predictions, and slope.
    """
    unit_slopes = []

    for unit_number in test_data_frame["Unit_Number"].unique():
        # Generate predictions for the unit
        unit_result = predict_unit_life(test_data_frame, unit_number, step)

        # Extract predictions and indices
        indices = [p["index"] for p in unit_result["predictions"]]
        values = [p["prediction"] for p in unit_result["predictions"]]

        # Ensure values are numerical
        values = [v for v in values if isinstance(v, (int, float))]

        # Calculate slope using linear regression
        if len(indices) > 1 and len(indices) == len(values):
            slope, _, _, _, _ = linregress(indices, values)
            unit_result["slope"] = slope
        else:
            unit_result["slope"] = None  # Handle cases where slope cannot be calculated

        unit_slopes.append(unit_result)

    return unit_slopes

# %%
unit_slopes = calculate_slope_for_all_units(test1_full, step=10)

# %%
closest_unit = None
min_diff = float("inf")

for unit in unit_slopes:
    if unit["slope"] is not None:
        diff = abs(unit["slope"] - (-1))
        if diff < min_diff:
            min_diff = diff
            closest_unit = unit

# %%
predictions = closest_unit["predictions"]
indices = [p["index"] for p in predictions]
values = [p["prediction"] for p in predictions]

plt.figure(figsize=(10, 6))
plt.plot(indices, values, marker="o", label="RUL Predictions")
plt.title(f"RUL Predictions for Unit {unit['unit_number']} (Slope: {unit['slope']:.2f})")
plt.xlabel("Index (10-Point Step)")
plt.ylabel("RUL Prediction")
plt.legend()
plt.grid()
plt.show()
