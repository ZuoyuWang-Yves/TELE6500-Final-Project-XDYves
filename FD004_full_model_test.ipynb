# %% [markdown]
# # FD002
#
# here we'll build the models for FD002, and test it.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import os

import plotly.express as px
from plotly.subplots import make_subplots


import warnings
# Ignore warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import ruptures as rpt
from scipy.interpolate import interp1d
from scipy.stats import linregress
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import statsmodels.api as sm
from tslearn.clustering import TimeSeriesKMeans
from tslearn.utils import to_time_series_dataset
from joblib import dump, load

# %% [markdown]
# Cause we're treating stationary data as time series, we'll have an un-clustered global linear regression after generating features with a size-20 rolling window.

# %% [markdown]
# ## generates  rolling window features

# %%
# train and test column names
column_names_first_5 = ['Unit_Number', 'Time_in_Cycles', 'Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']

remaining_column_names = [f'Sensor_Measurement_{i}' for i in range(1,22)]

column_names = column_names_first_5 + remaining_column_names

DF_train_FD004 = pd.read_csv("train_FD004.txt", delim_whitespace=True, names=column_names)

# %%
Max_Life_train_FD004 = DF_train_FD004.groupby('Unit_Number')['Time_in_Cycles'].max()
    
DF_train_FD004['Max_Life'] = DF_train_FD004['Unit_Number'].map(Max_Life_train_FD004)
DF_train_FD004['RUL'] = DF_train_FD004['Max_Life'] - DF_train_FD004['Time_in_Cycles']



# no exponential growth features


stationary_data = DF_train_FD004
stationary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unit_Number            61249 non-null  int64
#  1   Time_in_Cycles         61249 non-null  int64
#  2   Operational_Setting_1  61249 non-null  float64
#  3   Operational_Setting_2  61249 non-null  float64
#  4   Operational_Setting_3  61249 non-null  float64
#  5   Sensor_Measurement_1   61249 non-null  float64
#  6   Sensor_Measurement_2   61249 non-null  float64
#  7   Sensor_Measurement_3   61249 non-null  float64
#  8   Sensor_Measurement_4   61249 non-null  float64
#  9   Sensor_Measurement_5   61249 non-null  float64
#  10  Sensor_Measurement_6   61249 non-null  float64
#  11  Sensor_Measurement_7   61249 non-null  float64
#  12  Sensor_Measurement_8   61249 non-null  float64
#  13  Sensor_Measurement_9   61249 non-null  float64
#  14  Sensor_Measurement_10  61249 non-null  float64
#  15  Sensor_Measurement_11  61249 non-null  float64
#  16  Sensor_Measurement_12  61249 non-null  float64
#  17  Sensor_Measurement_13  61249 non-null  float64
#  18  Sensor_Measurement_14  61249 non-null  float64
#  19  Sensor_Measurement_15  61249 non-null  float64
#  20  Sensor_Measurement_16  61249 non-null  float64
#  21  Sensor_Measurement_17  61249 non-null  int64
#  22  Sensor_Measurement_18  61249 non-null  int64
#  23  Sensor_Measurement_19  61249 non-null  float64
#  24  Sensor_Measurement_20  61249 non-null  float64
#  25  Sensor_Measurement_21  61249 non-null  float64
#  26  Max_Life               61249 non-null  int64
#  27  RUL                    61249 non-null  int64
# dtypes: float64(22), int64(6)
# memory usage: 13.1 MB

# %%
features_draft = [col for col in stationary_data.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number']]

window_size = 20

# Create copies to store results
result_df = stationary_data.copy()

# Group the data by Unit_Number to calculate statistics separately for each unit
for feature in features_draft:
    if feature != "Time_in_Cycles":
        # Initialize empty lists to store the computed values
        means = []
        variances = []
        slopes = []

        # Process each unit separately
        for unit, group in stationary_data.groupby("Unit_Number"):
            group = group.sort_values("Time_in_Cycles")  # Ensure data is sorted by time

            # Initialize temporary lists for this feature and unit
            unit_means = []
            unit_variances = []
            unit_slopes = []

            # Iterate over rolling windows
            for i in range(len(group)):
                window = group.iloc[max(0, i - window_size + 1): i + 1]

                # Compute mean and variance
                unit_means.append(window[feature].mean())
                unit_variances.append(window[feature].var())

                # Compute slope if there's enough data
                if len(window) > 1:
                    slope, _, _, _, _ = linregress(window["Time_in_Cycles"], window[feature])
                    unit_slopes.append(slope)
                else:
                    unit_slopes.append(np.nan)

            # Append the computed results to the main lists
            means.extend(unit_means)
            variances.extend(unit_variances)
            slopes.extend(unit_slopes)

        # Add results to the DataFrame
        result_df[f"{feature}_mean"] = means
        result_df[f"{feature}_variance"] = variances
        result_df[f"{feature}_slope"] = slopes

# %%
print(result_df.info())
result_df.to_csv('data.csv', index=False)  # Saves to the current working directory
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 100 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unit_Number                     61249 non-null  int64
#  1   Time_in_Cycles                  61249 non-null  int64
#  2   Operational_Setting_1           61249 non-null  float64
#  3   Operational_Setting_2           61249 non-null  float64
#  4   Operational_Setting_3           61249 non-null  float64
#  5   Sensor_Measurement_1            61249 non-null  float64
#  6   Sensor_Measurement_2            61249 non-null  float64
#  7   Sensor_Measurement_3            61249 non-null  float64
#  8   Sensor_Measurement_4            61249 non-null  float64
#  9   Sensor_Measurement_5            61249 non-null  float64
#  10  Sensor_Measurement_6            61249 non-null  float64
#  11  Sensor_Measurement_7            61249 non-null  float64
#  12  Sensor_Measurement_8            61249 non-null  float64
#  13  Sensor_Measurement_9            61249 non-null  float64
#  14  Sensor_Measurement_10           61249 non-null  float64
#  15  Sensor_Measurement_11           61249 non-null  float64
#  16  Sensor_Measurement_12           61249 non-null  float64
#  17  Sensor_Measurement_13           61249 non-null  float64
#  18  Sensor_Measurement_14           61249 non-null  float64
#  19  Sensor_Measurement_15           61249 non-null  float64
#  20  Sensor_Measurement_16           61249 non-null  float64
#  21  Sensor_Measurement_17           61249 non-null  int64
#  22  Sensor_Measurement_18           61249 non-null  int64
#  23  Sensor_Measurement_19           61249 non-null  float64
#  24  Sensor_Measurement_20           61249 non-null  float64
#  25  Sensor_Measurement_21           61249 non-null  float64
#  26  Max_Life                        61249 non-null  int64
#  27  RUL                             61249 non-null  int64
#  28  Operational_Setting_1_mean      61249 non-null  float64
#  29  Operational_Setting_1_variance  61000 non-null  float64
#  30  Operational_Setting_1_slope     61000 non-null  float64
#  31  Operational_Setting_2_mean      61249 non-null  float64
#  32  Operational_Setting_2_variance  61000 non-null  float64
#  33  Operational_Setting_2_slope     61000 non-null  float64
#  34  Operational_Setting_3_mean      61249 non-null  float64
#  35  Operational_Setting_3_variance  61000 non-null  float64
#  36  Operational_Setting_3_slope     61000 non-null  float64
#  37  Sensor_Measurement_1_mean       61249 non-null  float64
#  38  Sensor_Measurement_1_variance   61000 non-null  float64
#  39  Sensor_Measurement_1_slope      61000 non-null  float64
#  40  Sensor_Measurement_2_mean       61249 non-null  float64
#  41  Sensor_Measurement_2_variance   61000 non-null  float64
#  42  Sensor_Measurement_2_slope      61000 non-null  float64
#  43  Sensor_Measurement_3_mean       61249 non-null  float64
#  44  Sensor_Measurement_3_variance   61000 non-null  float64
#  45  Sensor_Measurement_3_slope      61000 non-null  float64
#  46  Sensor_Measurement_4_mean       61249 non-null  float64
#  47  Sensor_Measurement_4_variance   61000 non-null  float64
#  48  Sensor_Measurement_4_slope      61000 non-null  float64
#  49  Sensor_Measurement_5_mean       61249 non-null  float64
#  50  Sensor_Measurement_5_variance   61000 non-null  float64
#  51  Sensor_Measurement_5_slope      61000 non-null  float64
#  52  Sensor_Measurement_6_mean       61249 non-null  float64
#  53  Sensor_Measurement_6_variance   61000 non-null  float64
#  54  Sensor_Measurement_6_slope      61000 non-null  float64
#  55  Sensor_Measurement_7_mean       61249 non-null  float64
#  56  Sensor_Measurement_7_variance   61000 non-null  float64
#  57  Sensor_Measurement_7_slope      61000 non-null  float64
#  58  Sensor_Measurement_8_mean       61249 non-null  float64
#  59  Sensor_Measurement_8_variance   61000 non-null  float64
#  60  Sensor_Measurement_8_slope      61000 non-null  float64
#  61  Sensor_Measurement_9_mean       61249 non-null  float64
#  62  Sensor_Measurement_9_variance   61000 non-null  float64
#  63  Sensor_Measurement_9_slope      61000 non-null  float64
#  64  Sensor_Measurement_10_mean      61249 non-null  float64
#  65  Sensor_Measurement_10_variance  61000 non-null  float64
#  66  Sensor_Measurement_10_slope     61000 non-null  float64
#  67  Sensor_Measurement_11_mean      61249 non-null  float64
#  68  Sensor_Measurement_11_variance  61000 non-null  float64
#  69  Sensor_Measurement_11_slope     61000 non-null  float64
#  70  Sensor_Measurement_12_mean      61249 non-null  float64
#  71  Sensor_Measurement_12_variance  61000 non-null  float64
#  72  Sensor_Measurement_12_slope     61000 non-null  float64
#  73  Sensor_Measurement_13_mean      61249 non-null  float64
#  74  Sensor_Measurement_13_variance  61000 non-null  float64
#  75  Sensor_Measurement_13_slope     61000 non-null  float64
#  76  Sensor_Measurement_14_mean      61249 non-null  float64
#  77  Sensor_Measurement_14_variance  61000 non-null  float64
#  78  Sensor_Measurement_14_slope     61000 non-null  float64
#  79  Sensor_Measurement_15_mean      61249 non-null  float64
#  80  Sensor_Measurement_15_variance  61000 non-null  float64
#  81  Sensor_Measurement_15_slope     61000 non-null  float64
#  82  Sensor_Measurement_16_mean      61249 non-null  float64
#  83  Sensor_Measurement_16_variance  61000 non-null  float64
#  84  Sensor_Measurement_16_slope     61000 non-null  float64
#  85  Sensor_Measurement_17_mean      61249 non-null  float64
#  86  Sensor_Measurement_17_variance  61000 non-null  float64
#  87  Sensor_Measurement_17_slope     61000 non-null  float64
#  88  Sensor_Measurement_18_mean      61249 non-null  float64
#  89  Sensor_Measurement_18_variance  61000 non-null  float64
#  90  Sensor_Measurement_18_slope     61000 non-null  float64
#  91  Sensor_Measurement_19_mean      61249 non-null  float64
#  92  Sensor_Measurement_19_variance  61000 non-null  float64
#  93  Sensor_Measurement_19_slope     61000 non-null  float64
#  94  Sensor_Measurement_20_mean      61249 non-null  float64
#  95  Sensor_Measurement_20_variance  61000 non-null  float64
#  96  Sensor_Measurement_20_slope     61000 non-null  float64
#  97  Sensor_Measurement_21_mean      61249 non-null  float64
#  98  Sensor_Measurement_21_variance  61000 non-null  float64
#  99  Sensor_Measurement_21_slope     61000 non-null  float64
# dtypes: float64(94), int64(6)
# memory usage: 46.7 MB
# None

# %% [markdown]
# ## generates un-clustered global linear regression

# %%
features_draft = [col for col in result_df.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number']]

result_df = result_df.fillna(0)

# Ensure this loop will refine features_draft until all p-values < 0.05
while True:
    
    # Prepare the features (X) and target (y)
    X = result_df[features_draft]
    y = result_df['RUL']
    
    # Add a constant to the features for the intercept
    X_train_with_const = sm.add_constant(X)
    
    # Fit the linear model
    linear_model2 = sm.OLS(y, X_train_with_const)
    linear_model_fit2 = linear_model2.fit()
    
    # Get p-values and coef
    p_values = linear_model_fit2.pvalues
    params = linear_model_fit2.params
    
    
    # Identify features with p-values > 0.05 or coef == 0
    insignificant_features = params[params == 0].index.tolist()
    insignificant_features = insignificant_features + p_values[p_values > 0.05].index.tolist()
    
    # Exclude 'const' from insignificant features if present
    insignificant_features = [col for col in insignificant_features if col != 'const']
    
    # Break the loop if there are no insignificant features
    if not insignificant_features:
        break
    
    # Update features_draft by removing insignificant features
    features_draft = [col for col in features_draft if col not in insignificant_features]
    

print(linear_model_fit2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.632
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     2059.
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:32:15   Log-Likelihood:            -3.3177e+05
# No. Observations:               61249   AIC:                         6.636e+05
# Df Residuals:                   61197   BIC:                         6.641e+05
# Df Model:                          51
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            502.0092    633.639      0.792      0.428    -739.925    1743.943
# Time_in_Cycles                    -0.3819      0.003   -110.267      0.000      -0.389      -0.375
# Sensor_Measurement_2               1.1943      0.205      5.840      0.000       0.793       1.595
# Sensor_Measurement_3              -0.1262      0.053     -2.386      0.017      -0.230      -0.023
# Sensor_Measurement_4              -0.2649      0.044     -6.068      0.000      -0.351      -0.179
# Sensor_Measurement_10             84.2455     14.651      5.750      0.000      55.529     112.962
# Sensor_Measurement_14              0.1121      0.023      4.911      0.000       0.067       0.157
# Sensor_Measurement_17             -0.5855      0.229     -2.562      0.010      -1.034      -0.138
# Operational_Setting_1_slope     -773.6390     35.948    -21.521      0.000    -844.096    -703.182
# Operational_Setting_2_variance  -440.9590     83.227     -5.298      0.000    -604.084    -277.834
# Operational_Setting_3_variance   -14.5048      4.841     -2.996      0.003     -23.994      -5.016
# Operational_Setting_3_slope     1.764e+04    704.510     25.038      0.000    1.63e+04     1.9e+04
# Sensor_Measurement_1_slope      5429.4396    231.151     23.489      0.000    4976.383    5882.496
# Sensor_Measurement_2_slope       -35.7925      6.108     -5.860      0.000     -47.763     -23.822
# Sensor_Measurement_3_slope        -3.6315      0.510     -7.121      0.000      -4.631      -2.632
# Sensor_Measurement_4_mean         -2.6289      0.194    -13.531      0.000      -3.010      -2.248
# Sensor_Measurement_4_variance      0.0023      0.001      2.801      0.005       0.001       0.004
# Sensor_Measurement_4_slope        -1.7703      0.489     -3.618      0.000      -2.729      -0.811
# Sensor_Measurement_5_slope     -2639.4888    160.150    -16.481      0.000   -2953.383   -2325.595
# Sensor_Measurement_7_variance      0.0595      0.006     10.081      0.000       0.048       0.071
# Sensor_Measurement_8_mean         13.4976      0.632     21.369      0.000      12.260      14.736
# Sensor_Measurement_8_variance     -0.3179      0.046     -6.869      0.000      -0.409      -0.227
# Sensor_Measurement_9_mean         -1.7892      0.174    -10.311      0.000      -2.129      -1.449
# Sensor_Measurement_9_variance     -0.0022      0.000    -12.116      0.000      -0.003      -0.002
# Sensor_Measurement_9_slope        -6.4004      0.467    -13.720      0.000      -7.315      -5.486
# Sensor_Measurement_10_mean       746.8766     89.030      8.389      0.000     572.378     921.376
# Sensor_Measurement_10_variance  3066.4251    612.801      5.004      0.000    1865.334    4267.516
# Sensor_Measurement_10_slope    -6801.8343    773.458     -8.794      0.000   -8317.815   -5285.854
# Sensor_Measurement_11_mean       -55.3749      6.055     -9.145      0.000     -67.244     -43.506
# Sensor_Measurement_11_variance     6.3603      1.148      5.541      0.000       4.111       8.610
# Sensor_Measurement_11_slope     -304.2171     18.512    -16.434      0.000    -340.500    -267.934
# Sensor_Measurement_12_variance    -0.0448      0.007     -6.778      0.000      -0.058      -0.032
# Sensor_Measurement_12_slope      -26.7628      3.841     -6.968      0.000     -34.291     -19.234
# Sensor_Measurement_13_mean        -9.0688      0.493    -18.382      0.000     -10.036      -8.102
# Sensor_Measurement_13_variance     0.1763      0.060      2.948      0.003       0.059       0.293
# Sensor_Measurement_13_slope     -157.9507     20.722     -7.622      0.000    -198.567    -117.335
# Sensor_Measurement_14_mean         1.6071      0.187      8.577      0.000       1.240       1.974
# Sensor_Measurement_14_slope       -5.7175      0.566    -10.103      0.000      -6.827      -4.608
# Sensor_Measurement_15_mean       -50.5500     12.104     -4.176      0.000     -74.274     -26.826
# Sensor_Measurement_15_variance   -70.9406     17.848     -3.975      0.000    -105.922     -35.959
# Sensor_Measurement_16_mean      1.659e+04    823.819     20.135      0.000     1.5e+04    1.82e+04
# Sensor_Measurement_16_variance -7.733e+05   1.94e+05     -3.981      0.000   -1.15e+06   -3.93e+05
# Sensor_Measurement_16_slope    -9646.8015   3259.558     -2.960      0.003    -1.6e+04   -3258.059
# Sensor_Measurement_17_mean        -8.9702      0.897    -10.003      0.000     -10.728      -7.213
# Sensor_Measurement_17_variance    -0.0840      0.016     -5.273      0.000      -0.115      -0.053
# Sensor_Measurement_17_slope      -11.9724      2.006     -5.969      0.000     -15.904      -8.041
# Sensor_Measurement_18_variance     0.3239      0.046      7.010      0.000       0.233       0.414
# Sensor_Measurement_18_slope    -2164.8553     94.541    -22.898      0.000   -2350.157   -1979.554
# Sensor_Measurement_19_slope     6645.4872    265.424     25.037      0.000    6125.255    7165.720
# Sensor_Measurement_20_variance     1.4186      0.372      3.811      0.000       0.689       2.148
# Sensor_Measurement_20_slope      -54.5070     19.882     -2.742      0.006     -93.475     -15.539
# Sensor_Measurement_21_variance   -11.3369      1.037    -10.936      0.000     -13.369      -9.305
# Sensor_Measurement_21_slope      171.3314     31.774      5.392      0.000     109.054     233.609
# ==============================================================================
# Omnibus:                     9055.144   Durbin-Watson:                   0.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19016.478
# Skew:                           0.897   Prob(JB):                         0.00
# Kurtosis:                       5.058   Cond. No.                     1.03e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.26e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Save the model and preprocessed data
dump((linear_model_fit2, X_train_with_const.columns), "FD004unclustered_regression_model_and_columns.joblib")
# Out:
# ['FD004unclustered_regression_model_and_columns.joblib']

# %%
print(result_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 100 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unit_Number                     61249 non-null  int64
#  1   Time_in_Cycles                  61249 non-null  int64
#  2   Operational_Setting_1           61249 non-null  float64
#  3   Operational_Setting_2           61249 non-null  float64
#  4   Operational_Setting_3           61249 non-null  float64
#  5   Sensor_Measurement_1            61249 non-null  float64
#  6   Sensor_Measurement_2            61249 non-null  float64
#  7   Sensor_Measurement_3            61249 non-null  float64
#  8   Sensor_Measurement_4            61249 non-null  float64
#  9   Sensor_Measurement_5            61249 non-null  float64
#  10  Sensor_Measurement_6            61249 non-null  float64
#  11  Sensor_Measurement_7            61249 non-null  float64
#  12  Sensor_Measurement_8            61249 non-null  float64
#  13  Sensor_Measurement_9            61249 non-null  float64
#  14  Sensor_Measurement_10           61249 non-null  float64
#  15  Sensor_Measurement_11           61249 non-null  float64
#  16  Sensor_Measurement_12           61249 non-null  float64
#  17  Sensor_Measurement_13           61249 non-null  float64
#  18  Sensor_Measurement_14           61249 non-null  float64
#  19  Sensor_Measurement_15           61249 non-null  float64
#  20  Sensor_Measurement_16           61249 non-null  float64
#  21  Sensor_Measurement_17           61249 non-null  int64
#  22  Sensor_Measurement_18           61249 non-null  int64
#  23  Sensor_Measurement_19           61249 non-null  float64
#  24  Sensor_Measurement_20           61249 non-null  float64
#  25  Sensor_Measurement_21           61249 non-null  float64
#  26  Max_Life                        61249 non-null  int64
#  27  RUL                             61249 non-null  int64
#  28  Operational_Setting_1_mean      61249 non-null  float64
#  29  Operational_Setting_1_variance  61249 non-null  float64
#  30  Operational_Setting_1_slope     61249 non-null  float64
#  31  Operational_Setting_2_mean      61249 non-null  float64
#  32  Operational_Setting_2_variance  61249 non-null  float64
#  33  Operational_Setting_2_slope     61249 non-null  float64
#  34  Operational_Setting_3_mean      61249 non-null  float64
#  35  Operational_Setting_3_variance  61249 non-null  float64
#  36  Operational_Setting_3_slope     61249 non-null  float64
#  37  Sensor_Measurement_1_mean       61249 non-null  float64
#  38  Sensor_Measurement_1_variance   61249 non-null  float64
#  39  Sensor_Measurement_1_slope      61249 non-null  float64
#  40  Sensor_Measurement_2_mean       61249 non-null  float64
#  41  Sensor_Measurement_2_variance   61249 non-null  float64
#  42  Sensor_Measurement_2_slope      61249 non-null  float64
#  43  Sensor_Measurement_3_mean       61249 non-null  float64
#  44  Sensor_Measurement_3_variance   61249 non-null  float64
#  45  Sensor_Measurement_3_slope      61249 non-null  float64
#  46  Sensor_Measurement_4_mean       61249 non-null  float64
#  47  Sensor_Measurement_4_variance   61249 non-null  float64
#  48  Sensor_Measurement_4_slope      61249 non-null  float64
#  49  Sensor_Measurement_5_mean       61249 non-null  float64
#  50  Sensor_Measurement_5_variance   61249 non-null  float64
#  51  Sensor_Measurement_5_slope      61249 non-null  float64
#  52  Sensor_Measurement_6_mean       61249 non-null  float64
#  53  Sensor_Measurement_6_variance   61249 non-null  float64
#  54  Sensor_Measurement_6_slope      61249 non-null  float64
#  55  Sensor_Measurement_7_mean       61249 non-null  float64
#  56  Sensor_Measurement_7_variance   61249 non-null  float64
#  57  Sensor_Measurement_7_slope      61249 non-null  float64
#  58  Sensor_Measurement_8_mean       61249 non-null  float64
#  59  Sensor_Measurement_8_variance   61249 non-null  float64
#  60  Sensor_Measurement_8_slope      61249 non-null  float64
#  61  Sensor_Measurement_9_mean       61249 non-null  float64
#  62  Sensor_Measurement_9_variance   61249 non-null  float64
#  63  Sensor_Measurement_9_slope      61249 non-null  float64
#  64  Sensor_Measurement_10_mean      61249 non-null  float64
#  65  Sensor_Measurement_10_variance  61249 non-null  float64
#  66  Sensor_Measurement_10_slope     61249 non-null  float64
#  67  Sensor_Measurement_11_mean      61249 non-null  float64
#  68  Sensor_Measurement_11_variance  61249 non-null  float64
#  69  Sensor_Measurement_11_slope     61249 non-null  float64
#  70  Sensor_Measurement_12_mean      61249 non-null  float64
#  71  Sensor_Measurement_12_variance  61249 non-null  float64
#  72  Sensor_Measurement_12_slope     61249 non-null  float64
#  73  Sensor_Measurement_13_mean      61249 non-null  float64
#  74  Sensor_Measurement_13_variance  61249 non-null  float64
#  75  Sensor_Measurement_13_slope     61249 non-null  float64
#  76  Sensor_Measurement_14_mean      61249 non-null  float64
#  77  Sensor_Measurement_14_variance  61249 non-null  float64
#  78  Sensor_Measurement_14_slope     61249 non-null  float64
#  79  Sensor_Measurement_15_mean      61249 non-null  float64
#  80  Sensor_Measurement_15_variance  61249 non-null  float64
#  81  Sensor_Measurement_15_slope     61249 non-null  float64
#  82  Sensor_Measurement_16_mean      61249 non-null  float64
#  83  Sensor_Measurement_16_variance  61249 non-null  float64
#  84  Sensor_Measurement_16_slope     61249 non-null  float64
#  85  Sensor_Measurement_17_mean      61249 non-null  float64
#  86  Sensor_Measurement_17_variance  61249 non-null  float64
#  87  Sensor_Measurement_17_slope     61249 non-null  float64
#  88  Sensor_Measurement_18_mean      61249 non-null  float64
#  89  Sensor_Measurement_18_variance  61249 non-null  float64
#  90  Sensor_Measurement_18_slope     61249 non-null  float64
#  91  Sensor_Measurement_19_mean      61249 non-null  float64
#  92  Sensor_Measurement_19_variance  61249 non-null  float64
#  93  Sensor_Measurement_19_slope     61249 non-null  float64
#  94  Sensor_Measurement_20_mean      61249 non-null  float64
#  95  Sensor_Measurement_20_variance  61249 non-null  float64
#  96  Sensor_Measurement_20_slope     61249 non-null  float64
#  97  Sensor_Measurement_21_mean      61249 non-null  float64
#  98  Sensor_Measurement_21_variance  61249 non-null  float64
#  99  Sensor_Measurement_21_slope     61249 non-null  float64
# dtypes: float64(94), int64(6)
# memory usage: 46.7 MB
# None

# %% [markdown]
# ## clustering

# %%
def normalize_segment_length(segment, length=100):
    if len(segment) == 0:  # Handle empty segments
        return np.zeros(length)
    x = np.linspace(0, 1, len(segment))
    f = interp1d(x, segment, kind='linear', fill_value="extrapolate")
    x_new = np.linspace(0, 1, length)
    return f(x_new)

# Initialize storage for normalized segments and mappings
normalized_segments = {}
segments_mapping = {}

# Features to segment and cluster
features = ['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']


# Loop through each feature
for feature in features:
    normalized_segments[feature] = []
    segments_mapping[feature] = []
    
    # Segment time series for each unit
    for unit in stationary_data['Unit_Number'].unique():
        # Extract unit data
        unit_data = stationary_data[stationary_data['Unit_Number'] == unit]
        
        # Scale the feature values
        scaler = StandardScaler()
        scaled_data = scaler.fit_transform(unit_data[feature].values.reshape(-1, 1)).flatten()
        
        # Detect change points using Ruptures
        model = rpt.Pelt(model="l2").fit(scaled_data)
        change_points = model.predict(pen=10)  # Adjust `pen` for granularity
        
        # Normalize each segment and store mapping information
        for start, end in zip([0] + change_points[:-1], change_points):
            segment = scaled_data[start:end]
            normalized_segment = normalize_segment_length(segment, length=100)
            
            normalized_segments[feature].append(normalized_segment)
            segments_mapping[feature].append({
                "unit_number": unit,
                "start_idx": start,
                "end_idx": end
            })

# %%
cluster_labels = {}
cluster_models = {}
k = 3  # Number of clusters (adjust as needed)

for feature, segments in normalized_segments.items():
    # Convert normalized segments to time-series dataset
    ts_data = to_time_series_dataset(segments)
    
    # Perform DTW clustering
    model = TimeSeriesKMeans(n_clusters=k, metric="dtw", random_state=42)
    labels = model.fit_predict(ts_data)
    
    # Store cluster labels and the trained model
    cluster_labels[feature] = labels
    cluster_models[feature] = model

# %%
for feature, model in cluster_models.items():
    plt.figure(figsize=(10, 6))
    for i, centroid in enumerate(model.cluster_centers_):
        plt.plot(centroid.ravel(), label=f"Cluster {i}")
    plt.title(f"Cluster Centroids for {feature}")
    plt.legend()
    plt.show()

# %%
for feature, labels in cluster_labels.items():
    # Count the number of segments in each cluster
    unique, counts = np.unique(labels, return_counts=True)
    cluster_sizes = dict(zip(unique, counts))
    
    plt.figure(figsize=(4, 3))
    plt.bar(unique, counts, tick_label=[f"Cluster {i}" for i in unique])
    plt.title(f"Cluster Sizes for {feature}")
    plt.xlabel("Cluster")
    plt.ylabel("Number of Segments")
    plt.show()
    
    # Print the cluster sizes
    print(f"Cluster sizes for {feature}:")
    for cluster, size in cluster_sizes.items():
        print(f"  Cluster {cluster}: {size} segments")
# Out:
# Cluster sizes for Operational_Setting_1:
#   Cluster 0: 74 segments
#   Cluster 1: 88 segments
#   Cluster 2: 91 segments
# Cluster sizes for Operational_Setting_2:
#   Cluster 0: 185 segments
#   Cluster 1: 66 segments
#   Cluster 2: 5 segments
# Cluster sizes for Operational_Setting_3:
#   Cluster 0: 55 segments
#   Cluster 1: 11 segments
#   Cluster 2: 216 segments

# %%
model_save_path = "clustering_models"

# Save each clustering model in the cluster_models dictionary
for feature, model in cluster_models.items():
    model_filename = f"{model_save_path}/FD004{feature}_clustering_model.pkl"
    dump(model, model_filename)
    
# # Load the saved clustering models
# loaded_cluster_models = {}

# for feature in normalized_segments.keys():
#     model_filename = f"{model_save_path}/{feature}_clustering_model.pkl"
#     loaded_cluster_models[feature] = joblib.load(model_filename)

# %% [markdown]
# ## linear regression for each cluster

# %%
# Create a mapping of cluster assignments to original rows
cluster_to_original_rows = {}

for feature, labels in cluster_labels.items():
    cluster_to_original_rows[feature] = []
    for i, label in enumerate(labels):
        metadata = segments_mapping[feature][i]
        unit_number = metadata["unit_number"]
        start_idx = metadata["start_idx"]
        end_idx = metadata["end_idx"]
        
        # Map each original row in the segment to the cluster
        cluster_to_original_rows[feature].append({
            "unit_number": unit_number,
            "start_idx": start_idx,
            "end_idx": end_idx,
            "cluster": label
        })

# %%
def get_windowdf_rows_by_cluster(feature, cluster_id):
    original_rows = []
    for mapping in cluster_to_original_rows[feature]:
        if mapping["cluster"] == cluster_id:
            unit = mapping["unit_number"]
            start, end = mapping["start_idx"], mapping["end_idx"]
            
            # Retrieve the original rows for the segment
            rows = result_df[
                (result_df["Unit_Number"] == unit) &
                (result_df["Time_in_Cycles"] >= start) &
                (result_df["Time_in_Cycles"] < end)
            ]
            original_rows.append(rows)
    
    return pd.concat(original_rows)

# %%
print(features)
# Out:
# ['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']

# %%
level2_models = {}

for cluster_feature in features:
    for cluster_number_id in range(3):
        
        cluster_rows = get_windowdf_rows_by_cluster(cluster_feature, cluster_number_id)

        features_draft = [col for col in cluster_rows.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number','Time_in_Cycles_mean','Time_in_Cycles_variance','Time_in_Cycles_slope']]

        cluster_rows = cluster_rows.fillna(0)

        X = cluster_rows[features_draft]
        y = cluster_rows['RUL']
        X_train_with_const = sm.add_constant(X)


        linear_model = sm.OLS(y, X_train_with_const)
        linear_model_fit = linear_model.fit()

        # Get the p-values from the fitted model
        p_values = linear_model_fit.pvalues

        # Filter for columns with p-value > 0.05
        insignificant_features = p_values[p_values > 0.05].index.tolist()

        features_draft = [col for col in features_draft if col not in insignificant_features]

        t_stats = linear_model_fit.tvalues

        # Sort the t-statistics by absolute value
        sorted_features_by_tstat = t_stats.abs().sort_values(ascending=False)

        filtered_t_stats = {key: value for key, value in t_stats.items() if key in features_draft}
        t_stats_df = pd.DataFrame(list(filtered_t_stats.items()), columns=["Feature", "T_Value"])

        # Identify sensor-stationary pairs
        sensor_pairs = []
        for feature in t_stats_df['Feature']:
            if "_stationary" in feature:
                original = feature.replace("_stationary", "")
                if original in t_stats_df['Feature'].values:
                    sensor_pairs.append((original, feature))


        kept_features = []

        for original, stationary in sensor_pairs:
            t_original = t_stats_df.loc[t_stats_df['Feature'] == original, 'T_Value'].values[0]
            t_stationary = t_stats_df.loc[t_stats_df['Feature'] == stationary, 'T_Value'].values[0]
            if abs(t_stationary) > abs(t_original):
                if original in features_draft: 
                    features_draft.remove(original)
            else:
                if stationary in features_draft: features_draft.remove(stationary)

        # Ensure this loop will refine features_draft until all p-values < 0.05
        while True:

            # Prepare the features (X) and target (y)
            X = cluster_rows[features_draft]
            y = cluster_rows['RUL']
            X_train_with_const = sm.add_constant(X)

            # Fit the linear model
            linear_model2 = sm.OLS(y, X_train_with_const)
            linear_model_fit2 = linear_model2.fit()

            # Get p-values
            p_values = linear_model_fit2.pvalues

            # Identify features with p-values > 0.05
            insignificant_features = p_values[p_values > 0.05].index.tolist()

            # Exclude 'const' from insignificant features if present
            insignificant_features = [col for col in insignificant_features if col != 'const']

            # Break the loop if there are no insignificant features
            if not insignificant_features:
                break

            # Update features_draft by removing insignificant features
            features_draft = [col for col in features_draft if col not in insignificant_features]

        level2_models[f'{cluster_feature},{cluster_number_id}'] = (linear_model_fit2,linear_model_fit2.summary())
        dump((linear_model_fit2, X_train_with_const.columns), f"FD004{cluster_feature}_c{cluster_number_id}_model_and_columns.joblib")
# Out:
# C:\Users\18065\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Users\18065\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)

# %%
print(level2_models)
# Out:
# {'Operational_Setting_1,0': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B38323A4C0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     856.3
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:37:25   Log-Likelihood:                -92589.
# No. Observations:               17191   AIC:                         1.853e+05
# Df Residuals:                   17152   BIC:                         1.856e+05
# Df Model:                          38
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             91.7174     14.878      6.165      0.000      62.555     120.880
# Time_in_Cycles                    -0.3804      0.006    -64.566      0.000      -0.392      -0.369
# Operational_Setting_1_mean      -154.6933     12.975    -11.922      0.000    -180.126    -129.261
# Operational_Setting_2_slope    -5203.0387    400.831    -12.981      0.000   -5988.709   -4417.368
# Operational_Setting_3_mean      2822.0708    211.911     13.317      0.000    2406.704    3237.438
# Sensor_Measurement_1_mean       1014.5223     77.096     13.159      0.000     863.406    1165.638
# Sensor_Measurement_2_variance      0.0866      0.028      3.041      0.002       0.031       0.142
# Sensor_Measurement_3_variance     -0.0074      0.002     -3.956      0.000      -0.011      -0.004
# Sensor_Measurement_4_mean         -3.2416      0.347     -9.340      0.000      -3.922      -2.561
# Sensor_Measurement_4_variance      0.0042      0.002      2.683      0.007       0.001       0.007
# Sensor_Measurement_4_slope        -2.6291      0.748     -3.515      0.000      -4.095      -1.163
# Sensor_Measurement_5_mean       -709.0468     55.534    -12.768      0.000    -817.899    -600.195
# Sensor_Measurement_6_variance     -7.3949      2.069     -3.573      0.000     -11.451      -3.339
# Sensor_Measurement_7_variance      0.0149      0.004      3.935      0.000       0.007       0.022
# Sensor_Measurement_8_mean        253.0399     40.908      6.186      0.000     172.857     333.223
# Sensor_Measurement_8_variance      0.3638      0.062      5.897      0.000       0.243       0.485
# Sensor_Measurement_8_slope        16.2350      1.151     14.102      0.000      13.978      18.492
# Sensor_Measurement_9_variance     -0.0027      0.000     -5.927      0.000      -0.004      -0.002
# Sensor_Measurement_10_mean     -2420.7217    311.674     -7.767      0.000   -3031.635   -1809.809
# Sensor_Measurement_10_variance  2396.8405    816.202      2.937      0.003     797.001    3996.681
# Sensor_Measurement_10_slope    -3395.6238    752.435     -4.513      0.000   -4870.473   -1920.775
# Sensor_Measurement_11_mean       -78.2260     11.270     -6.941      0.000    -100.315     -56.137
# Sensor_Measurement_11_variance     6.3304      2.175      2.910      0.004       2.066      10.595
# Sensor_Measurement_11_slope     -337.7988     34.761     -9.718      0.000    -405.934    -269.663
# Sensor_Measurement_12_slope      -20.5429      2.726     -7.536      0.000     -25.886     -15.199
# Sensor_Measurement_13_mean      -211.6351     39.387     -5.373      0.000    -288.838    -134.432
# Sensor_Measurement_14_mean         1.0289      0.227      4.533      0.000       0.584       1.474
# Sensor_Measurement_14_variance     0.0081      0.002      4.782      0.000       0.005       0.011
# Sensor_Measurement_14_slope       -6.8602      0.793     -8.646      0.000      -8.415      -5.305
# Sensor_Measurement_15_variance  -196.3806     33.202     -5.915      0.000    -261.460    -131.301
# Sensor_Measurement_16_mean      1.616e+04   1205.038     13.407      0.000    1.38e+04    1.85e+04
# Sensor_Measurement_16_slope    -1.982e+04   7493.737     -2.644      0.008   -3.45e+04   -5126.516
# Sensor_Measurement_17_mean       -16.6693      1.646    -10.125      0.000     -19.896     -13.442
# Sensor_Measurement_17_variance     0.1460      0.029      5.009      0.000       0.089       0.203
# Sensor_Measurement_18_mean      -655.6530     51.255    -12.792      0.000    -756.118    -555.188
# Sensor_Measurement_18_variance    -0.3614      0.061     -5.879      0.000      -0.482      -0.241
# Sensor_Measurement_19_mean      6779.5046    926.906      7.314      0.000    4962.675    8596.335
# Sensor_Measurement_20_variance     2.8050      0.694      4.040      0.000       1.444       4.166
# Sensor_Measurement_21_variance   -10.7603      1.951     -5.514      0.000     -14.585      -6.935
# Sensor_Measurement_21_slope      288.2300     54.531      5.286      0.000     181.344     395.116
# ==============================================================================
# Omnibus:                     1859.790   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2749.081
# Skew:                           0.818   Prob(JB):                         0.00
# Kurtosis:                       4.078   Cond. No.                     1.33e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.52e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_1,1': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B38325B610>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.678
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     1213.
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:37:26   Log-Likelihood:            -1.1318e+05
# No. Observations:               21361   AIC:                         2.264e+05
# Df Residuals:                   21323   BIC:                         2.267e+05
# Df Model:                          37
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              4.5636     23.125      0.197      0.844     -40.763      49.890
# Time_in_Cycles                    -0.3459      0.006    -54.538      0.000      -0.358      -0.334
# Operational_Setting_1_mean      -803.0115    196.533     -4.086      0.000   -1188.231    -417.792
# Operational_Setting_2_mean      9122.8380   1967.855      4.636      0.000    5265.694     1.3e+04
# Operational_Setting_2_variance  -339.9092     95.641     -3.554      0.000    -527.374    -152.445
# Operational_Setting_3_mean      1.662e+04   3868.349      4.297      0.000    9041.462    2.42e+04
# Operational_Setting_3_variance   -48.1040      7.470     -6.440      0.000     -62.745     -33.463
# Sensor_Measurement_1_mean       6035.2859   1399.741      4.312      0.000    3291.688    8778.884
# Sensor_Measurement_1_variance     -0.0418      0.020     -2.094      0.036      -0.081      -0.003
# Sensor_Measurement_3_slope        -5.1804      0.731     -7.091      0.000      -6.612      -3.748
# Sensor_Measurement_4_mean         -2.3018      0.291     -7.897      0.000      -2.873      -1.730
# Sensor_Measurement_4_variance      0.0079      0.001      6.212      0.000       0.005       0.010
# Sensor_Measurement_5_mean      -4514.8015    816.345     -5.531      0.000   -6114.899   -2914.704
# Sensor_Measurement_6_mean        588.2110     44.977     13.078      0.000     500.053     676.369
# Sensor_Measurement_7_variance      0.0329      0.009      3.845      0.000       0.016       0.050
# Sensor_Measurement_7_slope         0.8738      0.206      4.248      0.000       0.471       1.277
# Sensor_Measurement_8_mean       -359.7387     33.796    -10.645      0.000    -425.981    -293.497
# Sensor_Measurement_8_variance     -1.2186      0.079    -15.329      0.000      -1.374      -1.063
# Sensor_Measurement_8_slope        14.6482      1.571      9.327      0.000      11.570      17.727
# Sensor_Measurement_9_mean         -1.2545      0.276     -4.538      0.000      -1.796      -0.713
# Sensor_Measurement_9_slope        -2.9742      0.429     -6.939      0.000      -3.814      -2.134
# Sensor_Measurement_10_mean      2588.2218    297.537      8.699      0.000    2005.026    3171.417
# Sensor_Measurement_10_slope     2471.0502    409.755      6.031      0.000    1667.901    3274.200
# Sensor_Measurement_11_mean       -60.9308      9.610     -6.341      0.000     -79.766     -42.095
# Sensor_Measurement_11_variance    20.0690      1.753     11.447      0.000      16.633      23.506
# Sensor_Measurement_12_variance    -0.0351      0.010     -3.628      0.000      -0.054      -0.016
# Sensor_Measurement_13_mean       204.0540     31.783      6.420      0.000     141.757     266.351
# Sensor_Measurement_13_variance     0.6106      0.094      6.489      0.000       0.426       0.795
# Sensor_Measurement_13_slope       -8.6891      0.973     -8.930      0.000     -10.596      -6.782
# Sensor_Measurement_14_mean         0.9677      0.319      3.030      0.002       0.342       1.594
# Sensor_Measurement_14_variance    -0.0135      0.001     -9.529      0.000      -0.016      -0.011
# Sensor_Measurement_16_mean      1.963e+04   1021.902     19.213      0.000    1.76e+04    2.16e+04
# Sensor_Measurement_16_slope     -1.72e+04   6297.499     -2.731      0.006   -2.95e+04   -4857.369
# Sensor_Measurement_17_mean        -6.3533      1.336     -4.756      0.000      -8.972      -3.735
# Sensor_Measurement_17_variance    -0.2043      0.025     -8.029      0.000      -0.254      -0.154
# Sensor_Measurement_18_mean     -2101.2781    575.107     -3.654      0.000   -3228.530    -974.026
# Sensor_Measurement_18_variance     1.2101      0.079     15.230      0.000       1.054       1.366
# Sensor_Measurement_19_mean      6547.4090   2789.818      2.347      0.019    1079.156     1.2e+04
# Sensor_Measurement_19_variance    -6.8279      1.060     -6.440      0.000      -8.906      -4.750
# Sensor_Measurement_20_mean        98.3293      8.937     11.002      0.000      80.812     115.847
# ==============================================================================
# Omnibus:                     1103.814   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1445.668
# Skew:                           0.508   Prob(JB):                         0.00
# Kurtosis:                       3.771   Cond. No.                     1.32e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.11e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_1,2': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B383344F10>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     720.3
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:37:26   Log-Likelihood:            -1.2298e+05
# No. Observations:               22448   AIC:                         2.461e+05
# Df Residuals:                   22398   BIC:                         2.465e+05
# Df Model:                          49
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           -154.9407     23.276     -6.657      0.000    -200.564    -109.317
# Time_in_Cycles                    -0.3114      0.007    -46.317      0.000      -0.325      -0.298
# Sensor_Measurement_2               1.4706      0.291      5.050      0.000       0.900       2.041
# Sensor_Measurement_3              -0.2671      0.095     -2.798      0.005      -0.454      -0.080
# Sensor_Measurement_10             81.1392     18.364      4.418      0.000      45.145     117.133
# Sensor_Measurement_17             -1.5421      0.386     -3.998      0.000      -2.298      -0.786
# Sensor_Measurement_19              2.4124      0.476      5.069      0.000       1.480       3.345
# Operational_Setting_1_mean      1517.0930    230.280      6.588      0.000    1065.729    1968.457
# Operational_Setting_1_variance     0.2347      0.069      3.415      0.001       0.100       0.369
# Operational_Setting_1_slope    -2625.7658    498.613     -5.266      0.000   -3603.082   -1648.449
# Operational_Setting_2_mean     -1.579e+04   2310.666     -6.835      0.000   -2.03e+04   -1.13e+04
# Operational_Setting_2_variance -1001.3790    127.949     -7.826      0.000   -1252.168    -750.590
# Operational_Setting_2_slope     1.855e+04   5001.402      3.709      0.000    8747.609    2.84e+04
# Operational_Setting_3_mean     -3.028e+04   4533.391     -6.679      0.000   -3.92e+04   -2.14e+04
# Operational_Setting_3_slope     5.984e+04   1.09e+04      5.493      0.000    3.85e+04    8.12e+04
# Sensor_Measurement_1_mean      -1.092e+04   1640.373     -6.655      0.000   -1.41e+04   -7700.715
# Sensor_Measurement_1_slope       1.87e+04   3552.333      5.264      0.000    1.17e+04    2.57e+04
# Sensor_Measurement_2_variance     -0.0874      0.020     -4.291      0.000      -0.127      -0.047
# Sensor_Measurement_2_slope       -43.1282     10.994     -3.923      0.000     -64.678     -21.578
# Sensor_Measurement_3_variance      0.0053      0.002      2.982      0.003       0.002       0.009
# Sensor_Measurement_3_slope        -4.0847      0.910     -4.489      0.000      -5.868      -2.301
# Sensor_Measurement_4_mean         -4.7149      0.222    -21.261      0.000      -5.150      -4.280
# Sensor_Measurement_4_variance     -0.0040      0.001     -2.771      0.006      -0.007      -0.001
# Sensor_Measurement_5_mean       4926.3450    960.452      5.129      0.000    3043.791    6808.899
# Sensor_Measurement_5_slope      -1.02e+04   2073.957     -4.919      0.000   -1.43e+04   -6137.716
# Sensor_Measurement_6_mean       1132.7544     64.869     17.462      0.000    1005.607    1259.902
# Sensor_Measurement_7_mean         14.0051      3.164      4.426      0.000       7.803      20.207
# Sensor_Measurement_7_variance      0.0828      0.011      7.673      0.000       0.062       0.104
# Sensor_Measurement_8_variance     -0.3442      0.057     -6.083      0.000      -0.455      -0.233
# Sensor_Measurement_9_mean         -2.5589      0.309     -8.290      0.000      -3.164      -1.954
# Sensor_Measurement_9_slope        -5.4443      0.849     -6.414      0.000      -7.108      -3.780
# Sensor_Measurement_10_mean     -1962.5622    464.285     -4.227      0.000   -2872.593   -1052.532
# Sensor_Measurement_10_variance  6855.4954    873.047      7.852      0.000    5144.262    8566.729
# Sensor_Measurement_10_slope    -6378.4513   1359.137     -4.693      0.000   -9042.455   -3714.448
# Sensor_Measurement_11_variance   -12.3072      2.057     -5.984      0.000     -16.338      -8.276
# Sensor_Measurement_11_slope     -390.6476     36.149    -10.806      0.000    -461.503    -319.792
# Sensor_Measurement_12_mean       -23.7082      3.423     -6.926      0.000     -30.417     -16.999
# Sensor_Measurement_12_variance    -0.0472      0.012     -3.903      0.000      -0.071      -0.024
# Sensor_Measurement_12_slope      -27.1019      6.648     -4.077      0.000     -40.133     -14.071
# Sensor_Measurement_13_slope     -363.7519     38.426     -9.466      0.000    -439.069    -288.435
# Sensor_Measurement_14_mean         2.0194      0.341      5.915      0.000       1.350       2.689
# Sensor_Measurement_14_slope       -8.8611      1.079     -8.211      0.000     -10.976      -6.746
# Sensor_Measurement_15_mean      -515.8185     46.817    -11.018      0.000    -607.583    -424.054
# Sensor_Measurement_15_variance  -114.5662     31.733     -3.610      0.000    -176.766     -52.366
# Sensor_Measurement_16_mean      1.724e+04   1190.394     14.481      0.000    1.49e+04    1.96e+04
# Sensor_Measurement_17_variance    -0.0866      0.028     -3.102      0.002      -0.141      -0.032
# Sensor_Measurement_18_mean      4490.7735    672.543      6.677      0.000    3172.542    5809.005
# Sensor_Measurement_18_variance     0.3504      0.056      6.212      0.000       0.240       0.461
# Sensor_Measurement_18_slope    -7608.3300   1456.801     -5.223      0.000   -1.05e+04   -4752.898
# Sensor_Measurement_19_mean     -2.106e+04   3158.323     -6.669      0.000   -2.73e+04   -1.49e+04
# Sensor_Measurement_19_slope     2.254e+04   4103.707      5.493      0.000    1.45e+04    3.06e+04
# Sensor_Measurement_21_variance   -20.4785      1.915    -10.696      0.000     -24.231     -16.726
# ==============================================================================
# Omnibus:                     3694.974   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8368.578
# Skew:                           0.956   Prob(JB):                         0.00
# Kurtosis:                       5.300   Cond. No.                     1.34e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.91e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_2,0': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B3832776A0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.632
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     1405.
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:37:27   Log-Likelihood:            -2.4324e+05
# No. Observations:               44992   AIC:                         4.866e+05
# Df Residuals:                   44936   BIC:                         4.871e+05
# Df Model:                          55
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            -62.0054      9.253     -6.701      0.000     -80.142     -43.869
# Time_in_Cycles                    -0.3360      0.005    -73.193      0.000      -0.345      -0.327
# Sensor_Measurement_2               1.4402      0.199      7.219      0.000       1.049       1.831
# Sensor_Measurement_3              -0.1720      0.063     -2.712      0.007      -0.296      -0.048
# Sensor_Measurement_4              -0.2084      0.047     -4.443      0.000      -0.300      -0.116
# Sensor_Measurement_10            133.0522     18.721      7.107      0.000      96.359     169.745
# Sensor_Measurement_17             -1.1593      0.265     -4.378      0.000      -1.678      -0.640
# Sensor_Measurement_19              1.9749      0.317      6.231      0.000       1.354       2.596
# Operational_Setting_1_mean       250.4330     13.048     19.193      0.000     224.859     276.007
# Operational_Setting_1_variance     0.1839      0.076      2.405      0.016       0.034       0.334
# Operational_Setting_1_slope     -675.8395     39.570    -17.080      0.000    -753.397    -598.282
# Operational_Setting_2_mean     -2487.4600    129.196    -19.253      0.000   -2740.685   -2234.235
# Operational_Setting_2_variance  -743.9481    101.829     -7.306      0.000    -943.535    -544.361
# Operational_Setting_3_mean     -4640.6041    267.768    -17.331      0.000   -5165.434   -4115.774
# Operational_Setting_3_variance   -36.7126      5.562     -6.601      0.000     -47.614     -25.812
# Operational_Setting_3_slope      1.58e+04    787.861     20.050      0.000    1.43e+04    1.73e+04
# Sensor_Measurement_1_mean      -1656.9898     95.347    -17.379      0.000   -1843.872   -1470.108
# Sensor_Measurement_1_slope      4836.0586    256.879     18.826      0.000    4332.572    5339.545
# Sensor_Measurement_2_slope       -48.2340      7.161     -6.736      0.000     -62.269     -34.199
# Sensor_Measurement_3_slope        -4.5330      0.590     -7.680      0.000      -5.690      -3.376
# Sensor_Measurement_4_mean         -2.4883      0.225    -11.065      0.000      -2.929      -2.048
# Sensor_Measurement_4_variance      0.0022      0.001      2.404      0.016       0.000       0.004
# Sensor_Measurement_5_variance    -19.9289      3.553     -5.610      0.000     -26.892     -12.966
# Sensor_Measurement_5_slope     -2207.8191    178.288    -12.383      0.000   -2557.266   -1858.372
# Sensor_Measurement_6_mean        771.0917     43.151     17.869      0.000     686.514     855.669
# Sensor_Measurement_7_mean          5.6136      2.099      2.675      0.007       1.500       9.727
# Sensor_Measurement_7_variance      0.0652      0.007      9.535      0.000       0.052       0.079
# Sensor_Measurement_8_mean       -165.8121     25.538     -6.493      0.000    -215.867    -115.757
# Sensor_Measurement_8_variance     -0.7505      0.060    -12.520      0.000      -0.868      -0.633
# Sensor_Measurement_9_mean         -1.9084      0.211     -9.061      0.000      -2.321      -1.496
# Sensor_Measurement_9_slope        -5.5842      0.555    -10.060      0.000      -6.672      -4.496
# Sensor_Measurement_10_variance  3306.7370    896.839      3.687      0.000    1548.918    5064.556
# Sensor_Measurement_10_slope    -6449.7455    871.298     -7.402      0.000   -8157.505   -4741.986
# Sensor_Measurement_11_mean       -64.6864      7.032     -9.199      0.000     -78.469     -50.904
# Sensor_Measurement_11_variance     5.9662      1.352      4.413      0.000       3.316       8.616
# Sensor_Measurement_11_slope     -274.4262     21.191    -12.950      0.000    -315.962    -232.891
# Sensor_Measurement_12_mean       -14.3178      2.286     -6.264      0.000     -18.798      -9.838
# Sensor_Measurement_12_variance    -0.0377      0.008     -4.867      0.000      -0.053      -0.023
# Sensor_Measurement_12_slope      -30.2574      4.518     -6.698      0.000     -39.112     -21.403
# Sensor_Measurement_13_mean        94.6287     24.190      3.912      0.000      47.215     142.042
# Sensor_Measurement_13_variance     0.4724      0.070      6.748      0.000       0.335       0.610
# Sensor_Measurement_13_slope     -156.1094     24.609     -6.344      0.000    -204.343    -107.876
# Sensor_Measurement_14_mean         1.7017      0.241      7.059      0.000       1.229       2.174
# Sensor_Measurement_14_variance    -0.0091      0.001     -6.623      0.000      -0.012      -0.006
# Sensor_Measurement_14_slope       -5.1758      0.686     -7.544      0.000      -6.520      -3.831
# Sensor_Measurement_15_mean      -307.7309     28.998    -10.612      0.000    -364.568    -250.894
# Sensor_Measurement_15_variance   -96.8546     25.777     -3.757      0.000    -147.379     -46.331
# Sensor_Measurement_16_mean        1.8e+04    774.691     23.233      0.000    1.65e+04    1.95e+04
# Sensor_Measurement_17_variance    -0.1299      0.018     -7.173      0.000      -0.165      -0.094
# Sensor_Measurement_17_slope      -10.7509      2.433     -4.419      0.000     -15.519      -5.983
# Sensor_Measurement_18_mean       859.5834     45.650     18.830      0.000     770.108     949.059
# Sensor_Measurement_18_variance     0.7418      0.060     12.394      0.000       0.624       0.859
# Sensor_Measurement_18_slope    -1921.1475    105.048    -18.288      0.000   -2127.043   -1715.252
# Sensor_Measurement_19_mean     -5612.8368    596.431     -9.411      0.000   -6781.852   -4443.822
# Sensor_Measurement_19_variance    -5.2110      0.789     -6.601      0.000      -6.758      -3.664
# Sensor_Measurement_19_slope     5951.4172    296.827     20.050      0.000    5369.632    6533.202
# Sensor_Measurement_20_mean        46.9066      9.801      4.786      0.000      27.696      66.117
# Sensor_Measurement_21_variance    -9.6118      1.319     -7.286      0.000     -12.197      -7.026
# Sensor_Measurement_21_slope      167.5506     36.973      4.532      0.000      95.083     240.018
# ==============================================================================
# Omnibus:                     7045.589   Durbin-Watson:                   0.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16075.225
# Skew:                           0.913   Prob(JB):                         0.00
# Kurtosis:                       5.289   Cond. No.                     1.33e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.53e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_2,1': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B383333910>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.649
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                     861.8
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:37:27   Log-Likelihood:                -85954.
# No. Observations:               15884   AIC:                         1.720e+05
# Df Residuals:                   15849   BIC:                         1.722e+05
# Df Model:                          34
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            195.6626     29.683      6.592      0.000     137.481     253.845
# Time_in_Cycles                    -0.3736      0.008    -46.353      0.000      -0.389      -0.358
# Operational_Setting_1_mean     -1113.5113    245.951     -4.527      0.000   -1595.603    -631.419
# Operational_Setting_2_mean      9449.0314   2469.701      3.826      0.000    4608.138    1.43e+04
# Operational_Setting_3_mean      2.155e+04   4847.326      4.446      0.000    1.21e+04    3.11e+04
# Sensor_Measurement_1_mean       7802.7246   1753.848      4.449      0.000    4364.984    1.12e+04
# Sensor_Measurement_3_variance     -0.0085      0.002     -4.271      0.000      -0.012      -0.005
# Sensor_Measurement_4_mean         -3.1684      0.374     -8.469      0.000      -3.902      -2.435
# Sensor_Measurement_4_variance      0.0039      0.002      2.349      0.019       0.001       0.007
# Sensor_Measurement_5_mean      -5290.4425   1022.623     -5.173      0.000   -7294.899   -3285.986
# Sensor_Measurement_6_mean        401.9704     62.910      6.390      0.000     278.659     525.281
# Sensor_Measurement_6_variance      5.6718      1.591      3.566      0.000       2.554       8.790
# Sensor_Measurement_8_mean        232.7692     44.370      5.246      0.000     145.800     319.739
# Sensor_Measurement_8_variance      0.3295      0.069      4.746      0.000       0.193       0.466
# Sensor_Measurement_8_slope         4.3305      0.507      8.534      0.000       3.336       5.325
# Sensor_Measurement_9_variance     -0.0010      0.000     -3.228      0.001      -0.002      -0.000
# Sensor_Measurement_10_mean     -3933.2322    512.253     -7.678      0.000   -4937.306   -2929.158
# Sensor_Measurement_10_variance  3718.0667    803.637      4.627      0.000    2142.847    5293.286
# Sensor_Measurement_10_slope     3135.3245    389.551      8.049      0.000    2371.761    3898.888
# Sensor_Measurement_11_mean       -69.8171     12.233     -5.707      0.000     -93.795     -45.839
# Sensor_Measurement_11_variance     6.9355      2.257      3.072      0.002       2.511      11.360
# Sensor_Measurement_11_slope     -195.6120     25.582     -7.646      0.000    -245.756    -145.468
# Sensor_Measurement_12_slope       12.0709      1.770      6.819      0.000       8.601      15.540
# Sensor_Measurement_13_mean      -231.6353     42.477     -5.453      0.000    -314.894    -148.376
# Sensor_Measurement_14_mean         1.5484      0.263      5.891      0.000       1.033       2.064
# Sensor_Measurement_14_slope       -3.4349      0.577     -5.956      0.000      -4.565      -2.305
# Sensor_Measurement_15_mean      -210.0493     40.189     -5.227      0.000    -288.824    -131.275
# Sensor_Measurement_15_variance  -151.9233     30.333     -5.009      0.000    -211.379     -92.468
# Sensor_Measurement_16_mean      1.753e+04   1297.512     13.511      0.000     1.5e+04    2.01e+04
# Sensor_Measurement_17_mean       -18.5205      1.769    -10.471      0.000     -21.987     -15.054
# Sensor_Measurement_17_variance     0.2126      0.030      7.020      0.000       0.153       0.272
# Sensor_Measurement_18_mean     -3416.6106    720.423     -4.743      0.000   -4828.722   -2004.499
# Sensor_Measurement_18_variance    -0.3279      0.069     -4.749      0.000      -0.463      -0.193
# Sensor_Measurement_19_mean      2.031e+04   3525.467      5.762      0.000    1.34e+04    2.72e+04
# Sensor_Measurement_20_slope     -180.7863     25.584     -7.066      0.000    -230.934    -130.638
# Sensor_Measurement_21_variance    -7.0872      1.605     -4.415      0.000     -10.234      -3.940
# ==============================================================================
# Omnibus:                     1312.583   Durbin-Watson:                   0.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1725.570
# Skew:                           0.719   Prob(JB):                         0.00
# Kurtosis:                       3.733   Cond. No.                     1.33e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.35e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_2,2': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B38325B310>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.972
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     501.0
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):           1.33e-85
# Time:                        22:37:27   Log-Likelihood:                -495.35
# No. Observations:                 124   AIC:                             1009.
# Df Residuals:                     115   BIC:                             1034.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           1.394e+04   1777.940      7.839      0.000    1.04e+04    1.75e+04
# Time_in_Cycles                    -0.7020      0.027    -25.646      0.000      -0.756      -0.648
# Operational_Setting_2_variance   512.7758     87.711      5.846      0.000     339.037     686.514
# Sensor_Measurement_3_mean          5.2348      0.818      6.403      0.000       3.615       6.854
# Sensor_Measurement_6_mean         22.8114      3.444      6.623      0.000      15.989      29.634
# Sensor_Measurement_9_mean         -2.3270      0.307     -7.582      0.000      -2.935      -1.719
# Sensor_Measurement_15_mean      -170.6727     31.396     -5.436      0.000    -232.863    -108.482
# Sensor_Measurement_15_slope       33.4494     13.035      2.566      0.012       7.630      59.269
# Sensor_Measurement_16_variance -3.769e+06    5.1e+05     -7.393      0.000   -4.78e+06   -2.76e+06
# ==============================================================================
# Omnibus:                        2.250   Durbin-Watson:                   0.483
# Prob(Omnibus):                  0.325   Jarque-Bera (JB):                1.741
# Skew:                          -0.194   Prob(JB):                        0.419
# Kurtosis:                       3.431   Cond. No.                     3.65e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """), 'Operational_Setting_3,0': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B3831034C0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.681
# Method:                 Least Squares   F-statistic:                     770.6
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:37:28   Log-Likelihood:                -61055.
# No. Observations:               11179   AIC:                         1.222e+05
# Df Residuals:                   11147   BIC:                         1.224e+05
# Df Model:                          31
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                          -6370.3332    870.668     -7.317      0.000   -8076.996   -4663.670
# Time_in_Cycles                    -0.3570      0.007    -48.490      0.000      -0.371      -0.343
# Operational_Setting_2_variance  -848.6934    253.447     -3.349      0.001   -1345.495    -351.892
# Operational_Setting_3_variance     0.4451      0.093      4.764      0.000       0.262       0.628
# Sensor_Measurement_2_mean         26.7071      1.768     15.106      0.000      23.242      30.173
# Sensor_Measurement_2_slope        13.9410      4.180      3.335      0.001       5.747      22.135
# Sensor_Measurement_3_variance     -0.0105      0.002     -4.465      0.000      -0.015      -0.006
# Sensor_Measurement_4_mean         -3.8406      0.459     -8.363      0.000      -4.741      -2.940
# Sensor_Measurement_6_mean        109.2239     52.118      2.096      0.036       7.063     211.385
# Sensor_Measurement_6_variance    -13.6695      3.389     -4.033      0.000     -20.313      -7.026
# Sensor_Measurement_6_slope       -82.9902     20.038     -4.142      0.000    -122.268     -43.713
# Sensor_Measurement_7_variance      0.1000      0.014      6.912      0.000       0.072       0.128
# Sensor_Measurement_8_mean          2.8975      0.268     10.799      0.000       2.372       3.423
# Sensor_Measurement_8_slope        -1.5662      0.725     -2.159      0.031      -2.988      -0.144
# Sensor_Measurement_9_variance     -0.0027      0.000     -7.402      0.000      -0.003      -0.002
# Sensor_Measurement_10_variance  7550.4945   1481.295      5.097      0.000    4646.894    1.05e+04
# Sensor_Measurement_11_mean      -127.8879     15.467     -8.269      0.000    -158.206     -97.570
# Sensor_Measurement_11_variance    17.1112      2.714      6.304      0.000      11.791      22.432
# Sensor_Measurement_11_slope      -87.7252     40.362     -2.173      0.030    -166.842      -8.608
# Sensor_Measurement_12_mean        -5.7137      2.227     -2.566      0.010     -10.079      -1.349
# Sensor_Measurement_12_variance    -0.0695      0.016     -4.221      0.000      -0.102      -0.037
# Sensor_Measurement_14_mean         0.4898      0.075      6.498      0.000       0.342       0.638
# Sensor_Measurement_14_variance    -0.0092      0.003     -3.661      0.000      -0.014      -0.004
# Sensor_Measurement_14_slope       -5.4533      1.212     -4.500      0.000      -7.829      -3.078
# Sensor_Measurement_15_mean      -205.1878     53.208     -3.856      0.000    -309.485    -100.891
# Sensor_Measurement_15_variance  -143.3446     49.995     -2.867      0.004    -241.343     -45.346
# Sensor_Measurement_15_slope    -1102.7228    183.165     -6.020      0.000   -1461.758    -743.687
# Sensor_Measurement_16_mean       4.56e+04   2315.641     19.691      0.000    4.11e+04    5.01e+04
# Sensor_Measurement_16_variance  -1.52e+06   5.83e+05     -2.606      0.009   -2.66e+06   -3.77e+05
# Sensor_Measurement_17_mean       -23.3687      2.226    -10.497      0.000     -27.733     -19.005
# Sensor_Measurement_19_variance     0.1175      0.023      5.037      0.000       0.072       0.163
# Sensor_Measurement_20_variance     3.3264      0.980      3.393      0.001       1.405       5.248
# Sensor_Measurement_21_variance   -12.9284      2.610     -4.953      0.000     -18.045      -7.812
# ==============================================================================
# Omnibus:                      627.577   Durbin-Watson:                   0.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              781.716
# Skew:                           0.561   Prob(JB):                    1.79e-170
# Kurtosis:                       3.649   Cond. No.                     1.04e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.58e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_3,1': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B3830B7460>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):                nan
# Time:                        22:37:28   Log-Likelihood:                 1194.6
# No. Observations:                  72   AIC:                            -2245.
# Df Residuals:                       0   BIC:                            -2081.
# Df Model:                          71
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             -0.4070        inf         -0        nan         nan         nan
# Time_in_Cycles                    -0.8528        inf         -0        nan         nan         nan
# Operational_Setting_1            -20.6315        inf         -0        nan         nan         nan
# Operational_Setting_2           -351.3988        inf         -0        nan         nan         nan
# Operational_Setting_3           -336.9997        inf         -0        nan         nan         nan
# Sensor_Measurement_1               5.7069        inf          0        nan         nan         nan
# Sensor_Measurement_2              -1.4452        inf         -0        nan         nan         nan
# Sensor_Measurement_3              -0.2148        inf         -0        nan         nan         nan
# Sensor_Measurement_4               0.0892        inf          0        nan         nan         nan
# Sensor_Measurement_5            -472.8555        inf         -0        nan         nan         nan
# Sensor_Measurement_6              63.6998        inf          0        nan         nan         nan
# Sensor_Measurement_7               4.0947        inf          0        nan         nan         nan
# Sensor_Measurement_8              -1.6629        inf         -0        nan         nan         nan
# Sensor_Measurement_9              -0.0361        inf         -0        nan         nan         nan
# Sensor_Measurement_10          -2001.4531        inf         -0        nan         nan         nan
# Sensor_Measurement_11              3.6694        inf          0        nan         nan         nan
# Sensor_Measurement_12              2.2704        inf          0        nan         nan         nan
# Sensor_Measurement_13             43.3423        inf          0        nan         nan         nan
# Sensor_Measurement_14              0.2582        inf          0        nan         nan         nan
# Sensor_Measurement_15             61.0456        inf          0        nan         nan         nan
# Sensor_Measurement_16             -6.5512        inf         -0        nan         nan         nan
# Sensor_Measurement_17             -0.2655        inf         -0        nan         nan         nan
# Sensor_Measurement_18              1.5967        inf          0        nan         nan         nan
# Sensor_Measurement_19           -152.3207        inf         -0        nan         nan         nan
# Sensor_Measurement_20              7.6689        inf          0        nan         nan         nan
# Sensor_Measurement_21             26.4787        inf          0        nan         nan         nan
# Operational_Setting_1_mean       107.3818        inf          0        nan         nan         nan
# Operational_Setting_1_variance     5.9861        inf          0        nan         nan         nan
# Operational_Setting_1_slope      -54.9362        inf         -0        nan         nan         nan
# Operational_Setting_2_mean     -1332.6009        inf         -0        nan         nan         nan
# Operational_Setting_2_variance -2949.0861        inf         -0        nan         nan         nan
# Operational_Setting_2_slope      -33.1903        inf         -0        nan         nan         nan
# Operational_Setting_3_mean       678.5343        inf          0        nan         nan         nan
# Operational_Setting_3_variance   -67.5607        inf         -0        nan         nan         nan
# Operational_Setting_3_slope      -58.5812        inf         -0        nan         nan         nan
# Sensor_Measurement_1_mean         36.2656        inf          0        nan         nan         nan
# Sensor_Measurement_1_variance     -1.3884        inf         -0        nan         nan         nan
# Sensor_Measurement_1_slope       298.6850        inf          0        nan         nan         nan
# Sensor_Measurement_2_mean        157.9735        inf          0        nan         nan         nan
# Sensor_Measurement_2_variance      0.7161        inf          0        nan         nan         nan
# Sensor_Measurement_2_slope        39.7899        inf          0        nan         nan         nan
# Sensor_Measurement_3_mean          3.5361        inf          0        nan         nan         nan
# Sensor_Measurement_3_variance      0.0089        inf          0        nan         nan         nan
# Sensor_Measurement_3_slope        18.6830        inf          0        nan         nan         nan
# Sensor_Measurement_4_mean         -1.6221        inf         -0        nan         nan         nan
# Sensor_Measurement_4_variance      0.0129        inf          0        nan         nan         nan
# Sensor_Measurement_4_slope         2.1793        inf          0        nan         nan         nan
# Sensor_Measurement_5_mean       1283.6299        inf          0        nan         nan         nan
# Sensor_Measurement_5_variance   -521.4735        inf         -0        nan         nan         nan
# Sensor_Measurement_5_slope       353.6603        inf          0        nan         nan         nan
# Sensor_Measurement_6_mean        518.9111        inf          0        nan         nan         nan
# Sensor_Measurement_6_variance    222.5803        inf          0        nan         nan         nan
# Sensor_Measurement_6_slope       430.1505        inf          0        nan         nan         nan
# Sensor_Measurement_7_mean         -8.2304        inf         -0        nan         nan         nan
# Sensor_Measurement_7_variance      0.2112        inf          0        nan         nan         nan
# Sensor_Measurement_7_slope      -286.4555        inf         -0        nan         nan         nan
# Sensor_Measurement_8_mean        308.3105        inf          0        nan         nan         nan
# Sensor_Measurement_8_variance     -0.6745        inf         -0        nan         nan         nan
# Sensor_Measurement_8_slope      -101.7677        inf         -0        nan         nan         nan
# Sensor_Measurement_9_mean         -8.3212        inf         -0        nan         nan         nan
# Sensor_Measurement_9_variance     -0.0060        inf         -0        nan         nan         nan
# Sensor_Measurement_9_slope        21.7752        inf          0        nan         nan         nan
# Sensor_Measurement_10_mean       363.6467        inf          0        nan         nan         nan
# Sensor_Measurement_10_variance  -232.8367        inf         -0        nan         nan         nan
# Sensor_Measurement_10_slope      -89.1779        inf         -0        nan         nan         nan
# Sensor_Measurement_11_mean      -395.9784        inf         -0        nan         nan         nan
# Sensor_Measurement_11_variance   -60.5391        inf         -0        nan         nan         nan
# Sensor_Measurement_11_slope      105.3744        inf          0        nan         nan         nan
# Sensor_Measurement_12_mean       -16.3696        inf         -0        nan         nan         nan
# Sensor_Measurement_12_variance    -0.1930        inf         -0        nan         nan         nan
# Sensor_Measurement_12_slope      289.7312        inf          0        nan         nan         nan
# Sensor_Measurement_13_mean       -30.1359        inf         -0        nan         nan         nan
# Sensor_Measurement_13_variance     0.8921        inf          0        nan         nan         nan
# Sensor_Measurement_13_slope      236.2649        inf          0        nan         nan         nan
# Sensor_Measurement_14_mean         4.7375        inf          0        nan         nan         nan
# Sensor_Measurement_14_variance     0.0364        inf          0        nan         nan         nan
# Sensor_Measurement_14_slope      -16.4497        inf         -0        nan         nan         nan
# Sensor_Measurement_15_mean      -804.9355        inf         -0        nan         nan         nan
# Sensor_Measurement_15_variance  -842.6720        inf         -0        nan         nan         nan
# Sensor_Measurement_15_slope     2553.7874        inf          0        nan         nan         nan
# Sensor_Measurement_16_mean        19.5948        inf          0        nan         nan         nan
# Sensor_Measurement_16_variance    -0.7617        inf         -0        nan         nan         nan
# Sensor_Measurement_16_slope       -1.4191        inf         -0        nan         nan         nan
# Sensor_Measurement_17_mean       -40.3956        inf         -0        nan         nan         nan
# Sensor_Measurement_17_variance    -0.3208        inf         -0        nan         nan         nan
# Sensor_Measurement_17_slope       75.7692        inf          0        nan         nan         nan
# Sensor_Measurement_18_mean      -361.2565        inf         -0        nan         nan         nan
# Sensor_Measurement_18_variance     0.6553        inf          0        nan         nan         nan
# Sensor_Measurement_18_slope     -165.0622        inf         -0        nan         nan         nan
# Sensor_Measurement_19_mean       230.2817        inf          0        nan         nan         nan
# Sensor_Measurement_19_variance    -9.5896        inf         -0        nan         nan         nan
# Sensor_Measurement_19_slope      -22.0705        inf         -0        nan         nan         nan
# Sensor_Measurement_20_mean      -285.2324        inf         -0        nan         nan         nan
# Sensor_Measurement_20_variance     2.6714        inf          0        nan         nan         nan
# Sensor_Measurement_20_slope      -60.7403        inf         -0        nan         nan         nan
# Sensor_Measurement_21_mean        78.2715        inf          0        nan         nan         nan
# Sensor_Measurement_21_variance   -22.3142        inf         -0        nan         nan         nan
# Sensor_Measurement_21_slope     -439.6014        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        6.971   Durbin-Watson:                   0.560
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):               11.476
# Skew:                          -0.187   Prob(JB):                      0.00322
# Kurtosis:                       4.920   Cond. No.                     8.37e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 8.37e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """), 'Operational_Setting_3,2': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B3831B8AF0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.627
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     1857.
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        22:37:29   Log-Likelihood:            -2.6786e+05
# No. Observations:               49749   AIC:                         5.358e+05
# Df Residuals:                   49703   BIC:                         5.362e+05
# Df Model:                          45
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           1.472e+04    523.009     28.139      0.000    1.37e+04    1.57e+04
# Time_in_Cycles                    -0.3780      0.004    -88.798      0.000      -0.386      -0.370
# Sensor_Measurement_2               2.7454      0.343      8.008      0.000       2.074       3.417
# Sensor_Measurement_3              -0.1679      0.058     -2.907      0.004      -0.281      -0.055
# Sensor_Measurement_4              -0.3955      0.046     -8.600      0.000      -0.486      -0.305
# Sensor_Measurement_9              -0.1205      0.044     -2.737      0.006      -0.207      -0.034
# Sensor_Measurement_10            127.4207     15.497      8.222      0.000      97.047     157.794
# Sensor_Measurement_14              0.3016      0.045      6.639      0.000       0.213       0.391
# Sensor_Measurement_17             -1.0813      0.242     -4.463      0.000      -1.556      -0.606
# Operational_Setting_1_slope     -762.6733     40.037    -19.049      0.000    -841.147    -684.200
# Operational_Setting_2_variance  -138.0076     48.803     -2.828      0.005    -233.661     -42.354
# Operational_Setting_3_variance   -39.9593      5.171     -7.727      0.000     -50.095     -29.824
# Operational_Setting_3_slope     1.742e+04    794.377     21.932      0.000    1.59e+04     1.9e+04
# Sensor_Measurement_1_slope      5396.6359    259.282     20.814      0.000    4888.441    5904.831
# Sensor_Measurement_2_slope       -26.3002      6.673     -3.941      0.000     -39.380     -13.221
# Sensor_Measurement_3_slope        -3.6125      0.544     -6.638      0.000      -4.679      -2.546
# Sensor_Measurement_4_mean         -1.9402      0.206     -9.399      0.000      -2.345      -1.536
# Sensor_Measurement_4_variance     -0.0042      0.001     -5.550      0.000      -0.006      -0.003
# Sensor_Measurement_5_mean       -535.9677     25.621    -20.919      0.000    -586.186    -485.750
# Sensor_Measurement_5_slope     -2529.2085    171.256    -14.769      0.000   -2864.872   -2193.545
# Sensor_Measurement_6_mean        400.0025     19.004     21.049      0.000     362.755     437.250
# Sensor_Measurement_7_variance      0.0427      0.006      6.792      0.000       0.030       0.055
# Sensor_Measurement_8_variance     -0.6530      0.049    -13.431      0.000      -0.748      -0.558
# Sensor_Measurement_9_mean          1.5653      0.066     23.759      0.000       1.436       1.694
# Sensor_Measurement_9_slope        -6.8696      0.515    -13.347      0.000      -7.878      -5.861
# Sensor_Measurement_10_mean      1051.6559     87.052     12.081      0.000     881.033    1222.279
# Sensor_Measurement_10_slope    -7054.0784    833.558     -8.463      0.000   -8687.862   -5420.294
# Sensor_Measurement_11_mean      -116.0290      5.931    -19.563      0.000    -127.654    -104.404
# Sensor_Measurement_11_variance     4.8554      1.129      4.302      0.000       2.643       7.067
# Sensor_Measurement_11_slope     -263.4262     20.391    -12.919      0.000    -303.393    -223.459
# Sensor_Measurement_12_variance    -0.0382      0.007     -5.417      0.000      -0.052      -0.024
# Sensor_Measurement_12_slope      -33.9180      4.167     -8.139      0.000     -42.086     -25.750
# Sensor_Measurement_13_variance     0.5055      0.065      7.755      0.000       0.378       0.633
# Sensor_Measurement_13_slope     -138.3087     22.830     -6.058      0.000    -183.056     -93.562
# Sensor_Measurement_14_mean        -2.6772      0.071    -37.971      0.000      -2.815      -2.539
# Sensor_Measurement_14_slope       -5.8497      0.611     -9.582      0.000      -7.046      -4.653
# Sensor_Measurement_15_mean      -214.0263     16.847    -12.704      0.000    -247.046    -181.007
# Sensor_Measurement_16_mean      1.054e+04    678.637     15.531      0.000    9209.641    1.19e+04
# Sensor_Measurement_16_slope    -6887.2910   3303.398     -2.085      0.037   -1.34e+04    -412.592
# Sensor_Measurement_17_slope       -9.5226      2.179     -4.370      0.000     -13.794      -5.252
# Sensor_Measurement_18_variance     0.6493      0.049     13.357      0.000       0.554       0.745
# Sensor_Measurement_18_slope    -2158.0106    105.921    -20.374      0.000   -2365.617   -1950.404
# Sensor_Measurement_19_variance    -5.6718      0.734     -7.727      0.000      -7.110      -4.233
# Sensor_Measurement_19_slope     6563.9514    299.281     21.932      0.000    5977.356    7150.546
# Sensor_Measurement_20_mean       -37.0269      6.738     -5.495      0.000     -50.234     -23.820
# Sensor_Measurement_20_variance     1.8473      0.378      4.889      0.000       1.107       2.588
# Sensor_Measurement_21_variance    -8.8367      1.053     -8.389      0.000     -10.901      -6.772
# Sensor_Measurement_21_slope      194.0823     33.861      5.732      0.000     127.714     260.451
# ==============================================================================
# Omnibus:                     8197.936   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19805.392
# Skew:                           0.936   Prob(JB):                         0.00
# Kurtosis:                       5.460   Cond. No.                     1.03e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.22e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """)}

# %% [markdown]
# # testing

# %%
column_names_first_5 = ['Unit_Number', 'Time_in_Cycles', 'Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']

remaining_column_names = [f'Sensor_Measurement_{i}' for i in range(1,22)]

column_names = column_names_first_5 + remaining_column_names

test1 = pd.read_csv("test_FD004.txt", delim_whitespace=True, names=column_names)

# %% [markdown]
# ## generate columns for testing data

# %%
def generate_remaining_columns(df):
    
    rolling_columns = [col for col in df.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number']]


    result = []
    window_size = 20

    for unit, group in df.groupby("Unit_Number"):
        group = group.sort_values("Time_in_Cycles")  # Ensure data is sorted by time

        for feature in rolling_columns:
            if feature in group.columns:
                # Initialize temporary lists for this feature and unit
                unit_means = []
                unit_variances = []
                unit_slopes = []

                # Iterate over rolling windows
                for i in range(len(group)):
                    window = group.iloc[max(0, i - window_size + 1): i + 1]

                    # Compute mean and variance
                    unit_means.append(window[feature].mean())
                    unit_variances.append(window[feature].var())

                    # Compute slope if there's enough data
                    if len(window) > 1:
                        slope, _, _, _, _ = linregress(window["Time_in_Cycles"], window[feature])
                        unit_slopes.append(slope)
                    else:
                        unit_slopes.append(np.nan)

                # Add new columns to the group
                group[f'{feature}_mean'] = unit_means
                group[f'{feature}_variance'] = unit_variances
                group[f'{feature}_slope'] = unit_slopes

        # Append the processed group to the result
        result.append(group)

    # Concatenate all processed groups back together
    final_df = pd.concat(result, axis=0).reset_index(drop=True)

    return final_df

# %%
test1_full = generate_remaining_columns(test1)

# %% [markdown]
# ## assign each unit's last segment to its cluster

# %%
def assign_last_segment_to_cluster(test_data, features, cluster_models, segments_mapping):
    assigned_clusters = {}

    for feature in features:
        # Extract test data for the feature
        test_feature_data = test_data[feature].values

        # Scale the test feature
        scaler = StandardScaler()
        scaled_test_feature = scaler.fit_transform(test_feature_data.reshape(-1, 1)).flatten()

        # Detect change points using Ruptures
        model = rpt.Pelt(model="l2").fit(scaled_test_feature)
        change_points = model.predict(pen=10)  # Use the same penalty as training

        # Extract the last segment
        start_idx = change_points[-2] if len(change_points) > 1 else 0
        end_idx = len(scaled_test_feature)
        last_segment = scaled_test_feature[start_idx:end_idx]

        # Normalize the last segment
        normalized_last_segment = normalize_segment_length(last_segment, length=100)

        # Convert to the correct format for the model
        normalized_last_segment = normalized_last_segment.reshape(1, -1)

        # Assign the last segment to the closest cluster
        cluster_model = cluster_models[feature]
        cluster_label = cluster_model.predict(normalized_last_segment)[0]

        # Store the result
        assigned_clusters[feature] = {
            "cluster_label": cluster_label,
            "start_idx": start_idx,
            "end_idx": end_idx
        }

    return assigned_clusters

# %%
test_data = test1_full[test1_full["Unit_Number"] == 1]

assigned_clusters = assign_last_segment_to_cluster(
    test_data=test_data,
    features=['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3'],
    cluster_models=cluster_models,
    segments_mapping=segments_mapping
)
# Out:
# C:\Users\18065\anaconda3\lib\site-packages\tslearn\utils\utils.py:90: UserWarning: 2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries
#   warnings.warn(
# C:\Users\18065\anaconda3\lib\site-packages\tslearn\utils\utils.py:90: UserWarning: 2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries
#   warnings.warn(
# C:\Users\18065\anaconda3\lib\site-packages\tslearn\utils\utils.py:90: UserWarning: 2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries
#   warnings.warn(

# %%
print(assigned_clusters)
# Out:
# {'Operational_Setting_1': {'cluster_label': 1, 'start_idx': 0, 'end_idx': 230}, 'Operational_Setting_2': {'cluster_label': 0, 'start_idx': 0, 'end_idx': 230}, 'Operational_Setting_3': {'cluster_label': 0, 'start_idx': 180, 'end_idx': 230}}

# %% [markdown]
# ## get weighted prediction based on assigned clusters

# %%
def calculate_weighted_prediction(test_data, assigned_clusters, df_threshold=5):
    total_weight = 0
    weighted_sum = 0

    # Iterate through the assigned clusters
    for cluster_feature, details in assigned_clusters.items():
        cluster_number_id = details["cluster_label"]

        # Retrieve the corresponding model and its details
        model_key = f"{cluster_feature},{cluster_number_id}"
        model_fit, summary = level2_models[model_key]
        r2_value = model_fit.rsquared
        df_model = model_fit.df_model  # Degree of freedom of the model

        # Calculate scaling factor based on df_model
        scaling_factor = min(1, df_model / df_threshold)

        # Final weight for the model
        weight = r2_value * scaling_factor

        # Load the saved model and its features
        filename = f"FD004{cluster_feature}_c{cluster_number_id}_model_and_columns.joblib"
        linear_model_fit2, model_features = load(filename)

        # Prepare the test data for the model
        test_data = test_data.copy()
        test_data["const"] = 1  # Add intercept
        filtered_data = test_data[model_features].fillna(0)

        # Get the prediction for the current model
        filtered_data_last = filtered_data.iloc[-1]  # Use the last row of test data
        prediction = linear_model_fit2.predict(filtered_data_last)

        # Accumulate the weighted sum and total weight
        weighted_sum += prediction * weight
        total_weight += weight

    # Calculate the weighted average prediction
    if total_weight > 0:
        return weighted_sum / total_weight
    else:
        return 0  # Handle edge case where no models have a valid weight

# %%
import warnings
from statsmodels.tsa.api import SimpleExpSmoothing

# Ignore specific warning from tslearn
warnings.filterwarnings("ignore", message="2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries")

# Ignore SettingWithCopyWarning globally
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)


def test_dataset_fit(test_data_frame):
    RUL_predictions = []

    for unit_number, group in test_data_frame.groupby("Unit_Number"):
        # Get test data for the current unit
        test_data = test_data_frame[test_data_frame["Unit_Number"] == unit_number]

        # Assign clusters to the last segment of the test data
        assigned_clusters = assign_last_segment_to_cluster(
            test_data=test_data,
            features=['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3'],
            cluster_models=cluster_models,
            segments_mapping=segments_mapping
        )

        # Get predictions and weights from all relevant models
        weighted_prediction = calculate_weighted_prediction(test_data, assigned_clusters)

        # Use exponential smoothing to stabilize predictions
        y_train = []
        for i in range(1, 11):  # Take the last 10 data points
            prediction = weighted_prediction
            y_train.append(prediction)

        fit3 = SimpleExpSmoothing(y_train, initialization_method="estimated").fit()
        fcast3 = fit3.forecast(1)
        RUL_predictions.append(fcast3[0])

    return RUL_predictions
    
        
test1_RUL_Predict = test_dataset_fit(test1_full)

# %%
RUL_real = pd.read_csv("RUL_FD004.txt",names=['RUL'])  # Replace "file.csv" with your actual file path

# # Extract the integers into a list
RUL_real = RUL_real.iloc[:, 0].tolist()  # Assuming the integers are in the first column
print(RUL_real)

res = [a - b for a, b in zip(RUL_real, test1_RUL_Predict)]

print(res)
# Out:
# [22, 39, 107, 75, 149, 78, 94, 14, 99, 162, 143, 7, 71, 105, 12, 160, 162, 104, 194, 82, 91, 11, 26, 142, 39, 92, 76, 124, 64, 118, 6, 22, 147, 126, 36, 73, 89, 11, 151, 10, 97, 30, 42, 60, 85, 134, 34, 45, 24, 86, 119, 151, 142, 176, 157, 67, 97, 8, 154, 139, 51, 33, 184, 46, 12, 133, 46, 46, 12, 33, 15, 176, 23, 89, 124, 163, 25, 74, 78, 114, 96, 10, 172, 166, 115, 70, 94, 56, 86, 96, 50, 73, 154, 129, 171, 71, 105, 113, 37, 7, 13, 22, 9, 120, 100, 107, 41, 153, 126, 59, 18, 66, 13, 14, 139, 13, 75, 8, 109, 137, 41, 192, 23, 86, 184, 15, 195, 126, 120, 165, 101, 116, 126, 36, 7, 122, 159, 88, 173, 146, 130, 108, 53, 162, 59, 100, 56, 145, 76, 57, 31, 88, 173, 34, 7, 133, 172, 6, 22, 83, 82, 84, 95, 174, 111, 72, 109, 87, 179, 158, 126, 12, 8, 10, 123, 103, 12, 106, 12, 32, 37, 116, 15, 10, 46, 142, 24, 135, 56, 43, 178, 71, 104, 15, 166, 89, 36, 11, 92, 96, 59, 13, 167, 151, 154, 109, 116, 91, 11, 88, 108, 76, 14, 89, 145, 17, 66, 154, 41, 182, 73, 39, 58, 14, 145, 88, 162, 189, 120, 98, 33, 184, 110, 68, 24, 75, 18, 16, 166, 98, 176, 81, 118, 35, 131, 194, 112, 26]
# [-31.003731178308897, -57.14044214178941, -63.00676928448871, -59.43251241362512, 24.82173735015384, -86.83689069952405, -26.073262066754793, 29.631431938822022, 7.226403562713799, -25.46910270276527, -46.72656693796617, 10.123080124171775, -20.8815751711183, -29.464947173535563, -48.37841994394363, 29.820069404199188, 74.37091387523273, 61.98509231672896, -21.500964632546925, -18.400670605454025, -36.95698792683325, -17.75354043648656, -30.182269241968342, 3.867019890546004, 72.46742958081663, -26.5008909170721, -8.118940893261538, -73.61465405444594, -69.30558016660035, -43.433215121237964, -25.2935225310436, -4.4992253066041705, -49.881017713765715, 52.014180227763845, 35.62383762669842, -49.96514115104793, 45.28456116354916, -71.96319297164561, 35.93744623885864, -10.437828792966098, 65.35217925198731, 18.199160008243794, -69.93540461859462, 68.22958846493376, -90.80179112390823, -13.482924815234384, -22.57364616364042, -63.84171873184023, -11.149645472943028, -50.79617802488676, -83.59274368205854, -83.746368643252, -29.842205443290794, 59.163304391943115, -14.371664456308224, -63.720423158548726, -96.42903110823136, -8.324164885132646, -32.33256627273653, 1.2613238814295187, 56.04741643793299, -41.34048398844433, 33.89139116507445, -22.58400044030367, -38.017385566584885, 4.384381781878915, -11.924835188474745, -29.87687138279817, -22.51385733596387, -45.264019342167586, -50.28861204366645, -30.629764760872632, -20.83372569134218, -61.04209593420018, -17.430714036381232, -52.64452212322607, -80.65454953324517, -58.9151780439027, -63.46131878476564, -0.8445004662041953, -57.999524782661695, -23.656356158893935, 40.864741753073076, -29.504846991304447, -61.50521107430214, 11.14057451795344, -56.3699814880018, -45.28854936494412, 3.05738775880306, 19.32063771832989, -34.0113030766057, -57.362992080248944, 2.28006597133043, -39.90585351013726, 56.77102214381182, -36.75091124083801, -20.237772549643708, -60.287465583127016, -41.2529763055215, -11.011077575649743, -28.63669891383138, 57.925735435913296, -32.64964226298741, -99.86719955065371, 35.36189330424881, 44.61392329789513, -59.795769325046095, -9.42157360309892, -87.18848358797453, 8.039628228040428, 45.9386624393001, -30.96468776629247, -34.46085976896176, -47.95982839288661, 0.3859486378533177, -27.23331004257519, -80.91575096131137, -59.52292319933895, 12.505788672998861, 23.52647630396318, 7.453036441418853, -33.89364762020139, -27.839171503423394, 14.537901045870228, -4.877413592504865, -0.04841217709229717, 3.4736394449761576, -36.87998665554639, 27.95323513132888, 43.452242334163955, 12.643718146658031, -1.6687554509134799, -75.38557959578176, -19.976370360910543, 69.24883838788912, -14.33570236911774, 73.52599208271197, -16.693949229309368, -3.985260348503317, 26.521068959344248, -60.38389867466725, -79.98962534678591, 18.35210761606443, 1.0408044504572445, -38.07501806086445, -84.72152157676663, -102.57291127022773, -3.8594209026255726, 7.842410613408006, 9.538731499383118, 27.97168556768915, -38.25918051679611, 19.775235718954292, -13.198561049313952, -25.607139249673594, -29.627236705344842, -15.718570166785184, -36.9101580634763, -42.33841405822895, -86.43101562413335, -53.81117884335356, -29.061009077356914, -49.44554231727008, -12.350152992912484, -47.06610585569214, -87.33855367054835, -70.02841535031834, -39.810178828635074, 4.717510165395424, -30.695066465554135, 77.75864979694131, -45.63670621682304, -31.529442965459893, -45.24690376635123, 27.642596025942865, -0.01390684655557095, -48.936667183623726, -14.683994871361762, 11.050775538677343, 22.132765666798498, -9.604017041062896, -43.910218958546466, -30.365374072407192, -24.342763135425265, -6.600119623693082, -33.48895199474495, -85.34351698662755, 35.633193787404835, -99.21337290676436, -53.75840061783251, -16.235685461308634, -42.87488640530751, 12.217072331810073, -45.28295637382282, 4.698364528087353, -98.32573883189266, -12.216480248138737, -58.01814641697048, 55.74332155094298, -7.93076701646 ...

# %%
# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot the two lists against each other in the first subplot
axs[0].plot(RUL_real, label="RUL_real", marker='o')
axs[0].plot(test1_RUL_Predict, label="RUL_Predict", marker='x')
axs[0].set_title('Comparison of Two Lists')
axs[0].set_xlabel('Unit')
axs[0].set_ylabel('RUL')
axs[0].legend()

# Plot the difference in the second subplot
axs[1].plot(res, label="Difference (Real - Pred)", color='red', marker='s')
axs[1].axhline(0, color='blue', linestyle='--', label="x=0 Line,above is late pred, below is early")  # Add a horizontal line at x=0
axs[1].set_title('Difference Between the Lists')
axs[1].set_xlabel('Unit')
axs[1].set_ylabel('Difference')
axs[1].legend()

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
res_ratio = [(a - b)/((a+b)/2) for a, b in zip(RUL_real, test1_RUL_Predict)]
plt.figure(figsize=(8, 5))
plt.hist(res_ratio, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Residual = 0')  # Reference line at 0
plt.title('sMAPE Distribution')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
res= [a - b for a, b in zip(RUL_real, test1_RUL_Predict)]
plt.figure(figsize=(8, 5))
plt.hist(res, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Residual = 0')  # Reference line at 0
plt.title('residual Distribution')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
def test_dataset_fit_without_ep(test_data_frame):
    RUL_predictions = []

    for unit_number, group in test_data_frame.groupby("Unit_Number"):
        # Get test data for the current unit
        test_data = test_data_frame[test_data_frame["Unit_Number"] == unit_number]

        # Assign clusters to the last segment of the test data
        assigned_clusters = assign_last_segment_to_cluster(
            test_data=test_data,
            features=['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3'],
            cluster_models=cluster_models,
            segments_mapping=segments_mapping
        )

        # Get predictions and weights from all relevant models
        weighted_prediction = calculate_weighted_prediction(test_data, assigned_clusters)
        
        RUL_predictions.append(weighted_prediction)

    return RUL_predictions
    
        
test1_RUL_Predict_2 = test_dataset_fit_without_ep(test1_full)

# %%
res_ratio2 = [(a - b)/((a+b)/2) for a, b in zip(RUL_real, test1_RUL_Predict_2)]

# %%
res_ratio2 = [float(x) for x in res_ratio2]  # Ensure it's a numeric 1D array

# Plot the histogram with adjustments
plt.figure(figsize=(8, 5))
plt.hist(res_ratio2, bins=50, range=(-1, 1), color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Residual = 0')  # Reference line at 0
plt.title('sMAPE Distribution')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# we'll keep the simple expensional in prediction for FD004 too.

# %% [markdown]
# ## check each unit's prediction during its life time

# %%
def predict_unit_life(test_data_frame, unit_number, step=10):
    """
    Predict RUL for a specific unit every `step` data points.

    Args:
        test_data_frame (DataFrame): The dataset containing test data.
        unit_number (int): The unit number to process.
        step (int): The interval at which predictions are made.

    Returns:
        dict: Contains the unit number and its predictions.
    """
    # Filter data for the specified unit and sort by time
    unit_data = test_data_frame[test_data_frame["Unit_Number"] == unit_number].sort_values("Time_in_Cycles")
    predictions = []

    # Generate predictions at every `step`
    for i in range(0, len(unit_data), step):
        # Select the data range for prediction
        data_subset = unit_data.iloc[i:i + step]

        if len(data_subset) < step:  # Skip incomplete steps at the end
            continue

        # Predict RUL for the current subset
        assigned_clusters = assign_last_segment_to_cluster(
            test_data=data_subset,
            features=['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3'],
            cluster_models=cluster_models,
            segments_mapping=segments_mapping
        )

        # Get raw prediction and convert to a numerical value
        prediction = calculate_weighted_prediction(data_subset, assigned_clusters)
        if isinstance(prediction, pd.Series):  # Extract value from Series if needed
            prediction = prediction.values[0]
        predictions.append({"index": i, "prediction": prediction})

    return {"unit_number": unit_number, "predictions": predictions}

# %%
#cherry pick
def calculate_slope_for_all_units(test_data_frame, step=10):
    """
    Loop through all units, calculate predictions, and compute the slope for each unit.

    Args:
        test_data_frame (DataFrame): The dataset containing test data.
        step (int): The interval at which predictions are made.

    Returns:
        list of dict: Each dict contains the unit number, predictions, and slope.
    """
    unit_slopes = []

    for unit_number in test_data_frame["Unit_Number"].unique():
        # Generate predictions for the unit
        unit_result = predict_unit_life(test_data_frame, unit_number, step)

        # Extract predictions and indices
        indices = [p["index"] for p in unit_result["predictions"]]
        values = [p["prediction"] for p in unit_result["predictions"]]

        # Ensure values are numerical
        values = [v for v in values if isinstance(v, (int, float))]

        # Calculate slope using linear regression
        if len(indices) > 1 and len(indices) == len(values):
            slope, _, _, _, _ = linregress(indices, values)
            unit_result["slope"] = slope
        else:
            unit_result["slope"] = None  # Handle cases where slope cannot be calculated

        unit_slopes.append(unit_result)

    return unit_slopes

# %%
unit_slopes = calculate_slope_for_all_units(test1_full, step=10)

# %%
closest_unit = None
min_diff = float("inf")

for unit in unit_slopes:
    if unit["slope"] is not None:
        diff = abs(unit["slope"] - (-1))
        if diff < min_diff:
            min_diff = diff
            closest_unit = unit

# %%
predictions = closest_unit["predictions"]
indices = [p["index"] for p in predictions]
values = [p["prediction"] for p in predictions]

plt.figure(figsize=(10, 6))
plt.plot(indices, values, marker="o", label="RUL Predictions")
plt.title(f"RUL Predictions for Unit {unit['unit_number']} (Slope: {unit['slope']:.2f})")
plt.xlabel("Index (10-Point Step)")
plt.ylabel("RUL Prediction")
plt.legend()
plt.grid()
plt.show()
