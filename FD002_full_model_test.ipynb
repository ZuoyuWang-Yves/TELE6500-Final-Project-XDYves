# %% [markdown]
# # FD002
#
# here we'll build the models for FD002, and test it.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import os

import plotly.express as px
from plotly.subplots import make_subplots


import warnings
# Ignore warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import ruptures as rpt
from scipy.interpolate import interp1d
from scipy.stats import linregress
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import statsmodels.api as sm
from tslearn.clustering import TimeSeriesKMeans
from tslearn.utils import to_time_series_dataset
from joblib import dump, load

# %% [markdown]
# Cause we're treating stationary data as time series, we'll have an un-clustered global linear regression after generating features with a size-20 rolling window.

# %% [markdown]
# ## generates  rolling window features

# %%
# train and test column names
column_names_first_5 = ['Unit_Number', 'Time_in_Cycles', 'Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']

remaining_column_names = [f'Sensor_Measurement_{i}' for i in range(1,22)]

column_names = column_names_first_5 + remaining_column_names

DF_train_FD002 = pd.read_csv("train_FD002.txt", delim_whitespace=True, names=column_names)

# %%
Max_Life_train_FD002 = DF_train_FD002.groupby('Unit_Number')['Time_in_Cycles'].max()
    
DF_train_FD002['Max_Life'] = DF_train_FD002['Unit_Number'].map(Max_Life_train_FD002)
DF_train_FD002['RUL'] = DF_train_FD002['Max_Life'] - DF_train_FD002['Time_in_Cycles']



# no exponential growth features


stationary_data = DF_train_FD002
stationary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unit_Number            53759 non-null  int64
#  1   Time_in_Cycles         53759 non-null  int64
#  2   Operational_Setting_1  53759 non-null  float64
#  3   Operational_Setting_2  53759 non-null  float64
#  4   Operational_Setting_3  53759 non-null  float64
#  5   Sensor_Measurement_1   53759 non-null  float64
#  6   Sensor_Measurement_2   53759 non-null  float64
#  7   Sensor_Measurement_3   53759 non-null  float64
#  8   Sensor_Measurement_4   53759 non-null  float64
#  9   Sensor_Measurement_5   53759 non-null  float64
#  10  Sensor_Measurement_6   53759 non-null  float64
#  11  Sensor_Measurement_7   53759 non-null  float64
#  12  Sensor_Measurement_8   53759 non-null  float64
#  13  Sensor_Measurement_9   53759 non-null  float64
#  14  Sensor_Measurement_10  53759 non-null  float64
#  15  Sensor_Measurement_11  53759 non-null  float64
#  16  Sensor_Measurement_12  53759 non-null  float64
#  17  Sensor_Measurement_13  53759 non-null  float64
#  18  Sensor_Measurement_14  53759 non-null  float64
#  19  Sensor_Measurement_15  53759 non-null  float64
#  20  Sensor_Measurement_16  53759 non-null  float64
#  21  Sensor_Measurement_17  53759 non-null  int64
#  22  Sensor_Measurement_18  53759 non-null  int64
#  23  Sensor_Measurement_19  53759 non-null  float64
#  24  Sensor_Measurement_20  53759 non-null  float64
#  25  Sensor_Measurement_21  53759 non-null  float64
#  26  Max_Life               53759 non-null  int64
#  27  RUL                    53759 non-null  int64
# dtypes: float64(22), int64(6)
# memory usage: 11.5 MB

# %%
features_draft = [col for col in stationary_data.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number']]

window_size = 20

# Create copies to store results
result_df = stationary_data.copy()

# Group the data by Unit_Number to calculate statistics separately for each unit
for feature in features_draft:
    if feature != "Time_in_Cycles":
        # Initialize empty lists to store the computed values
        means = []
        variances = []
        slopes = []

        # Process each unit separately
        for unit, group in stationary_data.groupby("Unit_Number"):
            group = group.sort_values("Time_in_Cycles")  # Ensure data is sorted by time

            # Initialize temporary lists for this feature and unit
            unit_means = []
            unit_variances = []
            unit_slopes = []

            # Iterate over rolling windows
            for i in range(len(group)):
                window = group.iloc[max(0, i - window_size + 1): i + 1]

                # Compute mean and variance
                unit_means.append(window[feature].mean())
                unit_variances.append(window[feature].var())

                # Compute slope if there's enough data
                if len(window) > 1:
                    slope, _, _, _, _ = linregress(window["Time_in_Cycles"], window[feature])
                    unit_slopes.append(slope)
                else:
                    unit_slopes.append(np.nan)

            # Append the computed results to the main lists
            means.extend(unit_means)
            variances.extend(unit_variances)
            slopes.extend(unit_slopes)

        # Add results to the DataFrame
        result_df[f"{feature}_mean"] = means
        result_df[f"{feature}_variance"] = variances
        result_df[f"{feature}_slope"] = slopes

# %%
print(result_df.info())
result_df.to_csv('data.csv', index=False)  # Saves to the current working directory
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 100 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unit_Number                     53759 non-null  int64
#  1   Time_in_Cycles                  53759 non-null  int64
#  2   Operational_Setting_1           53759 non-null  float64
#  3   Operational_Setting_2           53759 non-null  float64
#  4   Operational_Setting_3           53759 non-null  float64
#  5   Sensor_Measurement_1            53759 non-null  float64
#  6   Sensor_Measurement_2            53759 non-null  float64
#  7   Sensor_Measurement_3            53759 non-null  float64
#  8   Sensor_Measurement_4            53759 non-null  float64
#  9   Sensor_Measurement_5            53759 non-null  float64
#  10  Sensor_Measurement_6            53759 non-null  float64
#  11  Sensor_Measurement_7            53759 non-null  float64
#  12  Sensor_Measurement_8            53759 non-null  float64
#  13  Sensor_Measurement_9            53759 non-null  float64
#  14  Sensor_Measurement_10           53759 non-null  float64
#  15  Sensor_Measurement_11           53759 non-null  float64
#  16  Sensor_Measurement_12           53759 non-null  float64
#  17  Sensor_Measurement_13           53759 non-null  float64
#  18  Sensor_Measurement_14           53759 non-null  float64
#  19  Sensor_Measurement_15           53759 non-null  float64
#  20  Sensor_Measurement_16           53759 non-null  float64
#  21  Sensor_Measurement_17           53759 non-null  int64
#  22  Sensor_Measurement_18           53759 non-null  int64
#  23  Sensor_Measurement_19           53759 non-null  float64
#  24  Sensor_Measurement_20           53759 non-null  float64
#  25  Sensor_Measurement_21           53759 non-null  float64
#  26  Max_Life                        53759 non-null  int64
#  27  RUL                             53759 non-null  int64
#  28  Operational_Setting_1_mean      53759 non-null  float64
#  29  Operational_Setting_1_variance  53499 non-null  float64
#  30  Operational_Setting_1_slope     53499 non-null  float64
#  31  Operational_Setting_2_mean      53759 non-null  float64
#  32  Operational_Setting_2_variance  53499 non-null  float64
#  33  Operational_Setting_2_slope     53499 non-null  float64
#  34  Operational_Setting_3_mean      53759 non-null  float64
#  35  Operational_Setting_3_variance  53499 non-null  float64
#  36  Operational_Setting_3_slope     53499 non-null  float64
#  37  Sensor_Measurement_1_mean       53759 non-null  float64
#  38  Sensor_Measurement_1_variance   53499 non-null  float64
#  39  Sensor_Measurement_1_slope      53499 non-null  float64
#  40  Sensor_Measurement_2_mean       53759 non-null  float64
#  41  Sensor_Measurement_2_variance   53499 non-null  float64
#  42  Sensor_Measurement_2_slope      53499 non-null  float64
#  43  Sensor_Measurement_3_mean       53759 non-null  float64
#  44  Sensor_Measurement_3_variance   53499 non-null  float64
#  45  Sensor_Measurement_3_slope      53499 non-null  float64
#  46  Sensor_Measurement_4_mean       53759 non-null  float64
#  47  Sensor_Measurement_4_variance   53499 non-null  float64
#  48  Sensor_Measurement_4_slope      53499 non-null  float64
#  49  Sensor_Measurement_5_mean       53759 non-null  float64
#  50  Sensor_Measurement_5_variance   53499 non-null  float64
#  51  Sensor_Measurement_5_slope      53499 non-null  float64
#  52  Sensor_Measurement_6_mean       53759 non-null  float64
#  53  Sensor_Measurement_6_variance   53499 non-null  float64
#  54  Sensor_Measurement_6_slope      53499 non-null  float64
#  55  Sensor_Measurement_7_mean       53759 non-null  float64
#  56  Sensor_Measurement_7_variance   53499 non-null  float64
#  57  Sensor_Measurement_7_slope      53499 non-null  float64
#  58  Sensor_Measurement_8_mean       53759 non-null  float64
#  59  Sensor_Measurement_8_variance   53499 non-null  float64
#  60  Sensor_Measurement_8_slope      53499 non-null  float64
#  61  Sensor_Measurement_9_mean       53759 non-null  float64
#  62  Sensor_Measurement_9_variance   53499 non-null  float64
#  63  Sensor_Measurement_9_slope      53499 non-null  float64
#  64  Sensor_Measurement_10_mean      53759 non-null  float64
#  65  Sensor_Measurement_10_variance  53499 non-null  float64
#  66  Sensor_Measurement_10_slope     53499 non-null  float64
#  67  Sensor_Measurement_11_mean      53759 non-null  float64
#  68  Sensor_Measurement_11_variance  53499 non-null  float64
#  69  Sensor_Measurement_11_slope     53499 non-null  float64
#  70  Sensor_Measurement_12_mean      53759 non-null  float64
#  71  Sensor_Measurement_12_variance  53499 non-null  float64
#  72  Sensor_Measurement_12_slope     53499 non-null  float64
#  73  Sensor_Measurement_13_mean      53759 non-null  float64
#  74  Sensor_Measurement_13_variance  53499 non-null  float64
#  75  Sensor_Measurement_13_slope     53499 non-null  float64
#  76  Sensor_Measurement_14_mean      53759 non-null  float64
#  77  Sensor_Measurement_14_variance  53499 non-null  float64
#  78  Sensor_Measurement_14_slope     53499 non-null  float64
#  79  Sensor_Measurement_15_mean      53759 non-null  float64
#  80  Sensor_Measurement_15_variance  53499 non-null  float64
#  81  Sensor_Measurement_15_slope     53499 non-null  float64
#  82  Sensor_Measurement_16_mean      53759 non-null  float64
#  83  Sensor_Measurement_16_variance  53499 non-null  float64
#  84  Sensor_Measurement_16_slope     53499 non-null  float64
#  85  Sensor_Measurement_17_mean      53759 non-null  float64
#  86  Sensor_Measurement_17_variance  53499 non-null  float64
#  87  Sensor_Measurement_17_slope     53499 non-null  float64
#  88  Sensor_Measurement_18_mean      53759 non-null  float64
#  89  Sensor_Measurement_18_variance  53499 non-null  float64
#  90  Sensor_Measurement_18_slope     53499 non-null  float64
#  91  Sensor_Measurement_19_mean      53759 non-null  float64
#  92  Sensor_Measurement_19_variance  53499 non-null  float64
#  93  Sensor_Measurement_19_slope     53499 non-null  float64
#  94  Sensor_Measurement_20_mean      53759 non-null  float64
#  95  Sensor_Measurement_20_variance  53499 non-null  float64
#  96  Sensor_Measurement_20_slope     53499 non-null  float64
#  97  Sensor_Measurement_21_mean      53759 non-null  float64
#  98  Sensor_Measurement_21_variance  53499 non-null  float64
#  99  Sensor_Measurement_21_slope     53499 non-null  float64
# dtypes: float64(94), int64(6)
# memory usage: 41.0 MB
# None

# %% [markdown]
# ## generates un-clustered global linear regression

# %%
features_draft = [col for col in result_df.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number']]

result_df = result_df.fillna(0)

# Ensure this loop will refine features_draft until all p-values < 0.05
while True:
    
    # Prepare the features (X) and target (y)
    X = result_df[features_draft]
    y = result_df['RUL']
    
    # Add a constant to the features for the intercept
    X_train_with_const = sm.add_constant(X)
    
    # Fit the linear model
    linear_model2 = sm.OLS(y, X_train_with_const)
    linear_model_fit2 = linear_model2.fit()
    
    # Get p-values and coef
    p_values = linear_model_fit2.pvalues
    params = linear_model_fit2.params
    
    
    # Identify features with p-values > 0.05 or coef == 0
    insignificant_features = params[params == 0].index.tolist()
    insignificant_features = insignificant_features + p_values[p_values > 0.05].index.tolist()
    
    # Exclude 'const' from insignificant features if present
    insignificant_features = [col for col in insignificant_features if col != 'const']
    
    # Break the loop if there are no insignificant features
    if not insignificant_features:
        break
    
    # Update features_draft by removing insignificant features
    features_draft = [col for col in features_draft if col not in insignificant_features]
    

print(linear_model_fit2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     2367.
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        21:54:59   Log-Likelihood:            -2.7547e+05
# No. Observations:               53759   AIC:                         5.510e+05
# Df Residuals:                   53715   BIC:                         5.514e+05
# Df Model:                          43
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                          -3726.6292    324.206    -11.495      0.000   -4362.076   -3091.183
# Time_in_Cycles                    -0.4023      0.004   -103.233      0.000      -0.410      -0.395
# Sensor_Measurement_2               1.9862      0.166     11.958      0.000       1.661       2.312
# Sensor_Measurement_3              -0.2601      0.045     -5.779      0.000      -0.348      -0.172
# Sensor_Measurement_6              14.4335      2.070      6.973      0.000      10.377      18.490
# Sensor_Measurement_9               0.0640      0.018      3.628      0.000       0.029       0.099
# Sensor_Measurement_11            -22.9264      1.291    -17.762      0.000     -25.456     -20.396
# Sensor_Measurement_15            -87.4537      4.697    -18.619      0.000     -96.660     -78.248
# Sensor_Measurement_17             -1.0543      0.182     -5.801      0.000      -1.411      -0.698
# Sensor_Measurement_20             -5.4659      1.427     -3.831      0.000      -8.262      -2.670
# Sensor_Measurement_21             -8.0696      2.388     -3.379      0.001     -12.750      -3.389
# Operational_Setting_1_variance    -0.4072      0.032    -12.697      0.000      -0.470      -0.344
# Operational_Setting_3_variance   -15.2311      2.082     -7.314      0.000     -19.313     -11.150
# Sensor_Measurement_2_mean         -5.9809      0.995     -6.010      0.000      -7.932      -4.030
# Sensor_Measurement_2_variance     -0.0434      0.008     -5.266      0.000      -0.059      -0.027
# Sensor_Measurement_2_slope        15.3887      2.189      7.029      0.000      11.098      19.680
# Sensor_Measurement_3_mean         -1.3196      0.159     -8.289      0.000      -1.632      -1.008
# Sensor_Measurement_3_variance     -0.0089      0.001    -11.439      0.000      -0.010      -0.007
# Sensor_Measurement_3_slope        -2.2020      0.353     -6.230      0.000      -2.895      -1.509
# Sensor_Measurement_4_slope        -0.9360      0.245     -3.826      0.000      -1.416      -0.456
# Sensor_Measurement_5_mean       3285.4144    124.889     26.307      0.000    3040.631    3530.198
# Sensor_Measurement_6_mean      -3141.2374    103.526    -30.343      0.000   -3344.148   -2938.326
# Sensor_Measurement_6_slope      -194.0516     41.158     -4.715      0.000    -274.721    -113.383
# Sensor_Measurement_7_mean         16.2889      1.447     11.256      0.000      13.453      19.125
# Sensor_Measurement_7_slope         7.2386      1.575      4.595      0.000       4.151      10.326
# Sensor_Measurement_8_mean          5.0421      0.336     15.008      0.000       4.384       5.701
# Sensor_Measurement_9_variance      0.0004      0.000      2.766      0.006       0.000       0.001
# Sensor_Measurement_9_slope         0.6814      0.275      2.474      0.013       0.142       1.221
# Sensor_Measurement_10_mean     -1237.5637     85.165    -14.531      0.000   -1404.487   -1070.641
# Sensor_Measurement_11_variance     2.6470      0.893      2.964      0.003       0.896       4.398
# Sensor_Measurement_11_slope     -100.1596     13.043     -7.679      0.000    -125.724     -74.595
# Sensor_Measurement_12_mean        21.4988      1.686     12.754      0.000      18.195      24.803
# Sensor_Measurement_12_variance    -0.0212      0.002    -12.605      0.000      -0.025      -0.018
# Sensor_Measurement_13_variance     0.1923      0.026      7.328      0.000       0.141       0.244
# Sensor_Measurement_14_variance    -0.0031      0.001     -4.469      0.000      -0.004      -0.002
# Sensor_Measurement_15_slope     -214.3926     38.757     -5.532      0.000    -290.357    -138.429
# Sensor_Measurement_16_mean      2593.0022    462.843      5.602      0.000    1685.827    3500.177
# Sensor_Measurement_16_slope     4745.0319   1504.375      3.154      0.002    1796.445    7693.619
# Sensor_Measurement_17_variance     0.0705      0.013      5.560      0.000       0.046       0.095
# Sensor_Measurement_17_slope      -12.5236      1.539     -8.139      0.000     -15.540      -9.508
# Sensor_Measurement_19_variance    -2.1621      0.296     -7.315      0.000      -2.741      -1.583
# Sensor_Measurement_20_mean        23.7891      6.604      3.602      0.000      10.845      36.734
# Sensor_Measurement_20_variance     3.0602      0.300     10.206      0.000       2.473       3.648
# Sensor_Measurement_21_mean       -46.8704     11.324     -4.139      0.000     -69.066     -24.674
# Sensor_Measurement_21_variance     6.3280      0.847      7.468      0.000       4.667       7.989
# ==============================================================================
# Omnibus:                     5512.217   Durbin-Watson:                   0.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7915.140
# Skew:                           0.800   Prob(JB):                         0.00
# Kurtosis:                       3.987   Cond. No.                     1.04e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.25e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Save the model and preprocessed data
dump((linear_model_fit2, X_train_with_const.columns), "FD002unclustered_regression_model_and_columns.joblib")
# Out:
# ['FD002unclustered_regression_model_and_columns.joblib']

# %%
print(result_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 100 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unit_Number                     53759 non-null  int64
#  1   Time_in_Cycles                  53759 non-null  int64
#  2   Operational_Setting_1           53759 non-null  float64
#  3   Operational_Setting_2           53759 non-null  float64
#  4   Operational_Setting_3           53759 non-null  float64
#  5   Sensor_Measurement_1            53759 non-null  float64
#  6   Sensor_Measurement_2            53759 non-null  float64
#  7   Sensor_Measurement_3            53759 non-null  float64
#  8   Sensor_Measurement_4            53759 non-null  float64
#  9   Sensor_Measurement_5            53759 non-null  float64
#  10  Sensor_Measurement_6            53759 non-null  float64
#  11  Sensor_Measurement_7            53759 non-null  float64
#  12  Sensor_Measurement_8            53759 non-null  float64
#  13  Sensor_Measurement_9            53759 non-null  float64
#  14  Sensor_Measurement_10           53759 non-null  float64
#  15  Sensor_Measurement_11           53759 non-null  float64
#  16  Sensor_Measurement_12           53759 non-null  float64
#  17  Sensor_Measurement_13           53759 non-null  float64
#  18  Sensor_Measurement_14           53759 non-null  float64
#  19  Sensor_Measurement_15           53759 non-null  float64
#  20  Sensor_Measurement_16           53759 non-null  float64
#  21  Sensor_Measurement_17           53759 non-null  int64
#  22  Sensor_Measurement_18           53759 non-null  int64
#  23  Sensor_Measurement_19           53759 non-null  float64
#  24  Sensor_Measurement_20           53759 non-null  float64
#  25  Sensor_Measurement_21           53759 non-null  float64
#  26  Max_Life                        53759 non-null  int64
#  27  RUL                             53759 non-null  int64
#  28  Operational_Setting_1_mean      53759 non-null  float64
#  29  Operational_Setting_1_variance  53759 non-null  float64
#  30  Operational_Setting_1_slope     53759 non-null  float64
#  31  Operational_Setting_2_mean      53759 non-null  float64
#  32  Operational_Setting_2_variance  53759 non-null  float64
#  33  Operational_Setting_2_slope     53759 non-null  float64
#  34  Operational_Setting_3_mean      53759 non-null  float64
#  35  Operational_Setting_3_variance  53759 non-null  float64
#  36  Operational_Setting_3_slope     53759 non-null  float64
#  37  Sensor_Measurement_1_mean       53759 non-null  float64
#  38  Sensor_Measurement_1_variance   53759 non-null  float64
#  39  Sensor_Measurement_1_slope      53759 non-null  float64
#  40  Sensor_Measurement_2_mean       53759 non-null  float64
#  41  Sensor_Measurement_2_variance   53759 non-null  float64
#  42  Sensor_Measurement_2_slope      53759 non-null  float64
#  43  Sensor_Measurement_3_mean       53759 non-null  float64
#  44  Sensor_Measurement_3_variance   53759 non-null  float64
#  45  Sensor_Measurement_3_slope      53759 non-null  float64
#  46  Sensor_Measurement_4_mean       53759 non-null  float64
#  47  Sensor_Measurement_4_variance   53759 non-null  float64
#  48  Sensor_Measurement_4_slope      53759 non-null  float64
#  49  Sensor_Measurement_5_mean       53759 non-null  float64
#  50  Sensor_Measurement_5_variance   53759 non-null  float64
#  51  Sensor_Measurement_5_slope      53759 non-null  float64
#  52  Sensor_Measurement_6_mean       53759 non-null  float64
#  53  Sensor_Measurement_6_variance   53759 non-null  float64
#  54  Sensor_Measurement_6_slope      53759 non-null  float64
#  55  Sensor_Measurement_7_mean       53759 non-null  float64
#  56  Sensor_Measurement_7_variance   53759 non-null  float64
#  57  Sensor_Measurement_7_slope      53759 non-null  float64
#  58  Sensor_Measurement_8_mean       53759 non-null  float64
#  59  Sensor_Measurement_8_variance   53759 non-null  float64
#  60  Sensor_Measurement_8_slope      53759 non-null  float64
#  61  Sensor_Measurement_9_mean       53759 non-null  float64
#  62  Sensor_Measurement_9_variance   53759 non-null  float64
#  63  Sensor_Measurement_9_slope      53759 non-null  float64
#  64  Sensor_Measurement_10_mean      53759 non-null  float64
#  65  Sensor_Measurement_10_variance  53759 non-null  float64
#  66  Sensor_Measurement_10_slope     53759 non-null  float64
#  67  Sensor_Measurement_11_mean      53759 non-null  float64
#  68  Sensor_Measurement_11_variance  53759 non-null  float64
#  69  Sensor_Measurement_11_slope     53759 non-null  float64
#  70  Sensor_Measurement_12_mean      53759 non-null  float64
#  71  Sensor_Measurement_12_variance  53759 non-null  float64
#  72  Sensor_Measurement_12_slope     53759 non-null  float64
#  73  Sensor_Measurement_13_mean      53759 non-null  float64
#  74  Sensor_Measurement_13_variance  53759 non-null  float64
#  75  Sensor_Measurement_13_slope     53759 non-null  float64
#  76  Sensor_Measurement_14_mean      53759 non-null  float64
#  77  Sensor_Measurement_14_variance  53759 non-null  float64
#  78  Sensor_Measurement_14_slope     53759 non-null  float64
#  79  Sensor_Measurement_15_mean      53759 non-null  float64
#  80  Sensor_Measurement_15_variance  53759 non-null  float64
#  81  Sensor_Measurement_15_slope     53759 non-null  float64
#  82  Sensor_Measurement_16_mean      53759 non-null  float64
#  83  Sensor_Measurement_16_variance  53759 non-null  float64
#  84  Sensor_Measurement_16_slope     53759 non-null  float64
#  85  Sensor_Measurement_17_mean      53759 non-null  float64
#  86  Sensor_Measurement_17_variance  53759 non-null  float64
#  87  Sensor_Measurement_17_slope     53759 non-null  float64
#  88  Sensor_Measurement_18_mean      53759 non-null  float64
#  89  Sensor_Measurement_18_variance  53759 non-null  float64
#  90  Sensor_Measurement_18_slope     53759 non-null  float64
#  91  Sensor_Measurement_19_mean      53759 non-null  float64
#  92  Sensor_Measurement_19_variance  53759 non-null  float64
#  93  Sensor_Measurement_19_slope     53759 non-null  float64
#  94  Sensor_Measurement_20_mean      53759 non-null  float64
#  95  Sensor_Measurement_20_variance  53759 non-null  float64
#  96  Sensor_Measurement_20_slope     53759 non-null  float64
#  97  Sensor_Measurement_21_mean      53759 non-null  float64
#  98  Sensor_Measurement_21_variance  53759 non-null  float64
#  99  Sensor_Measurement_21_slope     53759 non-null  float64
# dtypes: float64(94), int64(6)
# memory usage: 41.0 MB
# None

# %% [markdown]
# ## clustering

# %%
def normalize_segment_length(segment, length=100):
    if len(segment) == 0:  # Handle empty segments
        return np.zeros(length)
    x = np.linspace(0, 1, len(segment))
    f = interp1d(x, segment, kind='linear', fill_value="extrapolate")
    x_new = np.linspace(0, 1, length)
    return f(x_new)

# Initialize storage for normalized segments and mappings
normalized_segments = {}
segments_mapping = {}

# Features to segment and cluster
features = ['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']


# Loop through each feature
for feature in features:
    normalized_segments[feature] = []
    segments_mapping[feature] = []
    
    # Segment time series for each unit
    for unit in stationary_data['Unit_Number'].unique():
        # Extract unit data
        unit_data = stationary_data[stationary_data['Unit_Number'] == unit]
        
        # Scale the feature values
        scaler = StandardScaler()
        scaled_data = scaler.fit_transform(unit_data[feature].values.reshape(-1, 1)).flatten()
        
        # Detect change points using Ruptures
        model = rpt.Pelt(model="l2").fit(scaled_data)
        change_points = model.predict(pen=10)  # Adjust `pen` for granularity
        
        # Normalize each segment and store mapping information
        for start, end in zip([0] + change_points[:-1], change_points):
            segment = scaled_data[start:end]
            normalized_segment = normalize_segment_length(segment, length=100)
            
            normalized_segments[feature].append(normalized_segment)
            segments_mapping[feature].append({
                "unit_number": unit,
                "start_idx": start,
                "end_idx": end
            })

# %%
cluster_labels = {}
cluster_models = {}
k = 3  # Number of clusters (adjust as needed)

for feature, segments in normalized_segments.items():
    # Convert normalized segments to time-series dataset
    ts_data = to_time_series_dataset(segments)
    
    # Perform DTW clustering
    model = TimeSeriesKMeans(n_clusters=k, metric="dtw", random_state=42)
    labels = model.fit_predict(ts_data)
    
    # Store cluster labels and the trained model
    cluster_labels[feature] = labels
    cluster_models[feature] = model

# %%
for feature, model in cluster_models.items():
    plt.figure(figsize=(10, 6))
    for i, centroid in enumerate(model.cluster_centers_):
        plt.plot(centroid.ravel(), label=f"Cluster {i}")
    plt.title(f"Cluster Centroids for {feature}")
    plt.legend()
    plt.show()

# %%
for feature, labels in cluster_labels.items():
    # Count the number of segments in each cluster
    unique, counts = np.unique(labels, return_counts=True)
    cluster_sizes = dict(zip(unique, counts))
    
    plt.figure(figsize=(4, 3))
    plt.bar(unique, counts, tick_label=[f"Cluster {i}" for i in unique])
    plt.title(f"Cluster Sizes for {feature}")
    plt.xlabel("Cluster")
    plt.ylabel("Number of Segments")
    plt.show()
    
    # Print the cluster sizes
    print(f"Cluster sizes for {feature}:")
    for cluster, size in cluster_sizes.items():
        print(f"  Cluster {cluster}: {size} segments")
# Out:
# Cluster sizes for Operational_Setting_1:
#   Cluster 0: 87 segments
#   Cluster 1: 95 segments
#   Cluster 2: 85 segments
# Cluster sizes for Operational_Setting_2:
#   Cluster 0: 74 segments
#   Cluster 1: 95 segments
#   Cluster 2: 101 segments
# Cluster sizes for Operational_Setting_3:
#   Cluster 0: 204 segments
#   Cluster 1: 8 segments
#   Cluster 2: 79 segments

# %%
model_save_path = "clustering_models"

# Save each clustering model in the cluster_models dictionary
for feature, model in cluster_models.items():
    model_filename = f"{model_save_path}/FD002{feature}_clustering_model.pkl"
    dump(model, model_filename)
    
# # Load the saved clustering models
# loaded_cluster_models = {}

# for feature in normalized_segments.keys():
#     model_filename = f"{model_save_path}/{feature}_clustering_model.pkl"
#     loaded_cluster_models[feature] = joblib.load(model_filename)

# %% [markdown]
# ## linear regression for each cluster

# %%
# Create a mapping of cluster assignments to original rows
cluster_to_original_rows = {}

for feature, labels in cluster_labels.items():
    cluster_to_original_rows[feature] = []
    for i, label in enumerate(labels):
        metadata = segments_mapping[feature][i]
        unit_number = metadata["unit_number"]
        start_idx = metadata["start_idx"]
        end_idx = metadata["end_idx"]
        
        # Map each original row in the segment to the cluster
        cluster_to_original_rows[feature].append({
            "unit_number": unit_number,
            "start_idx": start_idx,
            "end_idx": end_idx,
            "cluster": label
        })

# %%
def get_windowdf_rows_by_cluster(feature, cluster_id):
    original_rows = []
    for mapping in cluster_to_original_rows[feature]:
        if mapping["cluster"] == cluster_id:
            unit = mapping["unit_number"]
            start, end = mapping["start_idx"], mapping["end_idx"]
            
            # Retrieve the original rows for the segment
            rows = result_df[
                (result_df["Unit_Number"] == unit) &
                (result_df["Time_in_Cycles"] >= start) &
                (result_df["Time_in_Cycles"] < end)
            ]
            original_rows.append(rows)
    
    return pd.concat(original_rows)

# %%
print(features)
# Out:
# ['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']

# %%
level2_models = {}

for cluster_feature in features:
    for cluster_number_id in range(3):
        
        cluster_rows = get_windowdf_rows_by_cluster(cluster_feature, cluster_number_id)

        features_draft = [col for col in cluster_rows.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number','Time_in_Cycles_mean','Time_in_Cycles_variance','Time_in_Cycles_slope']]

        cluster_rows = cluster_rows.fillna(0)

        X = cluster_rows[features_draft]
        y = cluster_rows['RUL']
        X_train_with_const = sm.add_constant(X)


        linear_model = sm.OLS(y, X_train_with_const)
        linear_model_fit = linear_model.fit()

        # Get the p-values from the fitted model
        p_values = linear_model_fit.pvalues

        # Filter for columns with p-value > 0.05
        insignificant_features = p_values[p_values > 0.05].index.tolist()

        features_draft = [col for col in features_draft if col not in insignificant_features]

        t_stats = linear_model_fit.tvalues

        # Sort the t-statistics by absolute value
        sorted_features_by_tstat = t_stats.abs().sort_values(ascending=False)

        filtered_t_stats = {key: value for key, value in t_stats.items() if key in features_draft}
        t_stats_df = pd.DataFrame(list(filtered_t_stats.items()), columns=["Feature", "T_Value"])

        # Identify sensor-stationary pairs
        sensor_pairs = []
        for feature in t_stats_df['Feature']:
            if "_stationary" in feature:
                original = feature.replace("_stationary", "")
                if original in t_stats_df['Feature'].values:
                    sensor_pairs.append((original, feature))


        kept_features = []

        for original, stationary in sensor_pairs:
            t_original = t_stats_df.loc[t_stats_df['Feature'] == original, 'T_Value'].values[0]
            t_stationary = t_stats_df.loc[t_stats_df['Feature'] == stationary, 'T_Value'].values[0]
            if abs(t_stationary) > abs(t_original):
                if original in features_draft: 
                    features_draft.remove(original)
            else:
                if stationary in features_draft: features_draft.remove(stationary)

        # Ensure this loop will refine features_draft until all p-values < 0.05
        while True:

            # Prepare the features (X) and target (y)
            X = cluster_rows[features_draft]
            y = cluster_rows['RUL']
            X_train_with_const = sm.add_constant(X)

            # Fit the linear model
            linear_model2 = sm.OLS(y, X_train_with_const)
            linear_model_fit2 = linear_model2.fit()

            # Get p-values
            p_values = linear_model_fit2.pvalues

            # Identify features with p-values > 0.05
            insignificant_features = p_values[p_values > 0.05].index.tolist()

            # Exclude 'const' from insignificant features if present
            insignificant_features = [col for col in insignificant_features if col != 'const']

            # Break the loop if there are no insignificant features
            if not insignificant_features:
                break

            # Update features_draft by removing insignificant features
            features_draft = [col for col in features_draft if col not in insignificant_features]

        level2_models[f'{cluster_feature},{cluster_number_id}'] = (linear_model_fit2,linear_model_fit2.summary())
        dump((linear_model_fit2, X_train_with_const.columns), f"FD002{cluster_feature}_c{cluster_number_id}_model_and_columns.joblib")
# Out:
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1749: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1749: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)

# %%
print(level2_models)
# Out:
# {'Operational_Setting_1,0': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd12d86d370>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     670.1
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        21:55:47   Log-Likelihood:                -88153.
# No. Observations:               17087   AIC:                         1.764e+05
# Df Residuals:                   17043   BIC:                         1.767e+05
# Df Model:                          43
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           3445.2369   1125.885      3.060      0.002    1238.386    5652.088
# Time_in_Cycles                    -0.3427      0.007    -46.295      0.000      -0.357      -0.328
# Sensor_Measurement_2               3.6062      0.290     12.429      0.000       3.037       4.175
# Sensor_Measurement_3              -0.4256      0.081     -5.230      0.000      -0.585      -0.266
# Sensor_Measurement_11            -26.7902      2.554    -10.489      0.000     -31.796     -21.784
# Sensor_Measurement_14              0.3914      0.063      6.185      0.000       0.267       0.515
# Sensor_Measurement_15            -57.5861      7.712     -7.467      0.000     -72.702     -42.470
# Sensor_Measurement_17             -1.8218      0.338     -5.393      0.000      -2.484      -1.160
# Sensor_Measurement_21             -3.0648      0.403     -7.608      0.000      -3.854      -2.275
# Operational_Setting_2_variance   483.3304    115.118      4.199      0.000     257.688     708.973
# Operational_Setting_3_variance   -48.9718      7.036     -6.960      0.000     -62.763     -35.181
# Sensor_Measurement_1_variance     -0.1571      0.027     -5.744      0.000      -0.211      -0.103
# Sensor_Measurement_2_mean         17.6782      1.281     13.801      0.000      15.167      20.189
# Sensor_Measurement_3_mean         -3.2899      0.322    -10.216      0.000      -3.921      -2.659
# Sensor_Measurement_3_variance     -0.0068      0.001     -4.615      0.000      -0.010      -0.004
# Sensor_Measurement_3_slope         1.8553      0.481      3.861      0.000       0.913       2.797
# Sensor_Measurement_4_mean         -0.6512      0.282     -2.306      0.021      -1.205      -0.098
# Sensor_Measurement_4_slope        -1.8127      0.418     -4.341      0.000      -2.631      -0.994
# Sensor_Measurement_5_mean       -900.6818    178.781     -5.038      0.000   -1251.111    -550.252
# Sensor_Measurement_5_variance   -136.0901     26.340     -5.167      0.000    -187.719     -84.461
# Sensor_Measurement_6_mean        438.6755    116.735      3.758      0.000     209.862     667.488
# Sensor_Measurement_6_variance     97.7838     17.922      5.456      0.000      62.654     132.914
# Sensor_Measurement_6_slope      -146.1240     32.004     -4.566      0.000    -208.855     -83.393
# Sensor_Measurement_8_variance     -0.5161      0.082     -6.293      0.000      -0.677      -0.355
# Sensor_Measurement_9_mean         -0.7044      0.119     -5.911      0.000      -0.938      -0.471
# Sensor_Measurement_10_mean       285.3504    142.293      2.005      0.045       6.441     564.260
# Sensor_Measurement_11_mean       -85.5377     10.042     -8.518      0.000    -105.221     -65.854
# Sensor_Measurement_11_variance    11.3576      1.703      6.668      0.000       8.019      14.696
# Sensor_Measurement_12_variance    -0.0793      0.011     -7.080      0.000      -0.101      -0.057
# Sensor_Measurement_13_mean        -1.5168      0.482     -3.145      0.002      -2.462      -0.572
# Sensor_Measurement_13_variance     0.6238      0.089      7.027      0.000       0.450       0.798
# Sensor_Measurement_13_slope       -1.9095      0.318     -6.006      0.000      -2.533      -1.286
# Sensor_Measurement_14_variance    -0.0044      0.001     -3.089      0.002      -0.007      -0.002
# Sensor_Measurement_15_slope     -309.5631     57.249     -5.407      0.000    -421.776    -197.350
# Sensor_Measurement_16_mean      7433.3556   1055.607      7.042      0.000    5364.257    9502.454
# Sensor_Measurement_16_variance -1.471e+06   2.33e+05     -6.302      0.000   -1.93e+06   -1.01e+06
# Sensor_Measurement_16_slope    -1.199e+04   3137.358     -3.823      0.000   -1.81e+04   -5844.047
# Sensor_Measurement_17_mean         8.1600      1.412      5.778      0.000       5.392      10.928
# Sensor_Measurement_17_variance     0.1737      0.024      7.370      0.000       0.128       0.220
# Sensor_Measurement_18_variance     0.5062      0.082      6.200      0.000       0.346       0.666
# Sensor_Measurement_19_variance    -7.1850      0.999     -7.191      0.000      -9.144      -5.226
# Sensor_Measurement_20_mean        80.6281     12.102      6.662      0.000      56.906     104.350
# Sensor_Measurement_20_variance     3.2049      0.544      5.890      0.000       2.138       4.272
# Sensor_Measurement_20_slope       79.2584     17.662      4.488      0.000      44.640     113.877
# Sensor_Measurement_21_variance     3.2369      1.527      2.120      0.034       0.244       6.230
# ==============================================================================
# Omnibus:                     1723.765   Durbin-Watson:                   0.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2556.263
# Skew:                           0.771   Prob(JB):                         0.00
# Kurtosis:                       4.102   Cond. No.                     1.05e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.11e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_1,1': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd12d86d4c0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.675
# Method:                 Least Squares   F-statistic:                     1168.
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        21:55:48   Log-Likelihood:            -1.0092e+05
# No. Observations:               19674   AIC:                         2.019e+05
# Df Residuals:                   19638   BIC:                         2.022e+05
# Df Model:                          35
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                          -9282.0188   1828.540     -5.076      0.000   -1.29e+04   -5697.925
# Time_in_Cycles                    -0.3389      0.006    -53.960      0.000      -0.351      -0.327
# Sensor_Measurement_2               1.4749      0.218      6.774      0.000       1.048       1.902
# Sensor_Measurement_3              -0.2188      0.074     -2.971      0.003      -0.363      -0.074
# Sensor_Measurement_4              -0.1005      0.022     -4.605      0.000      -0.143      -0.058
# Sensor_Measurement_11             -8.3078      1.375     -6.043      0.000     -11.003      -5.613
# Sensor_Measurement_15            -46.1167      5.090     -9.059      0.000     -56.094     -36.139
# Sensor_Measurement_17             -0.8412      0.299     -2.818      0.005      -1.426      -0.256
# Operational_Setting_1_mean        31.4003      2.583     12.155      0.000      26.337      36.464
# Operational_Setting_1_variance    -0.2937      0.050     -5.867      0.000      -0.392      -0.196
# Sensor_Measurement_2_mean        -41.5507      3.698    -11.235      0.000     -48.800     -34.302
# Sensor_Measurement_2_variance      0.0448      0.013      3.325      0.001       0.018       0.071
# Sensor_Measurement_3_mean          1.2356      0.291      4.244      0.000       0.665       1.806
# Sensor_Measurement_3_variance     -0.0103      0.001     -8.217      0.000      -0.013      -0.008
# Sensor_Measurement_3_slope        -2.5094      0.614     -4.087      0.000      -3.713      -1.306
# Sensor_Measurement_4_variance     -0.0031      0.001     -3.392      0.001      -0.005      -0.001
# Sensor_Measurement_5_mean       6089.4677    342.734     17.767      0.000    5417.680    6761.255
# Sensor_Measurement_6_mean      -5186.4471    265.170    -19.559      0.000   -5706.202   -4666.692
# Sensor_Measurement_7_mean         17.3874      2.473      7.030      0.000      12.539      22.236
# Sensor_Measurement_7_variance      0.0185      0.008      2.294      0.022       0.003       0.034
# Sensor_Measurement_8_variance      0.2119      0.016     13.269      0.000       0.181       0.243
# Sensor_Measurement_9_slope         1.4877      0.211      7.037      0.000       1.073       1.902
# Sensor_Measurement_11_mean       -43.4622      8.872     -4.899      0.000     -60.852     -26.072
# Sensor_Measurement_12_mean        32.4393      2.916     11.126      0.000      26.724      38.154
# Sensor_Measurement_12_variance    -0.0391      0.009     -4.264      0.000      -0.057      -0.021
# Sensor_Measurement_15_mean       111.8958     48.817      2.292      0.022      16.211     207.580
# Sensor_Measurement_15_variance   134.7204     18.311      7.357      0.000      98.829     170.612
# Sensor_Measurement_16_mean      5962.7864    806.407      7.394      0.000    4382.161    7543.412
# Sensor_Measurement_17_variance     0.0671      0.020      3.331      0.001       0.028       0.107
# Sensor_Measurement_17_slope       -9.0887      2.264     -4.014      0.000     -13.527      -4.650
# Sensor_Measurement_18_mean        19.0198      1.715     11.092      0.000      15.659      22.381
# Sensor_Measurement_18_variance    -0.2137      0.016    -13.380      0.000      -0.245      -0.182
# Sensor_Measurement_19_mean      -119.8950     36.069     -3.324      0.001    -190.593     -49.197
# Sensor_Measurement_20_mean       -28.6554     11.256     -2.546      0.011     -50.718      -6.593
# Sensor_Measurement_20_variance     2.8337      0.530      5.344      0.000       1.794       3.873
# Sensor_Measurement_21_variance     3.8620      1.484      2.602      0.009       0.952       6.772
# ==============================================================================
# Omnibus:                     1869.895   Durbin-Watson:                   0.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2586.268
# Skew:                           0.772   Prob(JB):                         0.00
# Kurtosis:                       3.878   Cond. No.                     2.97e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """), 'Operational_Setting_1,2': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd13cd993a0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.706
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        21:55:49   Log-Likelihood:                -83367.
# No. Observations:               16738   AIC:                         1.668e+05
# Df Residuals:                   16701   BIC:                         1.671e+05
# Df Model:                          36
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           1.765e+04   1451.358     12.163      0.000    1.48e+04    2.05e+04
# Time_in_Cycles                    -0.5354      0.007    -76.121      0.000      -0.549      -0.522
# Sensor_Measurement_2               1.5220      0.202      7.519      0.000       1.125       1.919
# Sensor_Measurement_3              -0.2638      0.068     -3.894      0.000      -0.397      -0.131
# Sensor_Measurement_4              -0.0415      0.019     -2.207      0.027      -0.078      -0.005
# Sensor_Measurement_15            -28.0270      3.780     -7.414      0.000     -35.437     -20.617
# Sensor_Measurement_17             -1.5028      0.269     -5.577      0.000      -2.031      -0.975
# Operational_Setting_1_variance    -0.5945      0.059    -10.053      0.000      -0.710      -0.479
# Operational_Setting_2_mean       817.8343    110.967      7.370      0.000     600.327    1035.341
# Sensor_Measurement_1_variance      0.1722      0.023      7.615      0.000       0.128       0.217
# Sensor_Measurement_2_mean        -15.8612      3.319     -4.778      0.000     -22.367      -9.355
# Sensor_Measurement_2_variance     -0.0920      0.019     -4.836      0.000      -0.129      -0.055
# Sensor_Measurement_2_slope        15.1154      3.353      4.508      0.000       8.544      21.687
# Sensor_Measurement_3_mean         -1.0510      0.262     -4.006      0.000      -1.565      -0.537
# Sensor_Measurement_3_variance     -0.0089      0.001     -7.045      0.000      -0.011      -0.006
# Sensor_Measurement_3_slope        -2.0958      0.572     -3.667      0.000      -3.216      -0.975
# Sensor_Measurement_4_slope        -2.1990      0.446     -4.934      0.000      -3.073      -1.325
# Sensor_Measurement_6_mean       -232.1612     55.452     -4.187      0.000    -340.854    -123.469
# Sensor_Measurement_7_mean         10.8658      2.082      5.220      0.000       6.786      14.946
# Sensor_Measurement_7_variance     -0.0449      0.007     -6.357      0.000      -0.059      -0.031
# Sensor_Measurement_8_mean          9.1742      1.580      5.806      0.000       6.077      12.271
# Sensor_Measurement_8_slope        -2.0781      0.350     -5.942      0.000      -2.764      -1.393
# Sensor_Measurement_9_mean          0.2709      0.094      2.882      0.004       0.087       0.455
# Sensor_Measurement_9_variance      0.0014      0.000      8.591      0.000       0.001       0.002
# Sensor_Measurement_9_slope         1.2306      0.405      3.038      0.002       0.437       2.025
# Sensor_Measurement_11_mean        29.7612      8.298      3.587      0.000      13.497      46.026
# Sensor_Measurement_11_slope     -146.5422     18.487     -7.927      0.000    -182.778    -110.306
# Sensor_Measurement_12_variance     0.0296      0.008      3.741      0.000       0.014       0.045
# Sensor_Measurement_13_mean       -30.1862      8.071     -3.740      0.000     -46.006     -14.366
# Sensor_Measurement_15_mean      -477.4202     46.487    -10.270      0.000    -568.539    -386.301
# Sensor_Measurement_15_slope     -717.1093     82.330     -8.710      0.000    -878.484    -555.734
# Sensor_Measurement_16_mean      3827.5569    732.684      5.224      0.000    2391.418    5263.696
# Sensor_Measurement_19_mean       451.5678    196.126      2.302      0.021      67.141     835.995
# Sensor_Measurement_20_variance     1.8356      0.475      3.865      0.000       0.905       2.766
# Sensor_Measurement_21_mean       -52.5322     16.673     -3.151      0.002     -85.213     -19.852
# Sensor_Measurement_21_variance     8.2451      1.336      6.171      0.000       5.626      10.864
# Sensor_Measurement_21_slope      -40.4905      6.061     -6.680      0.000     -52.371     -28.610
# ==============================================================================
# Omnibus:                      833.032   Durbin-Watson:                   0.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              962.317
# Skew:                           0.585   Prob(JB):                    1.09e-209
# Kurtosis:                       3.099   Cond. No.                     6.48e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.48e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """), 'Operational_Setting_2,0': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd12c7868b0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     550.7
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        21:55:50   Log-Likelihood:                -69215.
# No. Observations:               13550   AIC:                         1.385e+05
# Df Residuals:                   13502   BIC:                         1.389e+05
# Df Model:                          47
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           6.026e+04   3.16e+04      1.908      0.056   -1648.662    1.22e+05
# Time_in_Cycles                    -0.4218      0.009    -47.854      0.000      -0.439      -0.404
# Sensor_Measurement_2               0.9537      0.369      2.587      0.010       0.231       1.676
# Sensor_Measurement_3              -0.3077      0.086     -3.572      0.000      -0.477      -0.139
# Sensor_Measurement_4              -0.1213      0.027     -4.463      0.000      -0.175      -0.068
# Sensor_Measurement_9               0.1578      0.058      2.730      0.006       0.045       0.271
# Sensor_Measurement_11            -10.6620      2.076     -5.136      0.000     -14.731      -6.593
# Sensor_Measurement_15            -38.5593      6.748     -5.714      0.000     -51.786     -25.333
# Sensor_Measurement_17             -1.1857      0.375     -3.165      0.002      -1.920      -0.451
# Operational_Setting_1_mean      -143.5152     38.220     -3.755      0.000    -218.432     -68.598
# Operational_Setting_1_variance    -0.5822      0.066     -8.840      0.000      -0.711      -0.453
# Operational_Setting_1_slope      308.0468     58.349      5.279      0.000     193.674     422.419
# Operational_Setting_2_slope    -3084.0230    406.525     -7.586      0.000   -3880.869   -2287.177
# Operational_Setting_3_mean      2965.8457    912.973      3.249      0.001    1176.290    4755.401
# Operational_Setting_3_variance   -32.4930      6.636     -4.897      0.000     -45.499     -19.486
# Operational_Setting_3_slope    -6871.0739   1367.687     -5.024      0.000   -9551.932   -4190.216
# Sensor_Measurement_1_mean        954.7552    261.579      3.650      0.000     442.023    1467.487
# Sensor_Measurement_1_slope     -2195.1457    443.147     -4.954      0.000   -3063.775   -1326.516
# Sensor_Measurement_2_mean        -33.5458      4.367     -7.682      0.000     -42.105     -24.987
# Sensor_Measurement_3_mean         -1.5293      0.343     -4.455      0.000      -2.202      -0.856
# Sensor_Measurement_4_mean          1.6856      0.290      5.804      0.000       1.116       2.255
# Sensor_Measurement_4_slope        -5.6688      0.635     -8.926      0.000      -6.914      -4.424
# Sensor_Measurement_5_mean       3795.1914    531.848      7.136      0.000    2752.695    4837.688
# Sensor_Measurement_6_mean      -3950.8350    375.636    -10.518      0.000   -4687.133   -3214.537
# Sensor_Measurement_7_mean          8.9708      3.234      2.774      0.006       2.632      15.310
# Sensor_Measurement_7_variance      0.0309      0.009      3.386      0.001       0.013       0.049
# Sensor_Measurement_7_slope        23.4955      6.646      3.535      0.000      10.469      36.522
# Sensor_Measurement_8_variance     -0.3122      0.083     -3.767      0.000      -0.475      -0.150
# Sensor_Measurement_9_mean          0.6977      0.281      2.484      0.013       0.147       1.248
# Sensor_Measurement_10_mean     -4501.4939    764.706     -5.887      0.000   -6000.424   -3002.564
# Sensor_Measurement_11_slope     -164.1101     29.206     -5.619      0.000    -221.358    -106.862
# Sensor_Measurement_12_mean        30.8037      3.965      7.769      0.000      23.032      38.575
# Sensor_Measurement_12_variance    -0.0604      0.010     -5.829      0.000      -0.081      -0.040
# Sensor_Measurement_13_mean        37.4161      9.984      3.748      0.000      17.847      56.985
# Sensor_Measurement_13_variance     0.4106      0.084      4.907      0.000       0.247       0.575
# Sensor_Measurement_14_mean        -1.5906      0.305     -5.207      0.000      -2.189      -0.992
# Sensor_Measurement_15_variance   144.8632     16.950      8.547      0.000     111.640     178.087
# Sensor_Measurement_15_slope     -608.0098    137.366     -4.426      0.000    -877.266    -338.754
# Sensor_Measurement_16_mean     -3836.0433    965.779     -3.972      0.000   -5729.105   -1942.982
# Sensor_Measurement_16_slope    -9106.3642   3363.652     -2.707      0.007   -1.57e+04   -2513.136
# Sensor_Measurement_17_mean         3.7081      1.429      2.594      0.009       0.906       6.510
# Sensor_Measurement_17_slope      -13.9656      3.152     -4.430      0.000     -20.145      -7.786
# Sensor_Measurement_18_mean      -376.7498    107.095     -3.518      0.000    -586.672    -166.828
# Sensor_Measurement_18_variance     0.3065      0.083      3.701      0.000       0.144       0.469
# Sensor_Measurement_18_slope      918.6331    181.937      5.049      0.000     562.012    1275.255
# Sensor_Measurement_19_variance    -4.6121      0.942     -4.897      0.000      -6.458      -2.766
# Sensor_Measurement_19_slope    -2588.6771    515.276     -5.024      0.000   -3598.690   -1578.664
# Sensor_Measurement_20_variance     2.8196      0.626      4.505      0.000       1.593       4.047
# Sensor_Measurement_20_slope      121.2832     26.408      4.593      0.000      69.519     173.047
# Sensor_Measurement_21_variance     9.4451      1.678      5.629      0.000       6.156      12.734
# ==============================================================================
# Omnibus:                     1492.306   Durbin-Watson:                   0.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2244.277
# Skew:                           0.820   Prob(JB):                         0.00
# Kurtosis:                       4.133   Cond. No.                     1.03e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.98e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_2,1': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd12c786490>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.706
# Model:                            OLS   Adj. R-squared:                  0.705
# Method:                 Least Squares   F-statistic:                     783.9
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        21:55:51   Log-Likelihood:                -99703.
# No. Observations:               19687   AIC:                         1.995e+05
# Df Residuals:                   19626   BIC:                         2.000e+05
# Df Model:                          60
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            153.9985     12.999     11.847      0.000     128.519     179.478
# Time_in_Cycles                    -0.3290      0.006    -52.861      0.000      -0.341      -0.317
# Sensor_Measurement_2               2.1409      0.271      7.896      0.000       1.610       2.672
# Sensor_Measurement_3              -0.1705      0.070     -2.424      0.015      -0.308      -0.033
# Sensor_Measurement_4              -0.2120      0.062     -3.435      0.001      -0.333      -0.091
# Sensor_Measurement_11             -9.1471      2.145     -4.265      0.000     -13.351      -4.943
# Sensor_Measurement_15            -78.1651      9.699     -8.059      0.000     -97.176     -59.154
# Sensor_Measurement_17             -0.7549      0.285     -2.651      0.008      -1.313      -0.197
# Sensor_Measurement_19             -3.9766      0.861     -4.621      0.000      -5.664      -2.290
# Sensor_Measurement_21             -4.4870      0.768     -5.841      0.000      -5.993      -2.981
# Operational_Setting_1_mean     -1198.3917     91.248    -13.133      0.000   -1377.245   -1019.538
# Operational_Setting_1_variance    -0.2382      0.106     -2.241      0.025      -0.447      -0.030
# Operational_Setting_2_mean      1.276e+04    839.693     15.198      0.000    1.11e+04    1.44e+04
# Operational_Setting_2_variance   312.9492    111.368      2.810      0.005      94.658     531.240
# Operational_Setting_3_mean      2.481e+04   1858.484     13.351      0.000    2.12e+04    2.85e+04
# Operational_Setting_3_variance   -42.9909      5.759     -7.465      0.000     -54.279     -31.702
# Sensor_Measurement_1_mean       8940.5799    666.932     13.406      0.000    7633.337    1.02e+04
# Sensor_Measurement_2_mean        -24.0603      3.590     -6.701      0.000     -31.098     -17.023
# Sensor_Measurement_2_variance     -0.0715      0.022     -3.271      0.001      -0.114      -0.029
# Sensor_Measurement_2_slope       -28.4518      6.214     -4.578      0.000     -40.633     -16.271
# Sensor_Measurement_3_mean         -0.7041      0.277     -2.545      0.011      -1.246      -0.162
# Sensor_Measurement_3_variance     -0.0128      0.001     -9.982      0.000      -0.015      -0.010
# Sensor_Measurement_3_slope        -2.4415      0.622     -3.926      0.000      -3.660      -1.223
# Sensor_Measurement_4_mean          1.6664      0.259      6.437      0.000       1.159       2.174
# Sensor_Measurement_4_variance      0.0023      0.001      2.101      0.036       0.000       0.004
# Sensor_Measurement_4_slope        -4.7488      0.540     -8.788      0.000      -5.808      -3.690
# Sensor_Measurement_5_variance    126.5645     26.435      4.788      0.000      74.750     178.379
# Sensor_Measurement_6_mean      -3734.1357    249.130    -14.989      0.000   -4222.451   -3245.821
# Sensor_Measurement_6_variance    -88.8636     17.838     -4.982      0.000    -123.827     -53.900
# Sensor_Measurement_6_slope      -567.7061     79.253     -7.163      0.000    -723.048    -412.364
# Sensor_Measurement_7_mean         11.3922      2.656      4.289      0.000       6.186      16.599
# Sensor_Measurement_7_variance     -0.0357      0.008     -4.280      0.000      -0.052      -0.019
# Sensor_Measurement_7_slope        21.3580      3.104      6.880      0.000      15.273      27.443
# Sensor_Measurement_8_mean         97.4269     26.468      3.681      0.000      45.548     149.306
# Sensor_Measurement_8_variance     -0.2125      0.073     -2.919      0.004      -0.355      -0.070
# Sensor_Measurement_8_slope        30.1948      3.275      9.220      0.000      23.776      36.614
# Sensor_Measurement_9_mean         -1.5127      0.227     -6.665      0.000      -1.958      -1.068
# Sensor_Measurement_9_variance      0.0012      0.000      3.621      0.000       0.001       0.002
# Sensor_Measurement_10_mean      2044.2523    604.245      3.383      0.001     859.881    3228.624
# Sensor_Measurement_10_variance -4592.3838   1068.039     -4.300      0.000   -6685.831   -2498.936
# Sensor_Measurement_11_mean       -62.9528      9.478     -6.642      0.000     -81.530     -44.375
# Sensor_Measurement_11_variance    11.2907      1.551      7.281      0.000       8.251      14.330
# Sensor_Measurement_11_slope      -83.7633     20.777     -4.032      0.000    -124.488     -43.038
# Sensor_Measurement_12_variance     0.0619      0.011      5.831      0.000       0.041       0.083
# Sensor_Measurement_13_mean       -87.4923     24.823     -3.525      0.000    -136.147     -38.838
# Sensor_Measurement_13_variance     0.5382      0.073      7.391      0.000       0.395       0.681
# Sensor_Measurement_13_slope      -27.0569      2.586    -10.464      0.000     -32.125     -21.989
# Sensor_Measurement_14_mean         1.5883      0.262      6.064      0.000       1.075       2.102
# Sensor_Measurement_15_mean      -195.9370     49.174     -3.985      0.000    -292.322     -99.552
# Sensor_Measurement_15_slope     -898.8499     98.168     -9.156      0.000   -1091.268    -706.431
# Sensor_Measurement_16_mean      1.509e+04   1057.858     14.265      0.000     1.3e+04    1.72e+04
# Sensor_Measurement_16_variance -1.341e+06   2.51e+05     -5.337      0.000   -1.83e+06   -8.49e+05
# Sensor_Measurement_16_slope    -1.847e+04   3544.527     -5.210      0.000   -2.54e+04   -1.15e+04
# Sensor_Measurement_17_variance     0.1240      0.021      5.895      0.000       0.083       0.165
# Sensor_Measurement_17_slope      -12.7274      2.566     -4.961      0.000     -17.756      -7.698
# Sensor_Measurement_18_mean     -3746.2524    275.526    -13.597      0.000   -4286.307   -3206.198
# Sensor_Measurement_18_variance     0.2132      0.072      2.948      0.003       0.071       0.355
# Sensor_Measurement_19_mean      1.895e+04   1386.801     13.662      0.000    1.62e+04    2.17e+04
# Sensor_Measurement_19_variance    -7.5918      0.844     -8.994      0.000      -9.246      -5.937
# Sensor_Measurement_20_mean        78.8724     10.692      7.377      0.000      57.916      99.829
# Sensor_Measurement_20_variance     1.7944      0.514      3.492      0.000       0.787       2.802
# Sensor_Measurement_21_mean       -78.0627     17.799     -4.386      0.000    -112.951     -43.175
# Sensor_Measurement_21_variance    12.1649      1.451      8.383      0.000       9.321      15.009
# ==============================================================================
# Omnibus:                     1767.118   Durbin-Watson:                   0.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2437.940
# Skew:                           0.738   Prob(JB):                         0.00
# Kurtosis:                       3.890   Cond. No.                     1.32e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.77e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_2,2': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd12d861f10>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.645
# Model:                            OLS   Adj. R-squared:                  0.645
# Method:                 Least Squares   F-statistic:                     751.0
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        21:55:52   Log-Likelihood:            -1.0363e+05
# No. Observations:               20262   AIC:                         2.074e+05
# Df Residuals:                   20212   BIC:                         2.078e+05
# Df Model:                          49
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           -123.4236     16.674     -7.402      0.000    -156.105     -90.742
# Time_in_Cycles                    -0.4076      0.007    -61.295      0.000      -0.421      -0.395
# Sensor_Measurement_2               3.3578      0.255     13.179      0.000       2.858       3.857
# Sensor_Measurement_3              -0.2512      0.070     -3.568      0.000      -0.389      -0.113
# Sensor_Measurement_4              -0.4973      0.064     -7.802      0.000      -0.622      -0.372
# Sensor_Measurement_11            -19.2750      2.216     -8.698      0.000     -23.619     -14.931
# Sensor_Measurement_14              0.6659      0.062     10.820      0.000       0.545       0.786
# Sensor_Measurement_15            -38.8518      6.280     -6.187      0.000     -51.160     -26.543
# Sensor_Measurement_17             -1.2687      0.306     -4.146      0.000      -1.869      -0.669
# Sensor_Measurement_19             -3.3703      0.657     -5.128      0.000      -4.659      -2.082
# Operational_Setting_1_mean      1245.4493    165.412      7.529      0.000     921.228    1569.671
# Operational_Setting_1_variance    -0.8450      0.083    -10.137      0.000      -1.008      -0.682
# Operational_Setting_2_mean     -1.114e+04   1641.017     -6.789      0.000   -1.44e+04   -7924.973
# Operational_Setting_2_variance  -572.5736    132.219     -4.330      0.000    -831.734    -313.413
# Operational_Setting_3_mean     -2.329e+04   3257.795     -7.150      0.000   -2.97e+04   -1.69e+04
# Operational_Setting_3_variance    28.0731      6.177      4.545      0.000      15.966      40.180
# Sensor_Measurement_1_mean      -8454.6487   1177.969     -7.177      0.000   -1.08e+04   -6145.733
# Sensor_Measurement_2_mean        -16.0162      3.446     -4.648      0.000     -22.771      -9.262
# Sensor_Measurement_2_slope        12.2042      3.028      4.030      0.000       6.269      18.140
# Sensor_Measurement_3_variance     -0.0109      0.001     -8.180      0.000      -0.013      -0.008
# Sensor_Measurement_3_slope        -2.6571      0.579     -4.586      0.000      -3.793      -1.521
# Sensor_Measurement_4_mean         -2.2659      0.233     -9.745      0.000      -2.722      -1.810
# Sensor_Measurement_4_variance     -0.0044      0.001     -4.238      0.000      -0.006      -0.002
# Sensor_Measurement_5_mean       8252.0241    779.462     10.587      0.000    6724.215    9779.833
# Sensor_Measurement_6_mean      -2350.2757    290.134     -8.101      0.000   -2918.961   -1781.590
# Sensor_Measurement_7_mean          8.4442      2.609      3.237      0.001       3.331      13.557
# Sensor_Measurement_7_variance      0.0292      0.008      3.849      0.000       0.014       0.044
# Sensor_Measurement_8_variance      0.4392      0.076      5.765      0.000       0.290       0.588
# Sensor_Measurement_9_mean          0.8179      0.219      3.743      0.000       0.390       1.246
# Sensor_Measurement_9_variance      0.0012      0.000      4.552      0.000       0.001       0.002
# Sensor_Measurement_9_slope         1.2835      0.412      3.116      0.002       0.476       2.091
# Sensor_Measurement_10_mean      5163.8529    668.934      7.720      0.000    3852.688    6475.018
# Sensor_Measurement_10_variance  8047.7727   1166.018      6.902      0.000    5762.283    1.03e+04
# Sensor_Measurement_11_slope      -94.3468     17.339     -5.441      0.000    -128.334     -60.360
# Sensor_Measurement_12_variance    -0.0482      0.009     -5.599      0.000      -0.065      -0.031
# Sensor_Measurement_13_variance    -0.3422      0.078     -4.405      0.000      -0.494      -0.190
# Sensor_Measurement_13_slope       -0.6341      0.172     -3.682      0.000      -0.972      -0.297
# Sensor_Measurement_14_mean        -1.3394      0.252     -5.318      0.000      -1.833      -0.846
# Sensor_Measurement_14_variance    -0.0101      0.002     -6.560      0.000      -0.013      -0.007
# Sensor_Measurement_15_variance  -150.8541     32.874     -4.589      0.000    -215.289     -86.419
# Sensor_Measurement_15_slope     -464.7197     72.201     -6.436      0.000    -606.239    -323.200
# Sensor_Measurement_16_mean      3894.3666   1051.266      3.704      0.000    1833.799    5954.934
# Sensor_Measurement_16_variance  5.755e+05   2.47e+05      2.331      0.020    9.15e+04    1.06e+06
# Sensor_Measurement_17_mean         4.7555      1.163      4.088      0.000       2.475       7.036
# Sensor_Measurement_17_variance     0.1182      0.021      5.749      0.000       0.078       0.158
# Sensor_Measurement_17_slope      -13.9557      2.518     -5.541      0.000     -18.892      -9.019
# Sensor_Measurement_18_mean      3471.8358    482.937      7.189      0.000    2525.241    4418.431
# Sensor_Measurement_18_variance    -0.4464      0.076     -5.863      0.000      -0.596      -0.297
# Sensor_Measurement_19_mean     -1.647e+04   2266.171     -7.267      0.000   -2.09e+04    -1.2e+04
# Sensor_Measurement_19_variance     3.9940      0.877      4.556      0.000       2.276       5.712
# Sensor_Measurement_20_variance     4.7205      0.525      8.985      0.000       3.691       5.750
# Sensor_Measurement_20_slope      -17.6783      3.766     -4.694      0.000     -25.061     -10.296
# ==============================================================================
# Omnibus:                     2033.664   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2834.528
# Skew:                           0.803   Prob(JB):                         0.00
# Kurtosis:                       3.881   Cond. No.                     1.32e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.92e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """), 'Operational_Setting_3,0': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd13cd640d0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.676
# Method:                 Least Squares   F-statistic:                     1630.
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        21:55:55   Log-Likelihood:            -2.0954e+05
# No. Observations:               41375   AIC:                         4.192e+05
# Df Residuals:                   41321   BIC:                         4.197e+05
# Df Model:                          53
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              0.9597      0.260      3.692      0.000       0.450       1.469
# Time_in_Cycles                    -0.3892      0.004    -87.724      0.000      -0.398      -0.381
# Sensor_Measurement_2               1.8771      0.261      7.190      0.000       1.365       2.389
# Sensor_Measurement_3              -0.2253      0.049     -4.625      0.000      -0.321      -0.130
# Sensor_Measurement_4              -0.3520      0.042     -8.370      0.000      -0.434      -0.270
# Sensor_Measurement_9               0.1793      0.034      5.224      0.000       0.112       0.247
# Sensor_Measurement_11            -15.7082      1.443    -10.883      0.000     -18.537     -12.879
# Sensor_Measurement_15            -96.9257      6.796    -14.263      0.000    -110.245     -83.606
# Sensor_Measurement_17             -1.0766      0.204     -5.265      0.000      -1.477      -0.676
# Sensor_Measurement_19             -5.6360      0.562    -10.030      0.000      -6.737      -4.535
# Sensor_Measurement_21             -5.4980      0.532    -10.336      0.000      -6.541      -4.455
# Operational_Setting_1_variance    -0.3226      0.047     -6.892      0.000      -0.414      -0.231
# Operational_Setting_2_mean       606.3586    210.319      2.883      0.004     194.128    1018.589
# Operational_Setting_3_mean       863.6597     92.277      9.359      0.000     682.795    1044.525
# Operational_Setting_3_variance    -6.5849      2.514     -2.619      0.009     -11.512      -1.657
# Sensor_Measurement_1_mean        301.2276     30.114     10.003      0.000     242.203     360.253
# Sensor_Measurement_1_variance      0.1682      0.018      9.488      0.000       0.133       0.203
# Sensor_Measurement_2_mean        -26.1498      2.309    -11.325      0.000     -30.675     -21.624
# Sensor_Measurement_2_variance     -0.2208      0.017    -12.747      0.000      -0.255      -0.187
# Sensor_Measurement_2_slope        31.4238      1.856     16.928      0.000      27.785      35.062
# Sensor_Measurement_3_mean         -1.1455      0.181     -6.314      0.000      -1.501      -0.790
# Sensor_Measurement_3_variance     -0.0072      0.001     -8.396      0.000      -0.009      -0.006
# Sensor_Measurement_3_slope        -2.5641      0.381     -6.727      0.000      -3.311      -1.817
# Sensor_Measurement_4_variance     -0.0023      0.001     -3.492      0.000      -0.004      -0.001
# Sensor_Measurement_4_slope        -3.0662      0.340     -9.019      0.000      -3.733      -2.400
# Sensor_Measurement_5_mean       4014.1795    300.114     13.376      0.000    3425.949    4602.410
# Sensor_Measurement_6_mean      -3253.2835    193.135    -16.845      0.000   -3631.832   -2874.735
# Sensor_Measurement_6_slope      -663.2635     61.582    -10.770      0.000    -783.965    -542.562
# Sensor_Measurement_7_mean         11.3775      1.750      6.502      0.000       7.948      14.807
# Sensor_Measurement_7_variance     -0.0194      0.002    -10.756      0.000      -0.023      -0.016
# Sensor_Measurement_7_slope         7.9515      3.112      2.555      0.011       1.852      14.051
# Sensor_Measurement_8_mean         41.4081      6.030      6.867      0.000      29.589      53.227
# Sensor_Measurement_9_mean         -0.6824      0.080     -8.565      0.000      -0.839      -0.526
# Sensor_Measurement_9_variance      0.0022      0.000     11.377      0.000       0.002       0.003
# Sensor_Measurement_10_mean      1905.3126    428.030      4.451      0.000    1066.364    2744.261
# Sensor_Measurement_11_variance     3.8657      1.036      3.732      0.000       1.835       5.896
# Sensor_Measurement_11_slope     -108.8352     14.965     -7.273      0.000    -138.167     -79.504
# Sensor_Measurement_12_mean        11.5437      2.203      5.241      0.000       7.226      15.861
# Sensor_Measurement_12_slope       10.9069      3.374      3.233      0.001       4.294      17.520
# Sensor_Measurement_13_variance     0.0819      0.032      2.586      0.010       0.020       0.144
# Sensor_Measurement_13_slope       -3.3047      0.266    -12.411      0.000      -3.827      -2.783
# Sensor_Measurement_14_variance    -0.0045      0.001     -5.528      0.000      -0.006      -0.003
# Sensor_Measurement_15_slope     -574.4206     63.156     -9.095      0.000    -698.207    -450.634
# Sensor_Measurement_16_mean      4460.5021    642.477      6.943      0.000    3201.233    5719.772
# Sensor_Measurement_16_variance -4.368e+05   1.24e+05     -3.535      0.000   -6.79e+05   -1.95e+05
# Sensor_Measurement_16_slope    -8158.6775   2050.215     -3.979      0.000   -1.22e+04   -4140.212
# Sensor_Measurement_17_mean         2.4531      0.759      3.231      0.001       0.965       3.941
# Sensor_Measurement_17_variance     0.0870      0.014      6.257      0.000       0.060       0.114
# Sensor_Measurement_17_slope      -11.9416      1.653     -7.223      0.000     -15.182      -8.701
# Sensor_Measurement_18_mean      -149.7943     13.562    -11.045      0.000    -176.376    -123.213
# Sensor_Measurement_19_mean       385.2014     47.615      8.090      0.000     291.875     478.528
# Sensor_Measurement_19_variance    -0.9468      0.357     -2.652      0.008      -1.647      -0.247
# Sensor_Measurement_20_variance     2.8253      0.333      8.476      0.000       2.172       3.479
# Sensor_Measurement_20_slope       84.3229     12.550      6.719      0.000      59.725     108.921
# Sensor_Measurement_21_mean       -37.4729     12.195     -3.073      0.002     -61.374     -13.571
# Sensor_Measurement_21_variance     5.5219      0.955      5.779      0.000       3.649       7.395
# ==============================================================================
# Omnibus:                     3950.817   Durbin-Watson:                   0.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5729.272
# Skew:                           0.749   Prob(JB):                         0.00
# Kurtosis:                       4.038   Cond. No.                     1.57e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.52e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# ...
# Df Model:                          37
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Time_in_Cycles                    -0.3383        inf         -0        nan         nan         nan
# Operational_Setting_1             -1.7005        inf         -0        nan         nan         nan
# Operational_Setting_2              0.0179        inf          0        nan         nan         nan
# Operational_Setting_3              0.1840        inf          0        nan         nan         nan
# Sensor_Measurement_1              -0.4970        inf         -0        nan         nan         nan
# Sensor_Measurement_2               2.2822        inf          0        nan         nan         nan
# Sensor_Measurement_3              -0.2422        inf         -0        nan         nan         nan
# Sensor_Measurement_4               0.1359        inf          0        nan         nan         nan
# Sensor_Measurement_5               0.3479        inf          0        nan         nan         nan
# Sensor_Measurement_6               0.8248        inf          0        nan         nan         nan
# Sensor_Measurement_7              -0.3996        inf         -0        nan         nan         nan
# Sensor_Measurement_8              -0.4004        inf         -0        nan         nan         nan
# Sensor_Measurement_9              -0.1037        inf         -0        nan         nan         nan
# Sensor_Measurement_10             -0.0023        inf         -0        nan         nan         nan
# Sensor_Measurement_11             -4.2031        inf         -0        nan         nan         nan
# Sensor_Measurement_12             -0.1807        inf         -0        nan         nan         nan
# Sensor_Measurement_13              0.7375        inf          0        nan         nan         nan
# Sensor_Measurement_14              0.1352        inf          0        nan         nan         nan
# Sensor_Measurement_15             -0.0014        inf         -0        nan         nan         nan
# Sensor_Measurement_16          -5.497e-05        inf         -0        nan         nan         nan
# Sensor_Measurement_17             -0.6530        inf         -0        nan         nan         nan
# Sensor_Measurement_18             -0.3607        inf         -0        nan         nan         nan
# Sensor_Measurement_19             -0.1020        inf         -0        nan         nan         nan
# Sensor_Measurement_20              4.7929        inf          0        nan         nan         nan
# Sensor_Measurement_21              0.8090        inf          0        nan         nan         nan
# Operational_Setting_1_mean         0.9198        inf          0        nan         nan         nan
# Operational_Setting_1_variance    -0.0616        inf         -0        nan         nan         nan
# Operational_Setting_1_slope       -0.2698        inf         -0        nan         nan         nan
# Operational_Setting_2_mean        -0.0979        inf         -0        nan         nan         nan
# Operational_Setting_2_variance     0.0122        inf          0        nan         nan         nan
# Operational_Setting_2_slope        0.0055        inf          0        nan         nan         nan
# Operational_Setting_3_mean         0.1354        inf          0        nan         nan         nan
# Operational_Setting_3_variance     2.1621        inf          0        nan         nan         nan
# Operational_Setting_3_slope       -0.2286        inf         -0        nan         nan         nan
# Sensor_Measurement_1_mean          0.6552        inf          0        nan         nan         nan
# Sensor_Measurement_1_variance     -0.3347        inf         -0        nan         nan         nan
# Sensor_Measurement_1_slope         0.7620        inf          0        nan         nan         nan
# Sensor_Measurement_2_mean         -0.9921        inf         -0        nan         nan         nan
# Sensor_Measurement_2_variance      0.5423        inf          0        nan         nan         nan
# Sensor_Measurement_2_slope         0.4120        inf          0        nan         nan         nan
# Sensor_Measurement_3_mean          2.2292        inf          0        nan         nan         nan
# Sensor_Measurement_3_variance     -0.0250        inf         -0        nan         nan         nan
# Sensor_Measurement_3_slope        -5.2136        inf         -0        nan         nan         nan
# Sensor_Measurement_4_mean          1.6443        inf          0        nan         nan         nan
# Sensor_Measurement_4_variance     -0.0118        inf         -0        nan         nan         nan
# Sensor_Measurement_4_slope        -1.7832        inf         -0        nan         nan         nan
# Sensor_Measurement_5_mean         -0.1076        inf         -0        nan         nan         nan
# Sensor_Measurement_5_variance      0.3487        inf          0        nan         nan         nan
# Sensor_Measurement_5_slope        -0.0185        inf         -0        nan         nan         nan
# Sensor_Measurement_6_mean         -0.0934        inf         -0        nan         nan         nan
# Sensor_Measurement_6_variance      0.5027        inf          0        nan         nan         nan
# Sensor_Measurement_6_slope        -0.0543        inf         -0        nan         nan         nan
# Sensor_Measurement_7_mean          0.0571        inf          0        nan         nan         nan
# Sensor_Measurement_7_variance     -0.1873        inf         -0        nan         nan         nan
# Sensor_Measurement_7_slope        -1.7899        inf         -0        nan         nan         nan
# Sensor_Measurement_8_mean          1.5902        inf          0        nan         nan         nan
# Sensor_Measurement_8_variance      0.2099        inf          0        nan         nan         nan
# Sensor_Measurement_8_slope         0.0479        inf          0        nan         nan         nan
# Sensor_Measurement_9_mean         -2.7528        inf         -0        nan         nan         nan
# Sensor_Measurement_9_variance      0.0003        inf          0        nan         nan         nan
# Sensor_Measurement_9_slope         4.5335        inf          0        nan         nan         nan
# Sensor_Measurement_10_mean         0.0325        inf          0        nan         nan         nan
# Sensor_Measurement_10_variance    -0.0006        inf         -0        nan         nan         nan
# Sensor_Measurement_10_slope        0.0011        inf          0        nan         nan         nan
# Sensor_Measurement_11_mean         0.0590        inf          0        nan         nan         nan
# Sensor_Measurement_11_variance    -0.8691        inf         -0        nan         nan         nan
# Sensor_Measurement_11_slope        0.0177        inf          0        nan         nan         nan
# Sensor_Measurement_12_mean         0.2067        inf          0        nan         nan         nan
# Sensor_Measurement_12_variance     0.2042        inf          0        nan         nan         nan
# Sensor_Measurement_12_slope       -1.1060        inf         -0        nan         nan         nan
# Sensor_Measurement_13_mean        -2.5571        inf         -0        nan         nan         nan
# Sensor_Measurement_13_variance    -0.0291        inf         -0        nan         nan         nan
# Sensor_Measurement_13_slope       -1.8483        inf         -0        nan         nan         nan
# Sensor_Measurement_14_mean         1.9482        inf          0        nan         nan         nan
# Sensor_Measurement_14_variance     0.0184        inf          0        nan         nan         nan
# Sensor_Measurement_14_slope       -2.0623        inf         -0        nan         nan         nan
# Sensor_Measurement_15_mean        -0.2876        inf         -0        nan         nan         nan
# Sensor_Measurement_15_variance     0.0392        inf          0        nan         nan         nan
# Sensor_Measurement_15_slope        0.0317        inf          0        nan         nan         nan
# Sensor_Measurement_16_mean         0.0020        inf          0        nan         nan         nan
# Sensor_Measurement_16_variance -4.664e-06        inf         -0        nan         nan         nan
# Sensor_Measurement_16_slope        0.0002        inf          0        nan         nan         nan
# Sensor_Measurement_17_mean         4.2144        inf          0        nan         nan         nan
# Sensor_Measurement_17_variance     0.0640        inf          0        nan         nan         nan
# Sensor_Measurement_17_slope        0.0588        inf          0        nan         nan         nan
# Sensor_Measurement_18_mean         1.4436        inf          0        nan         nan         nan
# Sensor_Measurement_18_variance    -0.2180        inf         -0        nan         nan         nan
# Sensor_Measurement_18_slope        0.0495        inf          0        nan         nan         nan
# Sensor_Measurement_19_mean        -0.1203        inf         -0        nan         nan         nan
# Sensor_Measurement_19_variance     0.3069        inf          0        nan         nan         nan
# Sensor_Measurement_19_slope       -0.0861        inf         -0        nan         nan         nan
# Sensor_Measurement_20_mean         0.2664        inf          0        nan         nan         nan
# Sensor_Measurement_20_variance    -0.3913        inf         -0        nan         nan         nan
# Sensor_Measurement_20_slope       -0.1270        inf         -0        nan         nan         nan
# Sensor_Measurement_21_mean        -0.2999        inf         -0        nan         nan         nan
# Sensor_Measurement_21_variance     1.4735        inf          0        nan         nan         nan
# Sensor_Measurement_21_slope       -0.1290        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        1.867   Durbin-Watson:                   0.282
# Prob(Omnibus):                  0.393   Jarque-Bera (JB):                1.498
# Skew:                           0.313   Prob(JB):                        0.473
# Kurtosis:                       2.256   Cond. No.                     3.64e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 3.64e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """), 'Operational_Setting_3,2': (<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fd13cbe89a0>, <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RUL   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.600
# Method:                 Least Squares   F-statistic:                     627.3
# Date:                Sun, 15 Dec 2024   Prob (F-statistic):               0.00
# Time:                        21:55:56   Log-Likelihood:                -63612.
# No. Observations:               12086   AIC:                         1.273e+05
# Df Residuals:                   12056   BIC:                         1.275e+05
# Df Model:                          29
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           9103.2608    959.536      9.487      0.000    7222.416     1.1e+04
# Time_in_Cycles                    -0.3938      0.009    -41.962      0.000      -0.412      -0.375
# Sensor_Measurement_4              -0.1509      0.030     -5.024      0.000      -0.210      -0.092
# Sensor_Measurement_11            -15.5003      1.896     -8.176      0.000     -19.216     -11.784
# Sensor_Measurement_15            -35.9327      4.611     -7.792      0.000     -44.972     -26.893
# Sensor_Measurement_17              1.5203      0.203      7.496      0.000       1.123       1.918
# Operational_Setting_3_variance   -76.0355      8.270     -9.194      0.000     -92.246     -59.825
# Sensor_Measurement_2_variance      0.1291      0.019      6.686      0.000       0.091       0.167
# Sensor_Measurement_2_slope        15.3660      3.810      4.033      0.000       7.898      22.834
# Sensor_Measurement_3_variance     -0.0193      0.002    -10.037      0.000      -0.023      -0.016
# Sensor_Measurement_5_mean        769.2177    104.591      7.355      0.000     564.202     974.233
# Sensor_Measurement_6_mean      -1072.2366    110.265     -9.724      0.000   -1288.374    -856.100
# Sensor_Measurement_7_variance      0.0400      0.011      3.579      0.000       0.018       0.062
# Sensor_Measurement_8_variance     -0.7599      0.101     -7.546      0.000      -0.957      -0.563
# Sensor_Measurement_9_mean          1.3487      0.127     10.635      0.000       1.100       1.597
# Sensor_Measurement_9_variance     -0.0031      0.000     -6.972      0.000      -0.004      -0.002
# Sensor_Measurement_9_slope        -1.5990      0.588     -2.718      0.007      -2.752      -0.446
# Sensor_Measurement_11_variance     8.6505      2.075      4.169      0.000       4.583      12.717
# Sensor_Measurement_11_slope      -77.3775     23.137     -3.344      0.001    -122.730     -32.025
# Sensor_Measurement_12_mean        13.1209      1.886      6.958      0.000       9.425      16.817
# Sensor_Measurement_12_variance    -0.0383      0.013     -3.032      0.002      -0.063      -0.014
# Sensor_Measurement_13_variance     0.9486      0.104      9.097      0.000       0.744       1.153
# Sensor_Measurement_14_mean        -1.8542      0.160    -11.597      0.000      -2.168      -1.541
# Sensor_Measurement_15_slope     -460.5177     77.194     -5.966      0.000    -611.830    -309.206
# Sensor_Measurement_16_mean     -3354.7286   1193.126     -2.812      0.005   -5693.447   -1016.010
# Sensor_Measurement_16_variance   1.04e+06   2.29e+05      4.534      0.000     5.9e+05    1.49e+06
# Sensor_Measurement_17_mean       -13.3216      1.272    -10.470      0.000     -15.816     -10.828
# Sensor_Measurement_18_variance     0.7739      0.101      7.687      0.000       0.577       0.971
# Sensor_Measurement_19_variance   -10.6668      1.178     -9.052      0.000     -12.977      -8.357
# Sensor_Measurement_20_mean       126.6408     12.187     10.392      0.000     102.753     150.529
# Sensor_Measurement_21_slope      -15.6069      4.166     -3.746      0.000     -23.774      -7.440
# ==============================================================================
# Omnibus:                     1031.753   Durbin-Watson:                   0.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1315.569
# Skew:                           0.774   Prob(JB):                    2.13e-286
# Kurtosis:                       3.462   Cond. No.                     1.04e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.71e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """)}

# %% [markdown]
# # testing

# %%
column_names_first_5 = ['Unit_Number', 'Time_in_Cycles', 'Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3']

remaining_column_names = [f'Sensor_Measurement_{i}' for i in range(1,22)]

column_names = column_names_first_5 + remaining_column_names

test1 = pd.read_csv("test_FD002.txt", delim_whitespace=True, names=column_names)

# %% [markdown]
# ## generate columns for testing data

# %%
def generate_remaining_columns(df):
    
    rolling_columns = [col for col in df.columns if col not in ['Max_Life', 'RUL', 'normalized_time','Unit_Number']]


    result = []
    window_size = 20

    for unit, group in df.groupby("Unit_Number"):
        group = group.sort_values("Time_in_Cycles")  # Ensure data is sorted by time

        for feature in rolling_columns:
            if feature in group.columns:
                # Initialize temporary lists for this feature and unit
                unit_means = []
                unit_variances = []
                unit_slopes = []

                # Iterate over rolling windows
                for i in range(len(group)):
                    window = group.iloc[max(0, i - window_size + 1): i + 1]

                    # Compute mean and variance
                    unit_means.append(window[feature].mean())
                    unit_variances.append(window[feature].var())

                    # Compute slope if there's enough data
                    if len(window) > 1:
                        slope, _, _, _, _ = linregress(window["Time_in_Cycles"], window[feature])
                        unit_slopes.append(slope)
                    else:
                        unit_slopes.append(np.nan)

                # Add new columns to the group
                group[f'{feature}_mean'] = unit_means
                group[f'{feature}_variance'] = unit_variances
                group[f'{feature}_slope'] = unit_slopes

        # Append the processed group to the result
        result.append(group)

    # Concatenate all processed groups back together
    final_df = pd.concat(result, axis=0).reset_index(drop=True)

    return final_df

# %%
test1_full = generate_remaining_columns(test1)

# %% [markdown]
# ## assign each unit's last segment to its cluster

# %%
def assign_last_segment_to_cluster(test_data, features, cluster_models, segments_mapping):
    assigned_clusters = {}

    for feature in features:
        # Extract test data for the feature
        test_feature_data = test_data[feature].values

        # Scale the test feature
        scaler = StandardScaler()
        scaled_test_feature = scaler.fit_transform(test_feature_data.reshape(-1, 1)).flatten()

        # Detect change points using Ruptures
        model = rpt.Pelt(model="l2").fit(scaled_test_feature)
        change_points = model.predict(pen=10)  # Use the same penalty as training

        # Extract the last segment
        start_idx = change_points[-2] if len(change_points) > 1 else 0
        end_idx = len(scaled_test_feature)
        last_segment = scaled_test_feature[start_idx:end_idx]

        # Normalize the last segment
        normalized_last_segment = normalize_segment_length(last_segment, length=100)

        # Convert to the correct format for the model
        normalized_last_segment = normalized_last_segment.reshape(1, -1)

        # Assign the last segment to the closest cluster
        cluster_model = cluster_models[feature]
        cluster_label = cluster_model.predict(normalized_last_segment)[0]

        # Store the result
        assigned_clusters[feature] = {
            "cluster_label": cluster_label,
            "start_idx": start_idx,
            "end_idx": end_idx
        }

    return assigned_clusters

# %%
test_data = test1_full[test1_full["Unit_Number"] == 1]

assigned_clusters = assign_last_segment_to_cluster(
    test_data=test_data,
    features=['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3'],
    cluster_models=cluster_models,
    segments_mapping=segments_mapping
)
# Out:
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/tslearn/utils/utils.py:90: UserWarning: 2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries
#   warnings.warn(
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/tslearn/utils/utils.py:90: UserWarning: 2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries
#   warnings.warn(
# /Users/xd/opt/anaconda3/lib/python3.9/site-packages/tslearn/utils/utils.py:90: UserWarning: 2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries
#   warnings.warn(

# %%
print(assigned_clusters)
# Out:
# {'Operational_Setting_1': {'cluster_label': 0, 'start_idx': 0, 'end_idx': 258}, 'Operational_Setting_2': {'cluster_label': 0, 'start_idx': 0, 'end_idx': 258}, 'Operational_Setting_3': {'cluster_label': 0, 'start_idx': 0, 'end_idx': 258}}

# %% [markdown]
# ## get weighted prediction based on assigned clusters

# %%
def calculate_weighted_prediction(test_data, assigned_clusters, df_threshold=5):
    total_weight = 0
    weighted_sum = 0

    # Iterate through the assigned clusters
    for cluster_feature, details in assigned_clusters.items():
        cluster_number_id = details["cluster_label"]

        # Retrieve the corresponding model and its details
        model_key = f"{cluster_feature},{cluster_number_id}"
        model_fit, summary = level2_models[model_key]
        r2_value = model_fit.rsquared
        df_model = model_fit.df_model  # Degree of freedom of the model

        # Calculate scaling factor based on df_model
        scaling_factor = min(1, df_model / df_threshold)

        # Final weight for the model
        weight = r2_value * scaling_factor

        # Load the saved model and its features
        filename = f"FD002{cluster_feature}_c{cluster_number_id}_model_and_columns.joblib"
        linear_model_fit2, model_features = load(filename)

        # Prepare the test data for the model
        test_data = test_data.copy()
        test_data["const"] = 1  # Add intercept
        filtered_data = test_data[model_features].fillna(0)

        # Get the prediction for the current model
        filtered_data_last = filtered_data.iloc[-1]  # Use the last row of test data
        prediction = linear_model_fit2.predict(filtered_data_last)

        # Accumulate the weighted sum and total weight
        weighted_sum += prediction * weight
        total_weight += weight

    # Calculate the weighted average prediction
    if total_weight > 0:
        return weighted_sum / total_weight
    else:
        return 0  # Handle edge case where no models have a valid weight

# %%
import warnings
from statsmodels.tsa.api import SimpleExpSmoothing

# Ignore specific warning from tslearn
warnings.filterwarnings("ignore", message="2-Dimensional data passed. Assuming these are 1 1-dimensional timeseries")

# Ignore SettingWithCopyWarning globally
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)


def test_dataset_fit(test_data_frame):
    RUL_predictions = []

    for unit_number, group in test_data_frame.groupby("Unit_Number"):
        # Get test data for the current unit
        test_data = test_data_frame[test_data_frame["Unit_Number"] == unit_number]

        # Assign clusters to the last segment of the test data
        assigned_clusters = assign_last_segment_to_cluster(
            test_data=test_data,
            features=['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3'],
            cluster_models=cluster_models,
            segments_mapping=segments_mapping
        )

        # Get predictions and weights from all relevant models
        weighted_prediction = calculate_weighted_prediction(test_data, assigned_clusters)

        # Use exponential smoothing to stabilize predictions
        y_train = []
        for i in range(1, 11):  # Take the last 10 data points
            prediction = weighted_prediction
            y_train.append(prediction)

        fit3 = SimpleExpSmoothing(y_train, initialization_method="estimated").fit()
        fcast3 = fit3.forecast(1)
        RUL_predictions.append(fcast3[0])

    return RUL_predictions
    
        
test1_RUL_Predict = test_dataset_fit(test1_full)

# %%
RUL_real = pd.read_csv("RUL_FD002.txt",names=['RUL'])  # Replace "file.csv" with your actual file path

# # Extract the integers into a list
RUL_real = RUL_real.iloc[:, 0].tolist()  # Assuming the integers are in the first column
print(RUL_real)

res = [a - b for a, b in zip(RUL_real, test1_RUL_Predict)]

print(res)
# Out:
# [18, 79, 106, 110, 15, 155, 6, 90, 11, 79, 6, 73, 30, 11, 37, 67, 68, 99, 22, 54, 97, 10, 142, 77, 88, 163, 126, 138, 83, 78, 75, 11, 53, 173, 63, 100, 151, 55, 48, 37, 44, 27, 18, 6, 15, 112, 131, 13, 122, 13, 98, 53, 52, 106, 103, 152, 123, 26, 178, 73, 169, 39, 39, 14, 11, 121, 86, 56, 115, 17, 148, 104, 78, 86, 98, 36, 94, 52, 91, 15, 141, 74, 146, 17, 47, 194, 21, 79, 97, 8, 9, 73, 183, 97, 73, 49, 31, 97, 9, 14, 106, 8, 8, 106, 116, 120, 61, 168, 35, 80, 9, 50, 151, 78, 91, 7, 181, 150, 106, 15, 67, 145, 180, 7, 179, 124, 82, 108, 79, 121, 120, 39, 38, 9, 167, 87, 88, 7, 51, 55, 155, 47, 81, 43, 98, 10, 92, 11, 165, 34, 115, 59, 99, 103, 108, 83, 171, 15, 9, 42, 13, 41, 88, 14, 155, 188, 96, 82, 135, 182, 36, 107, 14, 95, 142, 23, 6, 144, 35, 97, 68, 14, 67, 191, 19, 10, 158, 183, 43, 12, 148, 13, 37, 122, 80, 93, 132, 32, 103, 174, 111, 68, 192, 121, 134, 48, 85, 8, 23, 8, 6, 57, 83, 172, 101, 81, 86, 165, 73, 121, 139, 75, 151, 145, 11, 108, 14, 126, 61, 85, 8, 101, 153, 89, 190, 12, 62, 134, 101, 121, 167, 17, 161, 181, 16, 152, 148, 56, 111, 23, 84, 12, 43, 48, 122, 191, 56, 131, 51]
# [22.73234517585932, -53.340132857851245, 13.861625727493305, 1.7384598522522623, -39.47786477035692, 4.226690559683561, -17.599792937799517, 33.19116894244795, -26.26273536713284, -51.19338634516049, -16.378747134420514, -50.45772717699913, -27.706811384144302, -11.874361458851514, -15.101204013877386, -74.11142881470266, 35.27826125559585, -65.76646173007188, -37.51429185585098, -62.69480438266672, 10.374453843245277, -22.445445765043168, 14.565316190586685, -5.332900532792337, -31.888395722414003, 20.369749103622155, -36.424665867747535, -7.05110896846972, -38.844552644879585, 4.091276430936446, -49.31125783264929, -19.997269374139236, -10.006682815397589, -2.274822618579776, -43.42732287057015, 19.213072854787868, -6.232647100965863, -19.867450015895443, -0.6502761687519367, 10.347991824488378, 24.026499153157477, -26.3880483076883, -17.537236265851398, -34.04719914636584, -8.964071037754305, -40.650175814576784, 12.042960987123394, -47.51657284536954, -17.2369182906898, -14.050985646545438, -74.05984875996319, -4.641068609066508, -15.085751876024673, -27.64689635604705, -1.1358053834434116, -16.304271181747424, -41.78898951103119, 29.98785687145869, 23.654348917840935, -15.18913364108083, 52.47724896400028, 10.421861803003065, -15.561598598128008, 24.443525238169247, 78.6706493124584, -28.602941186994173, -23.441789465997445, 25.601990627606057, 7.773657838118353, 23.52419631072048, -9.219554324295586, 25.989528962547027, -0.7334587184671477, -46.45637371694667, 12.800914837332883, 5.1228266212746725, -33.92507995298983, -64.696975868588, -26.42622103418563, 35.91426839998894, -3.76369861056034, -63.15402684448213, -7.056266457153754, -4.115856049976671, -7.834960928227773, 79.45607157411115, -27.883202962797675, 14.812950281822154, -21.145448388585706, -14.944428226734917, 51.61861706686817, -30.3983945923045, 58.38538601787653, 7.403639403740158, -33.752523059864984, -21.951268404847497, 29.708389936875264, 18.815720658844285, -28.85087386589526, -30.876030402047164, -59.335017734613274, -25.1818744178862, 2.8385097534178136, 32.17361941903695, -27.72870311149569, -20.737006651275408, -2.099854828165242, 60.2813434498007, -29.46354067138435, 17.624077759288618, -52.82587661018156, -48.402033550209836, -3.0813241196053696, 2.076698532117206, 50.725381996814725, 1.5289604315528234, 58.36421465864653, 8.881110328142597, 35.17801339353889, -21.227155792098436, -66.93745348808639, -18.227990034201014, 30.906626240696596, -31.704224206445204, 59.64728817409713, -1.6388497378214453, 2.9376778992913017, -7.709792529464636, -15.110379405850281, 41.05454391373263, -33.73464012273362, -33.345904163427846, -16.955388537070448, -27.970841465474685, 29.654398014622558, -5.011800907937541, 35.85588048685107, 2.5024519331531723, -49.87991670373971, 40.60524858875881, 11.783233699449909, 6.847027603956413, 24.785733549341437, -28.225228421976794, -8.11530931924149, -38.23917571365171, -17.30238637036922, -19.209753707480782, 28.06656846973246, -11.396003316655637, 15.784741700395017, -63.473018435114014, -2.5424736772036454, -29.445297182620635, -53.56289016848365, -69.65084798522437, 60.81004125531359, -17.120406983166035, 3.8719855251708726, -27.2533519090519, -26.472781196463004, -12.293350608118281, -0.2133807521579314, -8.331597831985633, -10.049966645967373, 69.41871919873948, -42.57826058581992, -20.273717103444667, 31.73107945754498, 42.38064405454807, 17.365269760677144, 9.810503582286685, -26.645281998562503, -30.573308084271545, -9.13338607846444, -12.794179270824898, -7.766247554977124, 11.398144434856675, -43.83014835245521, 19.83048674161236, 20.831595917132383, -34.623503097240956, -39.28711634140976, 12.903098282895172, 23.475826980831975, -0.4763888785601633, 16.16950020788144, 60.64832271610092, -22.849026485499934, -27.546898741690157, 20.430889726048278, -34.05412389855176, 26.641440739303412, -52.28357652999114, 31.345098800025966, -37.38185812044176, -39.23349344728774, -60.469278818369304, -45.473812543627616, 72.0 ...

# %%
# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot the two lists against each other in the first subplot
axs[0].plot(RUL_real, label="RUL_real", marker='o')
axs[0].plot(test1_RUL_Predict, label="RUL_Predict", marker='x')
axs[0].set_title('Comparison of Two Lists')
axs[0].set_xlabel('Unit')
axs[0].set_ylabel('RUL')
axs[0].legend()

# Plot the difference in the second subplot
axs[1].plot(res, label="Difference (Real - Pred)", color='red', marker='s')
axs[1].axhline(0, color='blue', linestyle='--', label="x=0 Line,above is late pred, below is early")  # Add a horizontal line at x=0
axs[1].set_title('Difference Between the Lists')
axs[1].set_xlabel('Unit')
axs[1].set_ylabel('Difference')
axs[1].legend()

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
res_ratio = [(a - b)/((a+b)/2) for a, b in zip(RUL_real, test1_RUL_Predict)]
plt.figure(figsize=(8, 5))
plt.hist(res_ratio, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Residual = 0')  # Reference line at 0
plt.title('sMAPE Distribution')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
res= [a - b for a, b in zip(RUL_real, test1_RUL_Predict)]
plt.figure(figsize=(8, 5))
plt.hist(res, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Residual = 0')  # Reference line at 0
plt.title('residual Distribution')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
def test_dataset_fit_without_ep(test_data_frame):
    RUL_predictions = []

    for unit_number, group in test_data_frame.groupby("Unit_Number"):
        # Get test data for the current unit
        test_data = test_data_frame[test_data_frame["Unit_Number"] == unit_number]

        # Assign clusters to the last segment of the test data
        assigned_clusters = assign_last_segment_to_cluster(
            test_data=test_data,
            features=['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3'],
            cluster_models=cluster_models,
            segments_mapping=segments_mapping
        )

        # Get predictions and weights from all relevant models
        weighted_prediction = calculate_weighted_prediction(test_data, assigned_clusters)
        
        RUL_predictions.append(weighted_prediction)

    return RUL_predictions
    
        
test1_RUL_Predict_2 = test_dataset_fit_without_ep(test1_full)

# %%
res_ratio2 = [(a - b)/((a+b)/2) for a, b in zip(RUL_real, test1_RUL_Predict_2)]

# %%
res_ratio2 = [float(x) for x in res_ratio2]  # Ensure it's a numeric 1D array

# Plot the histogram with adjustments
plt.figure(figsize=(8, 5))
plt.hist(res_ratio2, bins=50, range=(-1, 1), color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Residual = 0')  # Reference line at 0
plt.title('sMAPE Distribution')
plt.xlabel('Residual Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# we'll keep the simple expensional in prediction for FD002 too.

# %% [markdown]
# ## check each unit's prediction during its life time

# %%
def predict_unit_life(test_data_frame, unit_number, step=10):
    """
    Predict RUL for a specific unit every `step` data points.

    Args:
        test_data_frame (DataFrame): The dataset containing test data.
        unit_number (int): The unit number to process.
        step (int): The interval at which predictions are made.

    Returns:
        dict: Contains the unit number and its predictions.
    """
    # Filter data for the specified unit and sort by time
    unit_data = test_data_frame[test_data_frame["Unit_Number"] == unit_number].sort_values("Time_in_Cycles")
    predictions = []

    # Generate predictions at every `step`
    for i in range(0, len(unit_data), step):
        # Select the data range for prediction
        data_subset = unit_data.iloc[i:i + step]

        if len(data_subset) < step:  # Skip incomplete steps at the end
            continue

        # Predict RUL for the current subset
        assigned_clusters = assign_last_segment_to_cluster(
            test_data=data_subset,
            features=['Operational_Setting_1', 'Operational_Setting_2', 'Operational_Setting_3'],
            cluster_models=cluster_models,
            segments_mapping=segments_mapping
        )

        # Get raw prediction and convert to a numerical value
        prediction = calculate_weighted_prediction(data_subset, assigned_clusters)
        if isinstance(prediction, pd.Series):  # Extract value from Series if needed
            prediction = prediction.values[0]
        predictions.append({"index": i, "prediction": prediction})

    return {"unit_number": unit_number, "predictions": predictions}

# %%
#cherry pick
def calculate_slope_for_all_units(test_data_frame, step=10):
    """
    Loop through all units, calculate predictions, and compute the slope for each unit.

    Args:
        test_data_frame (DataFrame): The dataset containing test data.
        step (int): The interval at which predictions are made.

    Returns:
        list of dict: Each dict contains the unit number, predictions, and slope.
    """
    unit_slopes = []

    for unit_number in test_data_frame["Unit_Number"].unique():
        # Generate predictions for the unit
        unit_result = predict_unit_life(test_data_frame, unit_number, step)

        # Extract predictions and indices
        indices = [p["index"] for p in unit_result["predictions"]]
        values = [p["prediction"] for p in unit_result["predictions"]]

        # Ensure values are numerical
        values = [v for v in values if isinstance(v, (int, float))]

        # Calculate slope using linear regression
        if len(indices) > 1 and len(indices) == len(values):
            slope, _, _, _, _ = linregress(indices, values)
            unit_result["slope"] = slope
        else:
            unit_result["slope"] = None  # Handle cases where slope cannot be calculated

        unit_slopes.append(unit_result)

    return unit_slopes

# %%
unit_slopes = calculate_slope_for_all_units(test1_full, step=10)

# %%
closest_unit = None
min_diff = float("inf")

for unit in unit_slopes:
    if unit["slope"] is not None:
        diff = abs(unit["slope"] - (-1))
        if diff < min_diff:
            min_diff = diff
            closest_unit = unit

# %%
predictions = closest_unit["predictions"]
indices = [p["index"] for p in predictions]
values = [p["prediction"] for p in predictions]

plt.figure(figsize=(10, 6))
plt.plot(indices, values, marker="o", label="RUL Predictions")
plt.title(f"RUL Predictions for Unit {unit['unit_number']} (Slope: {unit['slope']:.2f})")
plt.xlabel("Index (10-Point Step)")
plt.ylabel("RUL Prediction")
plt.legend()
plt.grid()
plt.show()
